# %%
import numpy as np
from numpy import nan
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(font='Franklin Gothic Book',
        rc={
 'axes.axisbelow': False,
 'axes.edgecolor': 'lightgrey',
 'axes.facecolor': 'None',
 'axes.grid': False,
 'axes.labelcolor': 'dimgrey',
 'axes.spines.right': False,
 'axes.spines.top': False,
 'figure.facecolor': 'white',
 'lines.solid_capstyle': 'round',
 'patch.edgecolor': 'w',
 'patch.force_edgecolor': True,
 'text.color': 'dimgrey',
 'xtick.bottom': False,
 'xtick.color': 'dimgrey',
 'xtick.direction': 'out',
 'xtick.top': False,
 'ytick.color': 'dimgrey',
 'ytick.direction': 'out',
 'ytick.left': False,
 'ytick.right': False})

sns.set_context("notebook", rc={"font.size":16,
                                "axes.titlesize":20,
                                "axes.labelsize":18})

# %%
intvars = [60,605,17686, 67255]
time = [0.05, 0.19, 21.24, 464.09]

# %%
si = [2, 4, 58, 143, 148, 149]
v=[14,106,313,326,368,370,421,421,591,908]
e=[14,118,378,399,466,469,559,559,780,1267]
b=[1,1.11,1.2,1.22,1.26,1.26,1.32,1.32,1.32,1.39]
sigma=[0.29, 0.13,0.29,0.32,0.4,0.4]
cons = [2047,7654,88753,300148,889003,889033]

# %%
lj = [2.1e-4, 1.9e-3, 0.02, 0.09, 0.18, 0.43, 0.97]
gc = [1.1e-3, 0.017, 0.32, 0.57, 0.71,0.84,5.38]
pc = [4.7e-4,1.7e-3,0.02,0.04,0.07,0.22,6.04]
dss = [4.1e-4,3e-3,0.21,0.88,1.78,1.1,21.36]
ms = [6.7e-3,0.03, 1.12,6.88,12,52,14.81,nan]
total = [0.022,0.09,1.78,8.07,12.31,13.11]

# %%
amat = [0.1, 0.38, 13.8, 51.69, 129.6, 129.6]
bmat = [0.016, 0.066, 1.87, 6.77, 16.7, 16.7]

# %%
sns.set_style("ticks")
sns.set_style("whitegrid")

# %%
plt.figure(figsize=(8,5))
plt.scatter(cons,total, s=100)
plt.plot(cons,total)
plt.xlabel('Constraints')
plt.ylabel('Total time (s)')
# Out:
# Text(0, 0.5, 'Total time (s)')

# %%
plt.figure(figsize=(8,5))

# %%
fig, (ax2, ax1) = plt.subplots(1, 2, figsize=(16,5))
#fig.suptitle('Horizontally stacked subplots')
ax1.scatter(si,total)
ax1.plot(cons,total, label = 'Data')
ax1.set_xlabel('Number of service intentions')
ax1.set_ylabel('Total time (s)')
ax1.plot(x,y, label = 'Best fit f(x) = 5e-3*|SI|^2')
ax1.legend(prop={'size': 13})

ax2.scatter(si,cons)
ax2.plot(si,cons)
ax2.set_xlabel('Constraints')
ax2.set_ylabel('Total time (s)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-60197186568d> in <module>
#       5 ax1.set_xlabel('Number of service intentions')
#       6 ax1.set_ylabel('Total time (s)')
# ----> 7 ax1.plot(x,y, label = 'Best fit f(x) = 5e-3*|SI|^2')
#       8 ax1.legend(prop={'size': 13})
#       9
#
# NameError: name 'x' is not defined

# %%
fig, (ax2, ax1) = plt.subplots(1, 2, figsize=(16,5))
#fig.suptitle('Horizontally stacked subplots')
ax2.set_title('Size of A')
ax2.scatter(cons, amat)
ax2.plot(cons, amat)
ax2.set_xlabel('Constraints')
ax2.set_ylabel('Size (MB)')

ax1.set_title('Size of b')
ax1.scatter(cons, bmat)
ax1.plot(cons, bmat)
ax1.set_xlabel('Constraints')
ax1.set_ylabel('Size (MB)')
# Out:
# Text(0, 0.5, 'Size (MB)')

# %%
a = sum([x**2 * y for x,y in zip(si, cons)])/sum([x**4 for x in si])

# %%
mymodel = np.poly1d(np.polyfit(si, cons, 2))

# %%
plt.figure(figsize=(8,5))
plt.scatter(intvars, time)
plt.xlabel('Binary variables')
plt.ylabel('Computation time')
plt.legend(prop={'size': 13})
# Out:
# No handles with labels found to put in legend.
# findfont: Font family ['Franklin Gothic Book'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Franklin Gothic Book'] not found. Falling back to DejaVu Sans.

# %%
mymodel
# Out:
# poly1d([   50.31111971, -2735.93645289, 22918.85358019])

# %%
mymodel(0)
# Out:
# 22918.853580185678

# %%
a*np.array([])
# Out:
# array([], dtype=float64)

# %%
a*np.array(si)**2
# Out:
# array([1.30218967e+02, 5.20875868e+02, 1.09514151e+05, 6.65711913e+05,
#        7.13079063e+05, 7.22747821e+05])

# %%
import scipy
scipy.stats.pearsonr(amat, bmat)
# Out:
# (0.9999820934843611, 4.80962082688843e-10)

# %%
sum([x**4 for x in si])
# Out:
# 1402147986

# %%
sum([x**2 * y**2 for x,y in zip(si, total)])
# Out:
# 8477376.935736

# %%
x = np.linspace(0,150)
y = a*x**2

# %%
a
# Out:
# 0.0005218466490740301

# %%
slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(cons, amat)

# %%
cons
# Out:
# [2047, 7654, 88753, 300148, 889003, 889033]

# %%
mymodel2 = np.poly1d(np.polyfit(cons, amat, 1))

# %%
mymodel2
# Out:
# poly1d([1.45328744e-04, 1.47365547e+00])

# %%
mymodel2(0)
# Out:
# 1.4736554656710936

# %%
siadd = [365,476,133,287]

# %%
consadd = mymodel(siadd)

# %%
fig, ax2 = plt.subplots(1, 1, figsize=(8,5))
ax2.set_title('Size of A')
ax2.scatter(cons, amat)
ax2.plot(cons, amat)
ax2.scatter(consadd, mymodel2(consadd))
ax2.set_xlabel('Constraints')
ax2.set_ylabel('Size (MB)')
# Out:
# Text(0, 0.5, 'Size (MB)')

# %%
si2t = np.poly1d(np.polyfit(si, total, 2))

# %%
plt.figure(figsize=(8,5))
plt.scatter(intvars, mymodel(si), label = 'data')
plt.scatter([365,467,133,287], mymodel([365,467,133,287]), label = 'extrapolation')
plt.xlabel('|SI|')
plt.ylabel('Constraints')
plt.legend(prop={'size': 13})
# Out:
# [2, 4, 58, 143, 148, 149]

# %%
fig, ax2 = plt.subplots(1, 1, figsize=(8,5))
ax2.set_title('Size of A')
ax2.scatter(si, total)
ax2.scatter(siadd, si2t(siadd))
ax2.set_xlabel('Constraints')
ax2.set_ylabel('Size (MB)')
# Out:
# Text(0, 0.5, 'Size (MB)')
