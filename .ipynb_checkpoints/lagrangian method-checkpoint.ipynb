# %% [markdown]
# # Construction of Route Graphs

# %%
import json
import time
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import isodate
import cvxpy as cp
import gurobipy
from functools import reduce

# %% [markdown]
# ### Load Json

# %%
scenario = "02_a_little_less_dummy.json"  # adjust path to the sample instance if it is not located there
with open(scenario) as fp:
    scenario = json.load(fp)

# %% [markdown]
# ### Process section requirements

# %%
service_intentions = {}
for si in scenario['service_intentions']:
    requirements = {}
    for i,req in enumerate(si['section_requirements']):
        requirements[req['section_marker']] = {key:value for key,value in req.items()}
        if i == 0:
            requirements[req['section_marker']]['start_end'] = 'start'
        elif i == len(si['section_requirements']) - 1:
            requirements[req['section_marker']]['start_end'] = 'end'
        else: 
            requirements[req['section_marker']]['start_end'] = None
    service_intentions[si['id']] = requirements

#get resources
resources = {}
for resource in scenario['resources']:
    idx = resource['id']
    if idx in resources:
        print('something is wrong')
    resources[idx] = resource['release_time']

# %% [markdown]
# ### Printing of nodes

# %%
def from_node_id(route_path, route_section, index_in_path):
    if "route_alternative_marker_at_entry" in route_section.keys() and \
            route_section["route_alternative_marker_at_entry"] is not None and \
            len(route_section["route_alternative_marker_at_entry"]) > 0:
                return "(" + str(route_section["route_alternative_marker_at_entry"][0]) + ")"
    else:
        if index_in_path == 0:  # can only get here if this node is a very beginning of a route
            return "(" + str(route_section["sequence_number"]) + "_beginning)"
        else:
            return "(" + (str(route_path["route_sections"][index_in_path - 1]["sequence_number"]) + "->" +
                          str(route_section["sequence_number"])) + ")"
def to_node_id(route_path, route_section, index_in_path):
    if "route_alternative_marker_at_exit" in route_section.keys() and \
            route_section["route_alternative_marker_at_exit"] is not None and \
            len(route_section["route_alternative_marker_at_exit"]) > 0:

                return "(" + str(route_section["route_alternative_marker_at_exit"][0]) + ")"
    else:
        if index_in_path == (len(route_path["route_sections"]) - 1): # meaning this node is a very end of a route
            return "(" + str(route_section["sequence_number"]) + "_end" + ")"
        else:
            return "(" + (str(route_section["sequence_number"]) + "->" +
                          str(route_path["route_sections"][index_in_path + 1]["sequence_number"])) + ")"

# %% [markdown]
# ### Construct graph for every SI, and appropriate edge constraints

# %%
route_section_keys = ['penalty', 'minimum_running_time']
section_requirement_keys = ['start_end','min_stopping_time', 'entry_earliest', 'entry_latest',
                           'exit_earliest', 'exit_latest', 'entry_delay_weight',
                           'exit_delay_weight']

# %%
start_time = time.time()

# now build the graph. Nodes are called "previous_FAB -> next_FAB" within lineare abschnittsfolgen and "AK" if
# there is an Abschnittskennzeichen 'AK' on it
route_graphs = dict()
for route in scenario["routes"]:# iterates over si?
    
    print(f"\nConstructing route graph for route {route['id']}")
    # set global graph settings
    G = nx.DiGraph(route_id = route["id"], name="Route-Graph for route "+str(route["id"]))

    # add edges with data contained in the preprocessed graph
    for path in route["route_paths"]:#iterate over admissible routes
        print('new route')
        for (i, route_section) in enumerate(path["route_sections"]):
            sn = route_section['sequence_number']
            print("Adding Edge from {} to {} with sequence number {}".format(from_node_id(path, route_section, i), to_node_id(path, route_section, i), sn))
            edge_data = {}
            for key in route_section_keys:
                if key in route_section:
                    edge_data[key] = route_section[key]
                else:
                    edge_data[key] = None
                
            if 'resource_occupations' in route_section:
                resource_occupations = {}
                for resource in route_section['resource_occupations']:
                    idx = resource['resource']
                    R = resources[idx]
                    resource_occupations[idx] = R
                    #maximum? code below
                    R=[isodate.parse_duration(value).seconds for key,value in resource_occupations.items()]
            edge_data['resource_occupations'] = resource_occupations
            edge_data['R'] = max(R)
            
            #get section marker
            section_marker = None
            if 'section_marker' in route_section:
                try:
                    section_marker = route_section['section_marker'][0]
                except:
                    pass
            edge_data['section_marker'] = section_marker
            
            
            
            if section_marker in service_intentions[route['id']]:
                for key in section_requirement_keys:
                    if key in service_intentions[route['id']][section_marker]:
                            edge_data[key] = service_intentions[route['id']][section_marker][key]
        
            edge_data['sequence_number'] = sn
            
            print(edge_data)
            G.add_edge(from_node_id(path, route_section, i),
                       to_node_id(path, route_section, i),
                       edge_data = edge_data)

    route_graphs[route["id"]] = G

print("Finished building fahrweg-graphen in {} seconds".format(str(time.time() - start_time)))
# Out:
# Constructing route graph for route 2408
# new route
# Adding Edge from (1_beginning) to (1->5) with sequence number 1
# {'penalty': None, 'minimum_running_time': 'PT1M40S', 'resource_occupations': {'ZGPP_1': 'PT10S', 'ZG_83': 'PT10S', 'ZG_3': 'PT10S'}, 'R': 10, 'section_marker': 'ZGPP', 'start_end': 'start', 'entry_earliest': '06:20:00', 'entry_delay_weight': 1, 'exit_delay_weight': 1, 'sequence_number': 1}
# Adding Edge from (1->5) to (5->10) with sequence number 5
# {'penalty': None, 'minimum_running_time': 'PT42S', 'resource_occupations': {'ZG_83': 'PT10S', 'ZG_3': 'PT10S'}, 'R': 10, 'section_marker': 'ZG-ZGSE39', 'sequence_number': 5}
# Adding Edge from (5->10) to (10->12) with sequence number 10
# {'penalty': None, 'minimum_running_time': 'PT20S', 'resource_occupations': {'ZG_3': 'PT10S'}, 'R': 10, 'section_marker': 'ZG80', 'sequence_number': 10}
# Adding Edge from (10->12) to (12->15) with sequence number 12
# {'penalty': None, 'minimum_running_time': 'PT10S', 'resource_occupations': {'ZG_3': 'PT10S'}, 'R': 10, 'section_marker': 'ZG_Halt', 'start_end': None, 'min_stopping_time': 'PT48S', 'entry_latest': '06:27:00', 'exit_earliest': '06:29:00', 'entry_delay_weight': 1, 'sequence_number': 12}
# Adding Edge from (12->15) to (15->20) with sequence number 15
# {'penalty': None, 'minimum_running_time': 'PT59S', 'resource_occupations': {'ZG_W55': 'PT10S', 'ZG_W53': 'PT10S', 'ZG_43': 'PT10S', 'ZG_33': 'PT10S', 'ZG_13': 'PT10S', 'BAAL_3': 'PT10S'}, 'R': 10, 'section_marker': 'ZG', 'sequence_number': 15}
# Adding Edge from (15->20) to (20->25) with sequence number 20
# {'penalty': None, 'minimum_running_time': 'PT10S', 'resource_occupations': {'ZG_33': 'PT10S', 'ZG_13': 'PT10S', 'BAAL_3': 'PT10S', 'ZG-BAA_428': 'PT30S', 'BAAN_2': 'PT10S'}, 'R': 30, 'section_marker': 'ZG40', 'sequence_number': 20}
# Adding Edge from (20->25) to (25->30) with sequence number 25
# {'penalty': None, 'minimum_running_time': 'PT15S', 'resource_occupations': {'BAAL_3': 'PT10S', 'ZG-BAA_428': 'PT30S', 'BAAN_2': 'PT10S', 'BAA_93': 'PT10S', 'BAA_83': 'PT10S'}, 'R': 30, 'section_marker': 'ZGN', 'sequence_number': 25}
# Adding Edge from (25->30) to (30->35) with sequence number 30
# {'penalty': None, 'minimum_running_time': 'PT13S', 'resource_occupations': {'ZG-BAA_428': 'PT30S', 'BAAN_2': 'PT10S', 'BAA_93': 'PT10S', 'BAA_83': 'PT10S', 'BAA_73': 'PT10S', 'BAA_3': 'PT10S'}, 'R': 30, 'section_marker': 'BAAL', 'sequence_number': 30}
# Adding Edge from (30->35) to (35->40) with sequence number 35
# {'penalty': None, 'minimum_running_time': 'PT23S', 'resource_occupations': {'BAA_93': 'PT10S', 'BAA_83': 'PT10S', 'BAA_73': 'PT10S', 'BAA_3': 'PT10S', 'BAA_63': 'PT10S', 'BAA-LITT_425': 'PT30S'}, 'R': 30, 'section_marker': 'BAAN', 'sequence_number': 35}
# Adding Edge from (35->40) to (40->45) with sequence number 40
# {'penalty': None, 'minimum_running_time': 'PT11S', 'resource_occupations': {'BAA_83': 'PT10S', 'BAA_73': 'PT10S', 'BAA_3': 'PT10S', 'BAA_63': 'PT10S', 'BAA-LITT_425': 'PT30S'}, 'R': 30, 'section_marker': 'BAA90', 'sequence_number': 40}
# Adding Edge from (40->45) to (45->50) with sequence number 45
# {'penalty': None, 'minimum_running_time': 'PT9S', 'resource_occupations': {'BAA_73': 'PT10S', 'BAA_3': 'PT10S', 'BAA_63': 'PT10S', 'BAA-LITT_425': 'PT30S', 'LITT_91': 'PT10S', 'LITT_61': 'PT10S'}, 'R': 30, 'section_marker': 'BAA80', 'sequence_number': 45}
# Adding Edge from (45->50) to (50->55) with sequence number 50
# {'penalty': None, 'minimum_running_time': 'PT8S', 'resource_occupations': {'BAA_3': 'PT10S', 'BAA_63': 'PT10S', 'BAA-LITT_425': 'PT30S', 'LITT_91': 'PT10S', 'LITT_61': 'PT10S'}, 'R': 30, 'section_marker': 'BAA70', 'sequence_number': 50}
# Adding Edge from (50->55) to (55->60) with sequence number 55
# {'penalty': None, 'minimum_running_time': 'PT13S', 'resource_occupations': {'BAA_63': 'PT10S', 'BAA-LITT_425': 'PT30S', 'LITT_91': 'PT10S', 'LITT_61': 'PT10S', 'LITT_1': 'PT10S'}, 'R': 30, 'section_marker': 'BAA', 'sequence_number': 55}
# Adding Edge from (55->60) to (60->65) with sequence number 60
# {'penalty': None, 'minimum_running_time': 'PT20S', 'resource_occupations': {'BAA-LITT_425': 'PT30S', 'LITT_91': 'PT10S', 'LITT_61': 'PT10S', 'LITT_1': 'PT10S', 'LITT_11': 'PT10S'}, 'R': 30, 'section_marker': 'BAA60', 'sequence_number': 60}
# Adding Edge from (60->65) to (65->70) with sequence number 65
# {'penalty': None, 'minimum_running_time': 'PT22S', 'resource_occupations': {'LITT_91': 'PT10S', 'LITT_61': 'PT10S', 'LITT_1': 'PT10S', 'LITT_11': 'PT10S', 'SBG-LITT_424': 'PT30S'}, 'R': 30, 'section_marker': 'LITT-BAA25', 'sequence_number': 65}
# Adding Edge from (65->70) to (70->75) with sequence number 70
# {'penalty': None, 'minimum_running_time': 'PT28S', 'resource_occupations': {'LITT_1': 'PT10S', 'LITT_11': 'PT10S', 'SBG-LITT_424': 'PT30S', 'SBG-LITT_422': 'PT30S'}, 'R': 30, 'section_marker': 'LITTS', 'sequence_number': 70}
# Adding Edge from (70->75) to (75->80) with sequence number 75
# {'penalty': None, 'minimum_running_time': 'PT29S', 'resource_occupations': {'LITT_11': 'PT10S', 'SBG-LITT_424': 'PT30S', 'SBG-LITT_422': 'PT30S'}, 'R': 30, 'section_marker': 'LITT', 'sequence_number': 75}
# Adding Edge from (75->80) to (80->85) with sequence number 80
# {'penalty': None, 'minimum_running_time': 'PT26S', 'resource_occupations': {'SBG-LITT_424': 'PT30S', 'SBG-LITT_422': 'PT30S', 'SBG-LITT_421': 'PT30S', 'SBG-LITT_420': 'PT30S'}, 'R': 30, 'section_marker': 'LITTN', 'sequence_number': 80}
# Adding Edge from (80->85) to (85->90) with sequence number 85
# {'penalty': None, 'minimum_running_time': 'PT28S', 'resource_occupations': {'SBG-LITT_422': 'PT30S', 'SBG-LITT_421': 'PT30S', 'SBG-LITT_420': 'PT30S', 'SBG_94': 'PT10S', 'SBG_3': 'PT10S'}, 'R': 30, 'section_marker': 'SBG-LITT24', 'sequence_number': 85}
# Adding Edge from (85->90) to (90->95) with sequence number 90
# {'penalty': None, 'minimum_running_time': 'PT26S', 'resource_occupations': {'SBG-LITT_421': 'PT30S', 'SBG-LITT_420': 'PT30S', 'SBG_94': 'PT10S', 'SBG_3': 'PT10S', 'SBG_33': 'PT10S'}, 'R': 30, 'section_marker': 'SBG-LITT22', 'sequence_number': 90}
# Adding Edge from (90->95) to (95->100) with sequence number 95
# {'penalty': None, 'minimum_running_time': 'PT28S', 'resource_occupations': {'SBG_94': 'PT10S', 'SBG_3': 'PT10S', 'SBG_33': 'PT10S', 'SBG_14': 'PT10S'}, 'R': 10, 'section_marker': 'SBG-LITT20', 'sequence_number': 95}
# Adding Edge from (95->100) to (100->105) with sequence number 100
# {'penalty': None, 'minimum_running_time': 'PT16S', 'resource_occupations': {'SBG_3': 'PT10S', 'SBG_33': 'PT10S', 'SBG_14': 'PT10S', 'HGO-SBG_418': 'PT30S'}, 'R': 30, 'section_marker': 'SBGS', 'sequence_number': 100}
# Adding Edge from (100->105) to (105->110) with sequence number 105
# {'penalty': None, 'minimum_running_time': 'PT22S', 'resource_occupations': {'SBG_33': 'PT10S', 'SBG_14': 'PT10S', 'HGO-SBG_418': 'PT30S'}, 'R': 30, 'section_marker': 'SBG', 'sequence_number': 105}
# Adding Edge from (105->110) to (110->115) with sequence number 110
# {'penalty': None, 'minimum_running_time': 'PT12S', 'resource_occupations': {'SBG_14': 'PT10S', 'HGO-SBG_418': 'PT30S', 'HGO-SBG_417': 'PT30S', 'HGO-SBG_416': 'PT30S'}, 'R': 30, 'section_marker': 'SBG30', 'sequence_number': 110}
# Adding Edge from (110->115) to (115->120) with sequence number 115
# {'penalty': None, 'minimum_running_time': 'PT36S', 'resource_occupations': {'HGO-SBG_418': 'PT30S', 'HGO-SBG_417': 'PT30S', 'HGO-SBG_416': 'PT30S', 'HGO_94': 'PT10S', 'HGO_74': 'PT10S', 'HGO_4': 'PT10S'}, 'R': 30, 'section_marker': 'SBG10', 'sequence_number': 115}
# Adding Edge from (115->120) to (120->125) with sequence number 120
# {'penalty': None, 'minimum_running_time': 'PT27S', 'resource_occupations': {'HGO-SBG_417': 'PT30S', 'HGO-SBG_416': 'PT30S', 'HGO_94': 'PT10S', 'HGO_74': 'PT10S', 'HGO_4': 'PT10S', 'HGO_24': 'PT10S', 'HGO-ORDD_415': 'PT30S'}, 'R': 30, 'section_marker': 'HGO-SBG18', 'sequence_number': 120}
# Adding Edge from (120->125) to (125->130) with sequence number 125
# {'penalty': None, 'minimum_running_time': 'PT32S', 'resource_occupations': {'HGO_94': 'PT10S', 'HGO_74': 'PT10S', 'HGO_4': 'PT10S', 'HGO_24': 'PT10S', 'HGO-ORDD_415': 'PT30S', 'HGO-ORDD_414': 'PT30S'}, 'R': 30, 'section_marker': 'HGO-SBG16', 'sequence_number': 125}
# Adding Edge from (125->130) to (130->135) with sequence number 130
# {'penalty': None, 'minimum_running_time': 'PT16S', 'resource_occupations': {'HGO_4': 'PT10S', 'HGO_24': 'PT10S', 'HGO-ORDD_415': 'PT30S', 'HGO-ORDD_414': 'PT30S'}, 'R': 30, 'section_marker': 'HGOO', 'sequence_number': 130}
# Adding Edge from (130->135) to (135->140) with sequence number 135
# {'penalty': None, 'minimum_running_time': 'PT20S', 'resource_occupations': {'HGO_24': 'PT10S', 'HGO-ORDD_415': 'PT30S', 'HGO-ORDD_414': 'PT30S', 'ORDD_1': 'PT10S'}, 'R': 30, 'section_marker': 'HGO', 'sequence_number': 135}
# Adding Edge from (135->140) to (140->145) with sequence number 140
# {'penalty': None, 'minimum_running_time': 'PT12S', 'resource_occupations': {'HGO-ORDD_415': 'PT30S', 'HGO-ORDD_414': 'PT30S', 'ORDD_1': 'PT10S'}, 'R': 30, 'section_marker': 'HGOW', 'sequence_number': 140}
# Adding Edge from (140->145) to (145->150) with sequence number 145
# {'penalty': None, 'minimum_running_time': 'PT16S', 'resource_occupations': {'HGO-ORDD_414': 'PT30S', 'ORDD_1': 'PT10S', 'ORDD-TW_412': 'PT30S', 'ORDD-TW_411': 'PT30S'}, 'R': 30, 'section_marker': 'ORDD-HGO15', 'sequence_number': 145}
# Adding Edge from (145->150) to (150->155) with sequence number 150
# {'penalty': None, 'minimum_running_time': 'PT26S', 'resource_occupations': {'ORDD_1': 'PT10S', 'ORDD-TW_412': 'PT30S', 'ORDD-TW_411': 'PT30S', 'TW_85': 'PT10S', 'TW_55': 'PT10S', 'TW_5': 'PT10S'}, 'R': 30, 'section_marker': 'ORDD-HGO14', 'sequence_number': 150}
# Adding Edge from (150->155) to (155->160) with sequence number 155
# {'penalty': None, 'minimum_running_time': 'PT30S', 'resource_occupations': {'ORDD-TW_412': 'PT30S', 'ORDD-TW_411': 'PT30S', 'TW_85': 'PT10S', 'TW_55': 'PT10S', 'TW_5': 'PT10S', 'TW_45': 'PT10S', 'TW_26': 'PT10S', 'TW_25': 'PT10S'}, 'R': 30, 'section_marker': 'ORDD', 'sequence_number': 155}
# Adding Edge from (155->160) to (160->165) with sequence number 160
# {'penalty': None, 'minimum_running_time': 'PT53S', 'resource_occupations': {'TW_85': 'PT10S', 'TW_55': 'PT10S', 'TW_5': 'PT10S', 'TW_45': 'PT10S', 'TW_26': 'PT10S', 'TW_25': 'PT10S', 'TW-NIDB_258': 'PT30S'}, 'R': 30, 'section_marker': 'TW-ORDD12', 'sequence_number': 160}
# Adding Edge from (160->165) to (165->170) with sequence number 165
# {'penalty': None, 'minimum_running_time': 'PT32S', 'resource_occupations': {'TW_5': 'PT10S', 'TW_45': 'PT10S', 'TW_26': 'PT10S', 'TW_25': 'PT10S', 'TW-NIDB_258': 'PT30S'}, 'R': 30, 'section_marker': 'TWO', 'sequence_number': 165}
# Adding Edge from (165->170) to (170->175) with sequence number 170
# {'penalty': None, 'minimum_running_time': 'PT16S', 'resource_occupations': {'TW_45': 'PT10S', 'TW_26': 'PT10S', 'TW_25': 'PT10S', 'TW-NIDB_258': 'PT30S', 'NIDB_N94': 'PT10S'}, 'R': 30, 'section_marker': 'TW', 'sequence_number': 170}
# Adding Edge from (170->175) to (175->180) with sequence number 175
# {'penalty': None, 'minimum_running_time': 'PT14S', 'resource_occupations': {'TW_25': 'PT10S', 'TW-NIDB_258': 'PT30S', 'NIDB_N94': 'PT10S', 'NIDB_N13': 'PT10S'}, 'R': 30, 'section_marker': 'TWNO', 'sequence_number': 175}
# Adding Edge from (175->180) to (180->185) with sequence number 180
# {'penalty': None, 'minimum_running_time': 'PT17S', 'resource_occupations': {'TW-NIDB_258': 'PT30S', 'NIDB_N94': 'PT10S', 'NIDB_N13': 'PT10S', 'NIDB-ZKOL_257': 'PT30S'}, 'R': 30, 'section_marker': 'TW20', 'sequence_number': 180}
# Adding Edge from (180->185) to (185->190) with sequence number 185
# {'penalty': None, 'minimum_running_time': 'PT22S', 'resource_occupations': {'NIDB_N94': 'PT10S', 'NIDB_N13': 'PT10S', 'NIDB-ZKOL_257': 'PT30S', 'NIDB-ZKOL_256': 'PT30S'}, 'R': 30, 'section_marker': 'NIDB90', 'sequence_number': 185}
# Adding Edge from (185->190) to (190->195) with sequence number 190
# {'penalty': None, 'minimum_running_time': 'PT25S', 'resource_occupations': {'NIDB_N13': 'PT10S', 'NIDB-ZKOL_257': 'PT30S', 'NIDB-ZKOL_256': 'PT30S', 'NIDB-ZKOL_255': 'PT30S'}, 'R': 30, 'section_marker': 'NIDB', 'sequence_number': 190}
# Adding Edge from (190->195) to (195->200) with sequence number 195
# {'penalty': None, 'minimum_running_time': 'PT24S', 'resource_occupations': {'NIDB-ZKOL_257': 'PT30S', 'NIDB-ZKOL_256': 'PT30S', 'NIDB-ZKOL_255': 'PT30S', 'NIDB-ZKOL_254': 'PT30S'}, 'R': 30, 'section_marker': 'NIDB70', 'sequence_number': 195}
# Adding Edge from (195->200) to (200->205) with sequence number 200
# {'penalty': None, 'minimum_running_time': 'PT20S', 'resource_occupations': {'NIDB-ZKOL_256': 'PT30S', 'NIDB-ZKOL_255': 'PT30S', 'NIDB-ZKOL_254': 'PT30S', 'NIDB-ZKOL_253': 'PT30S'}, 'R': 30, 'section_marker': 'ZBT57', 'sequence_number': 200}
# Adding Edge from (200->205) to (205->210) with sequence number 205
# {'penalty': None, 'minimum_running_time': 'PT33S', 'resource_occupations': {'NIDB-ZKOL_255': 'PT30S', 'NIDB-ZKOL_254': 'PT30S', 'NIDB-ZKOL_253': 'PT30S'}, 'R': 30, 'section_marker': 'ZBT56', 'sequence_number': 205}
# Adding Edge from (205->210) to (210->215) with sequence number 210
# {'penalty': None, 'minimum_running_time': 'PT33S', 'resource_occupations': {'NIDB-ZKOL_254': 'PT30S', 'NIDB-ZKOL_253': 'PT30S', 'ZKOL_65': 'PT10S', 'ZKOL_45': 'PT10S'}, 'R': 30, 'section_marker': 'ZBT55', 'sequence_number': 210}
# Adding Edge from (210->215) to (215->220) with sequence number 215
# {'penalty': None, 'minimum_running_time': 'PT25S', 'resource_occupations': {'NIDB-ZKOL_253': 'PT30S', 'ZKOL_65': 'PT10S', 'ZKOL_45': 'PT10S', 'ZAU_25': 'PT10S'}, 'R': 30, 'section_marker': 'ZBT54', 'sequence_number': 215}
# Adding Edge from (215->220) to (220->225) with sequence number 220
# {'penalty': None, 'minimum_running_time': 'PT27S', 'resource_occupations': {'ZKOL_65': 'PT10S', 'ZKOL_45': 'PT10S', 'ZAU_25': 'PT10S', 'ZAU_15': 'PT10S', 'ZAU_GD': 'PT10S'}, 'R': 10, 'section_marker': 'ZBT53', 'sequence_number': 220}
# Adding Edge from (220->225) to (225->230) with sequence number 225
# {'penalty': None, 'minimum_running_time': 'PT14S', 'resource_occupations': {'ZKOL_45': 'PT10S', 'ZAU_25': 'PT10S', 'ZAU_15': 'PT10S', 'ZAU_GD': 'PT10S', 'ZAU-ZUE_251': 'PT30S'}, 'R': 30, 'section_marker': 'ZKOL', 'sequence_number': 225}
# Adding Edge from (225->230) to (230->235) with sequence number 230
# {'penalty': None, 'minimum_running_time': 'PT14S', 'resource_occupations': {'ZAU_25': 'PT10S', 'ZAU_15': 'PT10S', 'ZAU_GD': 'PT10S', 'ZAU-ZUE_251': 'PT30S'}, 'R': 30, 'section_marker': 'ZKOLN', 'sequence_number': 230}
# Adding Edge from (230->235) to (235->240) with sequence number 235
# {'penalty': None, 'minimum_running_time': 'PT28S', 'resource_occupations': {'ZAU_15': 'PT10S', 'ZAU_GD': 'PT10S', 'ZAU-ZUE_251': 'PT30S', 'ZUE_L3': 'PT10S', 'ZUE_Z3': 'PT10S', 'ZUE_C2': 'PT10S', 'ZUE_W11': 'PT10S', 'ZUE_B3': 'PT10S', 'ZUE_A7-A': 'PT10S', 'ZUE_A7-B': 'PT10S'}, 'R': 30, 'section_marker': 'ZAUZBT', 'sequence_number': 235}
# Adding Edge from (235->240) to (240->245) with sequence number 240
# {'penalty': None, 'minimum_running_time': 'PT31S', 'resource_occupations': {'ZAU-ZUE_251': 'PT30S', 'ZUE_L3': 'PT10S', 'ZUE_Z3': 'PT10S', 'ZUE_C2': 'PT10S', 'ZUE_W11': 'PT10S', 'ZUE_B3': 'PT10S', 'ZUE_A7-A': 'PT10S', 'ZUE_A7-B': 'PT10S'}, 'R': 30, 'section_marker': 'ZAU', 'sequence_number': 240}
# Adding Edge from (240->245) to (245->250) with sequence number 245
# {'penalty': None, 'minimum_running_time': 'PT39S', 'resource_occupations': {'ZAU-ZUE_251': 'PT30S', 'ZUE_L3': 'PT10S', 'ZUE_Z3': 'PT10S', 'ZUE_C2': 'PT10S', 'ZUE_W11': 'PT10S', 'ZUE_B3': 'PT10S', 'ZUE_A7-A': 'PT10S', 'ZUE_A7-B': 'PT10S'}, 'R': 30, 'section_marker': 'ZUE-ZAU01', 'sequence_number': 245}
# Adding Edge from (245->250) to (250->255) with sequence number 250
# {'penalty': None, 'minimum_running_time': 'PT4S', 'resource_occupations': {'ZUE_L3': 'PT10S', 'ZUE_Z3': 'PT10S', 'ZUE_C2': 'PT10S', 'ZUE_W11': 'PT10S', 'ZUE_B3': 'PT10S', 'ZUE_A7-A': 'PT10S', 'ZUE_A7-B': 'PT10S'}, 'R': 10, 'section_marker': 'ZLST', 'sequence_number': 250}
# Adding Edge from (250->255) to (255->260) with sequence number 255
# {'penalty': None, 'minimum_running_time': 'PT32S', 'resource_occupations': {'ZUE_C2': 'PT10S', 'ZUE_W11': 'PT10S', 'ZUE_B3': 'PT10S', 'ZUE_A7-A': 'PT10S', 'ZUE_A7-B': 'PT10S'}, 'R': 10, 'section_marker': 'ZUEZSW', 'sequence_number': 255}
# Adding Edge from (255->260) to (260->265) with sequence number 260
# {'penalty': None, 'minimum_running_time': 'PT24S', 'resource_occupations': {'ZUE_A7-A': 'PT10S', 'ZUE_A7-B': 'PT10S'}, 'R': 10, 'section_marker': 'ZUEC', 'sequence_number': 260}
# Adding Edge from (260->265) to (265_end) with sequence number 265
# {'penalty': None, 'minimum_running_time': 'PT10S', 'resource_occupations': {'ZUE_A7-A': 'PT10S', 'ZUE_A7-B': 'PT10S'}, 'R': 10, 'section_marker': 'ZUE_Halt', 'start_end': 'end', 'min_stopping_time': 'PT24S', 'entry_latest': '06:51:00', 'exit_latest': '06:56:00', 'entry_delay_weight': 1, 'exit_delay_weight': 1, 'sequence_number': 265}
#
# Constructing route graph for route 856
# new route
# Adding Edge from (1_beginning) to (1->5) with sequence number 1
# {'penalty': None, 'minimum_running_time': 'PT1M40S', 'resource_occupations': {'ZGPP_1': 'PT10S', 'ZG_83': 'PT10S', 'ZG_3': 'PT10S'}, 'R': 10, 'section_marker': 'ZGPP', 'start_end': 'start', 'entry_earliest': '07:20:00', 'entry_delay_weight': 1, 'exit_delay_weight': 1, 'sequence_number': 1}
# Adding Edge from (1->5) to (5->10) with sequence number 5
# {'penalty': None, 'minimum_running_time': 'PT42S', 'resource_occupations': {'ZG_83': 'PT10S', 'ZG_3': 'PT10S'}, 'R': 10, 'section_marker': 'ZG-ZGSE39', 'sequence_number': 5}
# Adding Edge from (5->10) to (10->12) with sequence number 10
# {'penalty': None, 'minimum_running_time': 'PT20S', 'resource_occupations': {'ZG_3': 'PT10S'}, 'R': 10, 'section_marker': 'ZG80', 'sequence_number': 10}
# Adding Edge from (10->12) to (12->15) with sequence number 12
# {'penalty': None, 'minimum_running_time': 'PT10S', 'resource_occupations': {'ZG_3': 'PT10S'}, 'R': 10, 'section_marker': 'ZG_Halt', 'start_end': None, 'min_stopping_time': 'PT48S', 'entry_latest': '07:27:00', 'exit_earliest': '07:29:00', 'entry_delay_weight': 1, 'sequence_number': 12}
# Adding Edge from (12->15) to (15->20) with sequence number 15
# {'penalty': None, 'minimum_running_time': 'PT59S', 'resource_occupations': {'ZG_W55': 'PT10S', 'ZG_W53': 'PT10S', 'ZG_43': 'PT10S', 'ZG_33': 'PT10S', 'ZG_13': 'PT10S', 'BAAL_3': 'PT10S'}, 'R': 10, 'section_marker': 'ZG', 'sequence_number': 15}
# Adding Edge from (15->20) to (20->25) with sequence number 20
# {'penalty': None, 'minimum_running_time': 'PT10S', 'resource_occupations': {'ZG_33': 'PT10S', 'ZG_13': 'PT10S', 'BAAL_3': 'PT10S', 'ZG-BAA_428': 'PT30S', 'BAAN_2': 'PT10S'}, 'R': 30, 'section_marker': 'ZG40', 'sequence_number': 20}
# Adding Edge from (20->25) to (25->30) with sequence number 25
# {'penalty': None, 'minimum_running_time': 'PT15S', 'resource_occupations': {'BAAL_3': 'PT10S', 'ZG-BAA_428': 'PT30S', 'BAAN_2': 'PT10S', 'BAA_93': 'PT10S', 'BAA_83': 'PT10S'}, 'R': 30, 'section_marker': 'ZGN', 'sequence_number': 25}
# Adding Edge from (25->30) to (30->35) with sequence number 30
# {'penalty': None, 'minimum_running_time': 'PT13S', 'resource_occupations': {'ZG-BAA_428': 'PT30S', 'BAAN_2': 'PT10S', 'BAA_93': 'PT10S', 'BAA_83': 'PT10S', 'BAA_73': 'PT10S', 'BAA_3': 'PT10S'}, 'R': 30, 'section_marker': 'BAAL', 'sequence_number': 30}
# Adding Edge from (30->35) to (35->40) with sequence number 35
# {'penalty': None, 'minimum_running_time': 'PT23S', 'resource_occupations': {'BAA_93': 'PT10S', 'BAA_83': 'PT10S', 'BAA_73': 'PT10S', 'BAA_3': 'PT10S', 'BAA_63': 'PT10S', 'BAA-LITT_425': 'PT30S'}, 'R': 30, 'section_marker': 'BAAN', 'sequence_number': 35}
# Adding Edge from (35->40) to (40->45) with sequence number 40
# {'penalty': None, 'minimum_running_time': 'PT11S', 'resource_occupations': {'BAA_83': 'PT10S', 'BAA_73': 'PT10S', 'BAA_3': 'PT10S', 'BAA_63': 'PT10S', 'BAA-LITT_425': 'PT30S'}, 'R': 30, 'section_marker': 'BAA90', 'sequence_number': 40}
# Adding Edge from (40->45) to (45->50) with sequence number 45
# {'penalty': None, 'minimum_running_time': 'PT9S', 'resource_occupations': {'BAA_73': 'PT10S', 'BAA_3': 'PT10S', 'BAA_63': 'PT10S', 'BAA-LITT_425': 'PT30S', 'LITT_91': 'PT10S', 'LITT_61': 'PT10S'}, 'R': 30, 'section_marker': 'BAA80', 'sequence_number': 45}
# Adding Edge from (45->50) to (50->55) with sequence number 50
# {'penalty': None, 'minimum_running_time': 'PT8S', 'resource_occupations': {'BAA_3': 'PT10S', 'BAA_63': 'PT10S', 'BAA-LITT_425': 'PT30S', 'LITT_91': 'PT10S', 'LITT_61': 'PT10S'}, 'R': 30, 'section_marker': 'BAA70', 'sequence_number': 50}
# Adding Edge from (50->55) to (55->60) with sequence number 55
# {'penalty': None, 'minimum_running_time': 'PT13S', 'resource_occupations': {'BAA_63': 'PT10S', 'BAA-LITT_425': 'PT30S', 'LITT_91': 'PT10S', 'LITT_61': 'PT10S', 'LITT_1': 'PT10S'}, 'R': 30, 'section_marker': 'BAA', 'sequence_number': 55}
# Adding Edge from (55->60) to (60->65) with sequence number 60
# {'penalty': None, 'minimum_running_time': 'PT20S', 'resource_occupations': {'BAA-LITT_425': 'PT30S', 'LITT_91': 'PT10S', 'LITT_61': 'PT10S', 'LITT_1': 'PT10S', 'LITT_11': 'PT10S'}, 'R': 30, 'section_marker': 'BAA60', 'sequence_number': 60}
# Adding Edge from (60->65) to (65->70) with sequence number 65
# {'penalty': None, 'minimum_running_time': 'PT22S', 'resource_occupations': {'LITT_91': 'PT10S', 'LITT_61': 'PT10S', 'LITT_1': 'PT10S', 'LITT_11': 'PT10S', 'SBG-LITT_424': 'PT30S'}, 'R': 30, 'section_marker': 'LITT-BAA25', 'sequence_number': 65}
# Adding Edge from (65->70) to (70->75) with sequence number 70
# {'penalty': None, 'minimum_running_time': 'PT28S', 'resource_occupations': {'LITT_1': 'PT10S', 'LITT_11': 'PT10S', 'SBG-LITT_424': 'PT30S', 'SBG-LITT_422': 'PT30S'}, 'R': 30, 'section_marker': 'LITTS', 'sequence_number': 70}
# Adding Edge from (70->75) to (75->80) with sequence number 75
# {'penalty': None, 'minimum_running_time': 'PT29S', 'resource_occupations': {'LITT_11': 'PT10S', 'SBG-LITT_424': 'PT30S', 'SBG-LITT_422': 'PT30S'}, 'R': 30, 'section_marker': 'LITT', 'sequence_number': 75}
# Adding Edge from (75->80) to (80->85) with sequence number 80
# {'penalty': None, 'minimum_running_time': 'PT26S', 'resource_occupations': {'SBG-LITT_424': 'PT30S', 'SBG-LITT_422': 'PT30S', 'SBG-LITT_421': 'PT30S', 'SBG-LITT_420': 'PT30S'}, 'R': 30, 'section_marker': 'LITTN', 'sequence_number': 80}
# Adding Edge from (80->85) to (85->90) with sequence number 85
# {'penalty': None, 'minimum_running_time': 'PT28S', 'resource_occupations': {'SBG-LITT_422': 'PT30S', 'SBG-LITT_421': 'PT30S', 'SBG-LITT_420': 'PT30S', 'SBG_94': 'PT10S', 'SBG_3': 'PT10S'}, 'R': 30, 'section_marker': 'SBG-LITT24', 'sequence_number': 85}
# Adding Edge from (85->90) to (90->95) with sequence number 90
# {'penalty': None, 'minimum_running_time': 'PT26S', 'resource_occupations': {'SBG-LITT_421': 'PT30S', 'SBG-LITT_420': 'PT30S', 'SBG_94': 'PT10S', 'SBG_3': 'PT10S', 'SBG_33': 'PT10S'}, 'R': 30, 'section_marker': 'SBG-LITT22', 'sequence_number': 90}
# Adding Edge from (90->95) to (95->100) with sequence number 95
# {'penalty': None, 'minimum_running_time': 'PT28S', 'resource_occupations': {'SBG_94': 'PT10S', 'SBG_3': 'PT10S', 'SBG_33': 'PT10S', 'SBG_14': 'PT10S'}, 'R': 10, 'section_marker': 'SBG-LITT20', 'sequence_number': 95}
# Adding Edge from (95->100) to (100->105) with sequence number 100
# {'penalty': None, 'minimum_running_time': 'PT16S', 'resource_occupations': {'SBG_3': 'PT10S', 'SBG_33': 'PT10S', 'SBG_14': 'PT10S', 'HGO-SBG_418': 'PT30S'}, 'R': 30, 'section_marker': 'SBGS', 'sequence_number': 100}
# Adding Edge from (100->105) to (105->110) with sequence number 105
# {'penalty': None, 'minimum_running_time': 'PT22S', 'resource_occupations': {'SBG_33': 'PT10S', 'SBG_14': 'PT10S', 'HGO-SBG_418': 'PT30S'}, 'R': 30, 'section_marker': 'SBG', 'sequence_number': 105}
# Adding Edge from (105->110) to (110->115) with sequence number 110
# {'penalty': None, 'minimum_running_time': 'PT12S', 'resource_occupations': {'SBG_14': 'PT10S', 'HGO-SBG_418': 'PT30S', 'HGO-SBG_417': 'PT30S', 'HGO-SBG_416': 'PT30S'}, 'R': 30, 'section_marker': 'SBG30', 'sequence_number': 110}
# Adding Edge from (110->115) to (115->120) with sequence number 115
# {'penalty': None, 'minimum_running_time': 'PT36S', 'resource_occupations': {'HGO-SBG_418': 'PT30S', 'HGO-SBG_417': 'PT30S', 'HGO-SBG_416': 'PT30S', 'HGO_94': 'PT10S', 'HGO_74': 'PT10S', 'HGO_4': 'PT10S'}, 'R': 30, 'section_marker': 'SBG10', 'sequence_number': 115}
# Adding Edge from (115->120) to (120->125) with sequence number 120
# {'penalty': None, 'minimum_running_time': 'PT27S', 'resource_occupations': {'HGO-SBG_417': 'PT30S', 'HGO-SBG_416': 'PT30S', 'HGO_94': 'PT10S', 'HGO_74': 'PT10S', 'HGO_4': 'PT10S', 'HGO_24': 'PT10S', 'HGO-ORDD_415': 'PT30S'}, 'R': 30, 'section_marker': 'HGO-SBG18', 'sequence_number': 120}
# Adding Edge from (120->125) to (125->130) with sequence number 125
# {'penalty': None, 'minimum_running_time': 'PT32S', 'resource_occupations': {'HGO_94': 'PT10S', 'HGO_74': 'PT10S', 'HGO_4': 'PT10S', 'HGO_24': 'PT10S', 'HGO-ORDD_415': 'PT30S', 'HGO-ORDD_414': 'PT30S'}, 'R': 30, 'section_marker': 'HGO-SBG16', 'sequence_number': 125}
# Adding Edge from (125->130) to (130->135) with sequence number 130
# {'penalty': None, 'minimum_running_time': 'PT16S', 'resource_occupations': {'HGO_4': 'PT10S', 'HGO_24': 'PT10S', 'HGO-ORDD_415': 'PT30S', 'HGO-ORDD_414': 'PT30S'}, 'R': 30, 'section_marker': 'HGOO', 'sequence_number': 130}
# Adding Edge from (130->135) to (135->140) with sequence number 135
# {'penalty': None, 'minimum_running_time': 'PT20S', 'resource_occupations': {'HGO_24': 'PT10S', 'HGO-ORDD_415': 'PT30S', 'HGO-ORDD_414': 'PT30S', 'ORDD_1': 'PT10S'}, 'R': 30, 'section_marker': 'HGO', 'sequence_number': 135}
# Adding Edge from (135->140) to (140->145) with sequence number 140
# {'penalty': None, 'minimum_running_time': 'PT12S', 'resource_occupations': {'HGO-ORDD_415': 'PT30S', 'HGO-ORDD_414': 'PT30S', 'ORDD_1': 'PT10S'}, 'R': 30, 'section_marker': 'HGOW', 'sequence_number': 140}
# Adding Edge from (140->145) to (145->150) with sequence number 145
# {'penalty': None, 'minimum_running_time': 'PT16S', 'resource_occupations': {'HGO-ORDD_414': 'PT30S', 'ORDD_1': 'PT10S', 'ORDD-TW_412': 'PT30S', 'ORDD-TW_411': 'PT30S'}, 'R': 30, 'section_marker': 'ORDD-HGO15', 'sequence_number': 145}
# Adding Edge from (145->150) to (150->155) with sequence number 150
# {'penalty': None, 'minimum_running_time': 'PT26S', 'resource_occupations': {'ORDD_1': 'PT10S', 'ORDD-TW_412': 'PT30S', 'ORDD-TW_411': 'PT30S', 'TW_85': 'PT10S', 'TW_55': 'PT10S', 'TW_5': 'PT10S'}, 'R': 30, 'section_marker': 'ORDD-HGO14', 'sequence_number': 150}
# Adding Edge from (150->155) to (155->160) with sequence number 155
# {'penalty': None, 'minimum_running_time': 'PT30S', 'resource_occupations': {'ORDD-TW_412': 'PT30S', 'ORDD-TW_411': 'PT30S', 'TW_85': 'PT10S', 'TW_55': 'PT10S', 'TW_5': 'PT10S', 'TW_45': 'PT10S', 'TW_26': 'PT10S', 'TW_25': 'PT10S'}, 'R': 30, 'section_marker': 'ORDD', 'sequence_number': 155}
# Adding Edge from (155->160) to (160->165) with sequence number 160
# {'penalty': None, 'minimum_running_time': 'PT53S', 'resource_occupations': {'TW_85': 'PT10S', 'TW_55': 'PT10S', 'TW_5': 'PT10S', 'TW_45': 'PT10S', 'TW_26': 'PT10S', 'TW_25': 'PT10S', 'TW-NIDB_258': 'PT30S'}, 'R': 30, 'section_marker': 'TW-ORDD12', 'sequence_number': 160}
# Adding Edge from (160->165) to (165->170) with sequence number 165
# {'penalty': None, 'minimum_running_time': 'PT32S', 'resource_occupations': {'TW_5': 'PT10S', 'TW_45': 'PT10S', 'TW_26': 'PT10S', 'TW_25': 'PT10S', 'TW-NIDB_258': 'PT30S'}, 'R': 30, 'section_marker': 'TWO', 'sequence_number': 165}
# Adding Edge from (165->170) to (170->175) with sequence number 170
# {'penalty': None, 'minimum_running_time': 'PT16S', 'resource_occupations': {'TW_45': 'PT10S', 'TW_26': 'PT10S', 'TW_25': 'PT10S', 'TW-NIDB_258': 'PT30S', 'NIDB_N94': 'PT10S'}, 'R': 30, 'section_marker': 'TW', 'sequence_number': 170}
# Adding Edge from (170->175) to (175->180) with sequence number 175
# {'penalty': None, 'minimum_running_time': 'PT14S', 'resource_occupations': {'TW_25': 'PT10S', 'TW-NIDB_258': 'PT30S', 'NIDB_N94': 'PT10S', 'NIDB_N13': 'PT10S'}, 'R': 30, 'section_marker': 'TWNO', 'sequence_number': 175}
# Adding Edge from (175->180) to (180->185) with sequence number 180
# {'penalty': None, 'minimum_running_time': 'PT17S', 'resource_occupations': {'TW-NIDB_258': 'PT30S', 'NIDB_N94': 'PT10S', 'NIDB_N13': 'PT10S', 'NIDB-ZKOL_257': 'PT30S'}, 'R': 30, 'section_marker': 'TW20', 'sequence_number': 180}
# Adding Edge from (180->185) to (185->190) with sequence number 185
# {'penalty': None, 'minimum_running_time': 'PT22S', 'resource_occupations': {'NIDB_N94': 'PT10S', 'NIDB_N13': 'PT10S', 'NIDB-ZKOL_257': 'PT30S', 'NIDB-ZKOL_256': 'PT30S'}, 'R': 30, 'section_marker': 'NIDB90', 'sequence_number': 185}
# Adding Edge from (185->190) to (190->195) with sequence number 190
# {'penalty': None, 'minimum_running_time': 'PT25S', 'resource_occupations': {'NIDB_N13': 'PT10S', 'NIDB-ZKOL_257': 'PT30S', 'NIDB-ZKOL_256': 'PT30S', 'NIDB-ZKOL_255': 'PT30S'}, 'R': 30, 'section_marker': 'NIDB', 'sequence_number': 190}
# Adding Edge from (190->195) to (195->200) with sequence number 195
# {'penalty': None, 'minimum_running_time': 'PT24S', 'resource_occupations': {'NIDB-ZKOL_257': 'PT30S', 'NIDB-ZKOL_256': 'PT30S', 'NIDB-ZKOL_255': 'PT30S', 'NIDB-ZKOL_254': 'PT30S'}, 'R': 30, 'section_marker': 'NIDB70', 'sequence_number': 195}
# Adding Edge from (195->200) to (200->205) with sequence number 200
# {'penalty': None, 'minimum_running_time': 'PT20S', 'resource_occupations': {'NIDB-ZKOL_256': 'PT30S', 'NIDB-ZKOL_255': 'PT30S', 'NIDB-ZKOL_254': 'PT30S', 'NIDB-ZKOL_253': 'PT30S'}, 'R': 30, 'section_marker': 'ZBT57', 'sequence_number': 200}
# Adding Edge from (200->205) to (205->210) with sequence number 205
# {'penalty': None, 'minimum_running_time': 'PT33S', 'resource_occupations': {'NIDB-ZKOL_255': 'PT30S', 'NIDB-ZKOL_254': 'PT30S', 'NIDB-ZKOL_253': 'PT30S'}, 'R': 30, 'section_marker': 'ZBT56', 'sequence_number': 205}
# Adding Edge from (205->210) to (210->215) with sequence number 210
# {'penalty': None, 'minimum_running_time': 'PT33S', 'resource_occupations': {'NIDB-ZKOL_254': 'PT30S', 'NIDB-ZKOL_253': 'PT30S', 'ZKOL_65': 'PT10S', 'ZKOL_45': 'PT10S'}, 'R': 30, 'section_marker': 'ZBT55', 'sequence_number': 210}
# Adding Edge from (210->215) to (215->220) with sequence number 215
# {'penalty': None, 'minimum_running_time': 'PT25S', 'resource_occupations': {'NIDB-ZKOL_253': 'PT30S', 'ZKOL_65': 'PT10S', 'ZKOL_45': 'PT10S', 'ZAU_25': 'PT10S'}, 'R': 30, 'section_marker': 'ZBT54', 'sequence_number': 215}
# Adding Edge from (215->220) to (220->225) with sequence number 220
# {'penalty': None, 'minimum_running_time': 'PT27S', 'resource_occupations': {'ZKOL_65': 'PT10S', 'ZKOL_45': 'PT10S', 'ZAU_25': 'PT10S', 'ZAU_15': 'PT10S', 'ZAU_GD': 'PT10S'}, 'R': 10, 'section_marker': 'ZBT53', 'sequence_number': 220}
# Adding Edge from (220->225) to (225->230) with sequence number 225
# {'penalty': None, 'minimum_running_time': 'PT14S', 'resource_occupations': {'ZKOL_45': 'PT10S', 'ZAU_25': 'PT10S', 'ZAU_15': 'PT10S', 'ZAU_GD': 'PT10S', 'ZAU-ZUE_251': 'PT30S'}, 'R': 30, 'section_marker': 'ZKOL', 'sequence_number': 225}
# Adding Edge from (225->230) to (230->235) with sequence number 230
# {'penalty': None, 'minimum_running_time': 'PT14S', 'resource_occupations': {'ZAU_25': 'PT10S', 'ZAU_15': 'PT10S', 'ZAU_GD': 'PT10S', 'ZAU-ZUE_251': 'PT30S'}, 'R': 30, 'section_marker': 'ZKOLN', 'sequence_number': 230}
# Adding Edge from (230->235) to (235->240) with sequence number 235
# {'penalty': None, 'minimum_running_time': 'PT28S', 'resource_occupations': {'ZAU_15': 'PT10S', 'ZAU_GD': 'PT10S', 'ZAU-ZUE_251': 'PT30S', 'ZUE_L3': 'PT10S', 'ZUE_Z3': 'PT10S', 'ZUE_C2': 'PT10S', 'ZUE_W11': 'PT10S', 'ZUE_B3': 'PT10S', 'ZUE_A7-A': 'PT10S', 'ZUE_A7-B': 'PT10S'}, 'R': 30, 'section_marker': 'ZAUZBT', 'sequence_number': 235}
# Adding Edge from (235->240) to (240->245) with sequence number 240
# {'penalty': None, 'minimum_running_time': 'PT31S', 'resource_occupations': {'ZAU-ZUE_251': 'PT30S', 'ZUE_L3': 'PT10S', 'ZUE_Z3': 'PT10S', 'ZUE_C2': 'PT10S', 'ZUE_W11': 'PT10S', 'ZUE_B3': 'PT10S', 'ZUE_A7-A': 'PT10S', 'ZUE_A7-B': 'PT10S'}, 'R': 30, 'section_marker': 'ZAU', 'sequence_number': 240}
# Adding Edge from (240->245) to (245->250) with sequence number 245
# {'penalty': None, 'minimum_running_time': 'PT39S', 'resource_occupations': {'ZAU-ZUE_251': 'PT30S', 'ZUE_L3': 'PT10S', 'ZUE_Z3': 'PT10S', 'ZUE_C2': 'PT10S', 'ZUE_W11': 'PT10S', 'ZUE_B3': 'PT10S', 'ZUE_A7-A': 'PT10S', 'ZUE_A7-B': 'PT10S'}, 'R': 30, 'section_marker': 'ZUE-ZAU01', 'sequence_number': 245}
# Adding Edge from (245->250) to (250->255) with sequence number 250
# {'penalty': None, 'minimum_running_time': 'PT4S', 'resource_occupations': {'ZUE_L3': 'PT10S', 'ZUE_Z3': 'PT10S', 'ZUE_C2': 'PT10S', 'ZUE_W11': 'PT10S', 'ZUE_B3': 'PT10S', 'ZUE_A7-A': 'PT10S', 'ZUE_A7-B': 'PT10S'}, 'R': 10, 'section_marker': 'ZLST', 'sequence_number': 250}
# Adding Edge from (250->255) to (255->260) with sequence number 255
# {'penalty': None, 'minimum_running_time': 'PT32S', 'resource_occupations': {'ZUE_C2': 'PT10S', 'ZUE_W11': 'PT10S', 'ZUE_B3': 'PT10S', 'ZUE_A7-A': 'PT10S', 'ZUE_A7-B': 'PT10S'}, 'R': 10, 'section_marker': 'ZUEZSW', 'sequence_number': 255}
# Adding Edge from (255->260) to (260->265) with sequence number 260
# {'penalty': None, 'minimum_running_time': 'PT24S', 'resource_occupations': {'ZUE_A7-A': 'PT10S', 'ZUE_A7-B': 'PT10S'}, 'R': 10, 'section_marker': 'ZUEC', 'sequence_number': 260}
# Adding Edge from (260->265) to (265_end) with sequence number 265
# {'penalty': None, 'minimum_running_time': 'PT10S', 'resource_occupations': {'ZUE_A7-A': 'PT10S', 'ZUE_A7-B': 'PT10S'}, 'R': 10, 'section_marker': 'ZUE_Halt', 'start_end': 'end', 'min_stopping_time': 'PT24S', 'entry_latest': '07:51:00', 'exit_latest': '07:56:00', 'entry_delay_weight': 1, 'exit_delay_weight': 1, 'sequence_number': 265}
#
# Constructing route graph for route 2620
# new route
# Adding Edge from (1_beginning) to (1->5) with sequence number 1
# {'penalty': None, 'minimum_running_time': 'PT40S', 'resource_occupations': {'ZGSE_1': 'PT10S', 'ZG_85': 'PT10S', 'ZG_5': 'PT10S'}, 'R': 10, 'section_marker': 'ZGSE', 'start_end': 'start', 'entry_earliest': '06:25:00', 'entry_delay_weight': 1, 'exit_delay_weight': 1, 'sequence_number': 1}
# Adding Edge from (1->5) to (5->10) with sequence number 5
# {'penalty': None, 'minimum_running_time': 'PT40S', 'resource_occupations': {'ZG_85': 'PT10S', 'ZG_5': 'PT10S'}, 'R': 10, 'section_marker': 'ZG-ZGSE39', 'sequence_number': 5}
# Adding Edge from (5->10) to (10->12) with sequence number 10
# {'penalty': None, 'minimum_running_time': 'PT21S', 'resource_occupations': {'ZG_5': 'PT10S'}, 'R': 10, 'section_marker': 'ZG80', 'sequence_number': 10}
# Adding Edge from (10->12) to (12->15) with sequence number 12
# {'penalty': None, 'minimum_running_time': 'PT10S', 'resource_occupations': {'ZG_5': 'PT10S'}, 'R': 10, 'section_marker': 'ZG_Halt', 'start_end': None, 'min_stopping_time': 'PT48S', 'entry_latest': '06:30:00', 'exit_earliest': '06:31:00', 'entry_delay_weight': 1, 'sequence_number': 12}
# Adding Edge from (12->15) to (15->20) with sequence number 15
# {'penalty': None, 'minimum_running_time': 'PT1M4S', 'resource_occupations': {'ZG_W56': 'PT10S', 'ZG_43': 'PT10S', 'ZG_33': 'PT10S', 'ZG_13': 'PT10S', 'BAAL_3': 'PT10S'}, 'R': 10, 'section_marker': 'ZG', 'sequence_number': 15}
# Adding Edge from (15->20) to (20->25) with sequence number 20
# {'penalty': None, 'minimum_running_time': 'PT11S', 'resource_occupations': {'ZG_33': 'PT10S', 'ZG_13': 'PT10S', 'BAAL_3': 'PT10S', 'ZG-BAA_428': 'PT30S', 'BAAN_2': 'PT10S'}, 'R': 30, 'section_marker': 'ZG40', 'sequence_number': 20}
# Adding Edge from (20->25) to (25->30) with sequence number 25
# {'penalty': None, 'minimum_running_time': 'PT15S', 'resource_occupations': {'BAAL_3': 'PT10S', 'ZG-BAA_428': 'PT30S', 'BAAN_2': 'PT10S', 'BAA_93': 'PT10S', 'BAA_83': 'PT10S'}, 'R': 30, 'section_marker': 'ZGN', 'sequence_number': 25}
# Adding Edge from (25->30) to (30->35) with sequence number 30
# {'penalty': None, 'minimum_running_time': 'PT13S', 'resource_occupations': {'ZG-BAA_428': 'PT30S', 'BAAN_2': 'PT10S', 'BAA_93': 'PT10S', 'BAA_83': 'PT10S', 'BAA_73': 'PT10S', 'BAA_3': 'PT10S'}, 'R': 30, 'section_marker': 'BAAL', 'sequence_number': 30}
# Adding Edge from (30->35) to (35->40) with sequence number 35
# {'penalty': None, 'minimum_running_time': 'PT23S', 'resource_occupations': {'BAA_93': 'PT10S', 'BAA_83': 'PT10S', 'BAA_73': 'PT10S', 'BAA_3': 'PT10S', 'BAA_63': 'PT10S', 'BAA-LITT_425': 'PT30S'}, 'R': 30, 'section_marker': 'BAAN', 'sequence_number': 35}
# Adding Edge from (35->40) to (40->45) with sequence number 40
# {'penalty': None, 'minimum_running_time': 'PT11S', 'resource_occupations': {'BAA_83': 'PT10S', 'BAA_73': 'PT10S', 'BAA_3': 'PT10S', 'BAA_63': 'PT10S', 'BAA-LITT_425': 'PT30S'}, 'R': 30, 'section_marker': 'BAA90', 'sequence_number': 40}
# Adding Edge from (40->45) to (45->50) with sequence number 45
# {'penalty': None, 'minimum_running_time': 'PT9S', 'resource_occupations': {'BAA_73': 'PT10S', 'BAA_3': 'PT10S', 'BAA_63': 'PT10S', 'BAA-LITT_425': 'PT30S', 'LITT_91': 'PT10S', 'LITT_61': 'PT10S'}, 'R': 30, 'section_marker': 'BAA80', 'sequence_number': 45}
# Adding Edge from (45->50) to (50->55) with sequence number 50
# {'penalty': None, 'minimum_running_time': 'PT8S', 'resource_occupations': {'BAA_3': 'PT10S', 'BAA_63': 'PT10S', 'BAA-LITT_425': 'PT30S', 'LITT_91': 'PT10S', 'LITT_61': 'PT10S'}, 'R': 30, 'section_marker': 'BAA70', 'sequence_number': 50}
# Adding Edge from (50->55) to (55->60) with sequence number 55
# {'penalty': None, 'minimum_running_time': 'PT13S', 'resource_occupations': {'BAA_63': 'PT10S', 'BAA-LITT_425': 'PT30S', 'LITT_91': 'PT10S', 'LITT_61': 'PT10S', 'LITT_1': 'PT10S'}, 'R': 30, 'section_marker': 'BAA', 'sequence_number': 55}
# Adding Edge from (55->60) to (60->65) with sequence number 60
# {'penalty': None, 'minimum_running_time': 'PT20S', 'resource_occupations': {'BAA-LITT_425': 'PT30S', 'LITT_91': 'PT10S', 'LITT_61': 'PT10S', 'LITT_1': 'PT10S', 'LITT_11': 'PT10S'}, 'R': 30, 'section_marker': 'BAA60', 'sequence_number': 60}
# Adding Edge from (60->65) to (65->70) with sequence number 65
# {'penalty': None, 'minimum_running_time': 'PT22S', 'resource_occupations': {'LITT_91': 'PT10S', 'LITT_61': 'PT10S', 'LITT_1': 'PT10S', 'LITT_11': 'PT10S', 'SBG-LITT_424': 'PT30S'}, 'R': 30, 'section_marker': 'LITT-BAA25', 'sequence_number': 65}
# Adding Edge from (65->70) to (70->75) with sequence number 70
# {'penalty': None, 'minimum_running_time': 'PT27S', 'resource_occupations': {'LITT_1': 'PT10S', 'LITT_11': 'PT10S', 'SBG-LITT_424': 'PT30S', 'SBG-LITT_422': 'PT30S'}, 'R': 30, 'section_marker': 'LITTS', 'sequence_number': 70}
# Adding Edge from (70->75) to (75->80) with sequence number 75
# {'penalty': None, 'minimum_running_time': 'PT29S', 'resource_occupations': {'LITT_11': 'PT10S', 'SBG-LITT_424': 'PT30S', 'SBG-LITT_422': 'PT30S'}, 'R': 30, 'section_marker': 'LITT', 'sequence_number': 75}
# Adding Edge from (75->80) to (80->85) with sequence number 80
# {'penalty': None, 'minimum_running_time': 'PT26S', 'resource_occupations': {'SBG-LITT_424': 'PT30S', 'SBG-LITT_422': 'PT30S', 'SBG-LITT_421': 'PT30S', 'SBG-LITT_420': 'PT30S'}, 'R': 30, 'section_marker': 'LITTN', 'sequence_number': 80}
# Adding Edge from (80->85) to (85->90) with sequence number 85
# {'penalty': None, 'minimum_running_time': 'PT28S', 'resource_occupations': {'SBG-LITT_422': 'PT30S', 'SBG-LITT_421': 'PT30S', 'SBG-LITT_420': 'PT30S', 'SBG_94': 'PT10S', 'SBG_3': 'PT10S'}, 'R': 30, 'section_marker': 'SBG-LITT24', 'sequence_number': 85}
# Adding Edge from (85->90) to (90->95) with sequence number 90
# {'penalty': None, 'minimum_running_time': 'PT26S', 'resource_occupations': {'SBG-LITT_421': 'PT30S', 'SBG-LITT_420': 'PT30S', 'SBG_94': 'PT10S', 'SBG_3': 'PT10S', 'SBG_33': 'PT10S'}, 'R': 30, 'section_marker': 'SBG-LITT22', 'sequence_number': 90}
# Adding Edge from (90->95) to (95->100) with sequence number 95
# {'penalty': None, 'minimum_running_time': 'PT30S', 'resource_occupations': {'SBG_94': 'PT10S', 'SBG_3': 'PT10S', 'SBG_33': 'PT10S', 'SBG_14': 'PT10S'}, 'R': 10, 'section_marker': 'SBG-LITT20', 'sequence_number': 95}
# Adding Edge from (95->100) to (100->105) with sequence number 100
# {'penalty': None, 'minimum_running_time': 'PT16S', 'resource_occupations': {'SBG_3': 'PT10S', 'SBG_33': 'PT10S', 'SBG_14': 'PT10S', 'HGO-SBG_418': 'PT30S'}, 'R': 30, 'section_marker': 'SBGS', 'sequence_number': 100}
# Adding Edge from (100->105) to (105->110) with sequence number 105
# {'penalty': None, 'minimum_running_time': 'PT22S', 'resource_occupations': {'SBG_33': 'PT10S', 'SBG_14': 'PT10S', 'HGO-SBG_418': 'PT30S'}, 'R': 30, 'section_marker': 'SBG', 'sequence_number': 105}
# Adding Edge from (105->110) to (110->115) with sequence number 110
# {'penalty': None, 'minimum_running_time': 'PT12S', 'resource_occupations': {'SBG_14': 'PT10S', 'HGO-SBG_418': 'PT30S', 'HGO-SBG_417': 'PT30S', 'HGO-SBG_416': 'PT30S'}, 'R': 30, 'section_marker': 'SBG30', 'sequence_number': 110}
# Adding Edge from (110->115) to (115->120) with sequence number 115
# {'penalty': None, 'minimum_running_time': 'PT35S', 'resource_occupations': {'HGO-SBG_418': 'PT30S', 'HGO-SBG_417': 'PT30S', 'HGO-SBG_416': 'PT30S', 'HGO_94': 'PT10S', 'HGO_74': 'PT10S', 'HGO_4': 'PT10S'}, 'R': 30, 'section_marker': 'SBG10', 'sequence_number': 115}
# Adding Edge from (115->120) to (120->125) with sequence number 120
# {'penalty': None, 'minimum_running_time': 'PT27S', 'resource_occupations': {'HGO-SBG_417': 'PT30S', 'HGO-SBG_416': 'PT30S', 'HGO_94': 'PT10S', 'HGO_74': 'PT10S', 'HGO_4': 'PT10S', 'HGO_24': 'PT10S', 'HGO-ORDD_415': 'PT30S'}, 'R': 30, 'section_marker': 'HGO-SBG18', 'sequence_number': 120}
# Adding Edge from (120->125) to (125->130) with sequence number 125
# {'penalty': None, 'minimum_running_time': 'PT34S', 'resource_occupations': {'HGO_94': 'PT10S', 'HGO_74': 'PT10S', 'HGO_4': 'PT10S', 'HGO_24': 'PT10S', 'HGO-ORDD_415': 'PT30S', 'HGO-ORDD_414': 'PT30S'}, 'R': 30, 'section_marker': 'HGO-SBG16', 'sequence_number': 125}
# Adding Edge from (125->130) to (130->135) with sequence number 130
# {'penalty': None, 'minimum_running_time': 'PT16S', 'resource_occupations': {'HGO_4': 'PT10S', 'HGO_24': 'PT10S', 'HGO-ORDD_415': 'PT30S', 'HGO-ORDD_414': 'PT30S'}, 'R': 30, 'section_marker': 'HGOO', 'sequence_number': 130}
# Adding Edge from (130->135) to (135->140) with sequence number 135
# {'penalty': None, 'minimum_running_time': 'PT20S', 'resource_occupations': {'HGO_24': 'PT10S', 'HGO-ORDD_415': 'PT30S', 'HGO-ORDD_414': 'PT30S', 'ORDD_1': 'PT10S'}, 'R': 30, 'section_marker': 'HGO', 'sequence_number': 135}
# Adding Edge from (135->140) to (140->145) with sequence number 140
# {'penalty': None, 'minimum_running_time': 'PT12S', 'resource_occupations': {'HGO-ORDD_415': 'PT30S', 'HGO-ORDD_414': 'PT30S', 'ORDD_1': 'PT10S'}, 'R': 30, 'section_marker': 'HGOW', 'sequence_number': 140}
# Adding Edge from (140->145) to (145->150) with sequence number 145
# {'penalty': None, 'minimum_running_time': 'PT15S', 'resource_occupations': {'HGO-ORDD_414': 'PT30S', 'ORDD_1': 'PT10S', 'ORDD-TW_412': 'PT30S', 'ORDD-TW_411': 'PT30S'}, 'R': 30, 'section_marker': 'ORDD-HGO15', 'sequence_number': 145}
# Adding Edge from (145->150) to (150->155) with sequence number 150
# {'penalty': None, 'minimum_running_time': 'PT27S', 'resource_occupations': {'ORDD_1': 'PT10S', 'ORDD-TW_412': 'PT30S', 'ORDD-TW_411': 'PT30S', 'TW_85': 'PT10S', 'TW_55': 'PT10S', 'TW_5': 'PT10S'}, 'R': 30, 'section_marker': 'ORDD-HGO14', 'sequence_number': 150}
# Adding Edge from (150->155) to (155->160) with sequence number 155
# {'penalty': None, 'minimum_running_time': 'PT30S', 'resource_occupations': {'ORDD-TW_412': 'PT30S', 'ORDD-TW_411': 'PT30S', 'TW_85': 'PT10S', 'TW_55': 'PT10S', 'TW_5': 'PT10S'}, 'R': 30, 'section_marker': 'ORDD', 'sequence_number': 155}
# Adding Edge from (155->160) to (160->165) with sequence number 160
# {'penalty': None, 'minimum_running_time': 'PT53S', 'resource_occupations': {'TW_85': 'PT10S', 'TW_55': 'PT10S', 'TW_5': 'PT10S'}, 'R': 10, 'section_marker': 'TW-ORDD12', 'sequence_number': 160}
# Adding Edge from (160->165) to (165->167) with sequence number 165
# {'penalty': None, 'minimum_running_time': 'PT38S', 'resource_occupations': {'TW_5': 'PT10S'}, 'R': 10, 'section_marker': 'TWO', 'sequence_number': 165}
# Adding Edge from (165->167) to (167->170) with sequence number 167
# {'penalty': None, 'minimum_running_time': 'PT10S', 'resource_occupations': {'TW_5': 'PT10S'}, 'R': 10, 'section_marker': 'TW_Halt', 'start_end': None, 'min_stopping_time': 'PT48S', 'entry_latest': '06:46:00', 'exit_earliest': '06:46:00', 'entry_delay_weight': 1, 'sequence_number': 167}
# Adding Edge from (167->170) to (170->175) with sequence number 170
# {'penalty': None, 'minimum_running_time': 'PT54S', 'resource_occupations': {'TW_45': 'PT10S', 'TW_26': 'PT10S', 'TW_25': 'PT10S', 'TW-NIDB_258': 'PT30S'}, 'R': 30, 'section_marker': 'TW', 'sequence_number': 170}
# Adding Edge from (170->175) to (175->180) with sequence number 175
# {'penalty': None, 'minimum_running_time': 'PT19S', 'resource_occupations': {'TW_25': 'PT10S', 'TW-NIDB_258': 'PT30S', 'NIDB_N94': 'PT10S', 'NIDB_N13': 'PT10S'}, 'R': 30, 'section_marker': 'TWNO', 'sequence_number': 175}
# Adding Edge from (175->180) to (180->185) with sequence number 180
# {'penalty': None, 'minimum_running_time': 'PT16S', 'resource_occupations': {'TW-NIDB_258': 'PT30S', 'NIDB_N94': 'PT10S', 'NIDB_N13': 'PT10S', 'NIDB-ZKOL_257': 'PT30S'}, 'R': 30, 'section_marker': 'TW20', 'sequence_number': 180}
# Adding Edge from (180->185) to (185->190) with sequence number 185
# {'penalty': None, 'minimum_running_time': 'PT20S', 'resource_occupations': {'NIDB_N94': 'PT10S', 'NIDB_N13': 'PT10S', 'NIDB-ZKOL_257': 'PT30S', 'NIDB-ZKOL_256': 'PT30S'}, 'R': 30, 'section_marker': 'NIDB90', 'sequence_number': 185}
# Adding Edge from (185->190) to (190->195) with sequence number 190
# {'penalty': None, 'minimum_running_time': 'PT26S', 'resource_occupations': {'NIDB_N13': 'PT10S', 'NIDB-ZKOL_257': 'PT30S', 'NIDB-ZKOL_256': 'PT30S', 'NIDB-ZKOL_255': 'PT30S'}, 'R': 30, 'section_marker': 'NIDB', 'sequence_number': 190}
# Adding Edge from (190->195) to (195->200) with sequence number 195
# {'penalty': None, 'minimum_running_time': 'PT24S', 'resource_occupations': {'NIDB-ZKOL_257': 'PT30S', 'NIDB-ZKOL_256': 'PT30S', 'NIDB-ZKOL_255': 'PT30S', 'NIDB-ZKOL_254': 'PT30S'}, 'R': 30, 'section_marker': 'NIDB70', 'sequence_number': 195}
# Adding Edge from (195->200) to (200->205) with sequence number 200
# {'penalty': None, 'minimum_running_time': 'PT20S', 'resource_occupations': {'NIDB-ZKOL_256': 'PT30S', 'NIDB-ZKOL_255': 'PT30S', 'NIDB-ZKOL_254': 'PT30S', 'NIDB-ZKOL_253': 'PT30S'}, 'R': 30, 'section_marker': 'ZBT57', 'sequence_number': 200}
# Adding Edge from (200->205) to (205->210) with sequence number 205
# {'penalty': None, 'minimum_running_time': 'PT34S', 'resource_occupations': {'NIDB-ZKOL_255': 'PT30S', 'NIDB-ZKOL_254': 'PT30S', 'NIDB-ZKOL_253': 'PT30S'}, 'R': 30, 'section_marker': 'ZBT56', 'sequence_number': 205}
# Adding Edge from (205->210) to (210->215) with sequence number 210
# {'penalty': None, 'minimum_running_time': 'PT34S', 'resource_occupations': {'NIDB-ZKOL_254': 'PT30S', 'NIDB-ZKOL_253': 'PT30S', 'ZKOL_65': 'PT10S', 'ZKOL_45': 'PT10S'}, 'R': 30, 'section_marker': 'ZBT55', 'sequence_number': 210}
# Adding Edge from (210->215) to (215->220) with sequence number 215
# {'penalty': None, 'minimum_running_time': 'PT26S', 'resource_occupations': {'NIDB-ZKOL_253': 'PT30S', 'ZKOL_65': 'PT10S', 'ZKOL_45': 'PT10S', 'ZAU_25': 'PT10S'}, 'R': 30, 'section_marker': 'ZBT54', 'sequence_number': 215}
# Adding Edge from (215->220) to (220->225) with sequence number 220
# {'penalty': None, 'minimum_running_time': 'PT26S', 'resource_occupations': {'ZKOL_65': 'PT10S', 'ZKOL_45': 'PT10S', 'ZAU_25': 'PT10S', 'ZAU_15': 'PT10S', 'ZAU_GD': 'PT10S'}, 'R': 10, 'section_marker': 'ZBT53', 'sequence_number': 220}
# Adding Edge from (220->225) to (225->230) with sequence number 225
# ...
# Adding Edge from (477->480) to (480->485) with sequence number 480
# {'penalty': None, 'minimum_running_time': 'PT1M16S', 'resource_occupations': {'MG-UNT_220': 'PT30S', 'UNT_82': 'PT10S', 'UNT_2': 'PT10S'}, 'R': 30, 'section_marker': 'MG', 'sequence_number': 480}
# Adding Edge from (480->485) to (485->490) with sequence number 485
# {'penalty': None, 'minimum_running_time': 'PT46S', 'resource_occupations': {'UNT_82': 'PT10S', 'UNT_2': 'PT10S'}, 'R': 10, 'section_marker': 'MG-UNT20', 'sequence_number': 485}
# Adding Edge from (485->490) to (490->492) with sequence number 490
# {'penalty': None, 'minimum_running_time': 'PT30S', 'resource_occupations': {'UNT_2': 'PT10S'}, 'R': 10, 'section_marker': 'UNTW', 'sequence_number': 490}
# Adding Edge from (490->492) to (492->495) with sequence number 492
# {'penalty': None, 'minimum_running_time': 'PT10S', 'resource_occupations': {'UNT_2': 'PT10S'}, 'R': 10, 'section_marker': 'UNT_Halt', 'start_end': None, 'min_stopping_time': 'PT24S', 'exit_earliest': '07:41:00', 'exit_delay_weight': 1, 'sequence_number': 492}
# Adding Edge from (492->495) to (495->500) with sequence number 495
# {'penalty': None, 'minimum_running_time': 'PT44S', 'resource_occupations': {'UNT_22': 'PT10S', 'UNT-MOLS_215': 'PT30S', 'MOLS_2': 'PT10S'}, 'R': 30, 'section_marker': 'UNT', 'sequence_number': 495}
# Adding Edge from (495->500) to (500->502) with sequence number 500
# {'penalty': None, 'minimum_running_time': 'PT14S', 'resource_occupations': {'UNT-MOLS_215': 'PT30S', 'MOLS_2': 'PT10S'}, 'R': 30, 'section_marker': 'UNTO', 'sequence_number': 500}
# Adding Edge from (500->502) to (502->505) with sequence number 502
# {'penalty': None, 'minimum_running_time': 'PT10S', 'resource_occupations': {'UNT-MOLS_215': 'PT30S', 'MOLS_2': 'PT10S'}, 'R': 30, 'section_marker': 'MOLS_Halt', 'start_end': None, 'min_stopping_time': 'PT24S', 'exit_earliest': '07:43:00', 'exit_delay_weight': 1, 'sequence_number': 502}
# Adding Edge from (502->505) to (505->510) with sequence number 505
# {'penalty': None, 'minimum_running_time': 'PT1M3S', 'resource_occupations': {'MOLS-WAL_214': 'PT30S', 'WAL_83': 'PT10S', 'WAL_3': 'PT10S'}, 'R': 30, 'section_marker': 'MOLS', 'sequence_number': 505}
# Adding Edge from (505->510) to (510->515) with sequence number 510
# {'penalty': None, 'minimum_running_time': 'PT1M10S', 'resource_occupations': {'WAL_83': 'PT10S', 'WAL_3': 'PT10S', 'WAL_23': 'PT10S', 'WAL-FMS_212': 'PT30S'}, 'R': 30, 'section_marker': 'MOLS-WAL14', 'sequence_number': 510}
# Adding Edge from (510->515) to (515->517) with sequence number 515
# {'penalty': None, 'minimum_running_time': 'PT17S', 'resource_occupations': {'WAL_3': 'PT10S', 'WAL_23': 'PT10S', 'WAL-FMS_212': 'PT30S'}, 'R': 30, 'section_marker': 'WALW', 'sequence_number': 515}
# Adding Edge from (515->517) to (517->520) with sequence number 517
# {'penalty': None, 'minimum_running_time': 'PT10S', 'resource_occupations': {'WAL_3': 'PT10S', 'WAL_23': 'PT10S', 'WAL-FMS_212': 'PT30S'}, 'R': 30, 'section_marker': 'WAL_Halt', 'start_end': None, 'min_stopping_time': 'PT24S', 'exit_earliest': '07:46:00', 'exit_delay_weight': 1, 'sequence_number': 517}
# Adding Edge from (517->520) to (520->525) with sequence number 520
# {'penalty': None, 'minimum_running_time': 'PT1M4S', 'resource_occupations': {'WAL_23': 'PT10S', 'WAL-FMS_212': 'PT30S'}, 'R': 30, 'section_marker': 'WAL', 'sequence_number': 520}
# Adding Edge from (520->525) to (525->530) with sequence number 525
# {'penalty': None, 'minimum_running_time': 'PT10S', 'resource_occupations': {'WAL-FMS_212': 'PT30S', 'FMS_84': 'PT10S', 'FMS_4': 'PT10S'}, 'R': 30, 'section_marker': 'WALO', 'sequence_number': 525}
# Adding Edge from (525->530) to (530->535) with sequence number 530
# {'penalty': None, 'minimum_running_time': 'PT55S', 'resource_occupations': {'FMS_84': 'PT10S', 'FMS_4': 'PT10S'}, 'R': 10, 'section_marker': 'WAL-FMS12', 'sequence_number': 530}
# Adding Edge from (530->535) to (535->537) with sequence number 535
# {'penalty': None, 'minimum_running_time': 'PT18S', 'resource_occupations': {'FMS_4': 'PT10S'}, 'R': 10, 'section_marker': 'FMSW', 'sequence_number': 535}
# Adding Edge from (535->537) to (537->540) with sequence number 537
# {'penalty': None, 'minimum_running_time': 'PT10S', 'resource_occupations': {'FMS_4': 'PT10S'}, 'R': 10, 'section_marker': 'FMS_Halt', 'start_end': None, 'min_stopping_time': 'PT24S', 'exit_earliest': '07:50:00', 'exit_delay_weight': 1, 'sequence_number': 537}
# Adding Edge from (537->540) to (540->545) with sequence number 540
# {'penalty': None, 'minimum_running_time': 'PT1M5S', 'resource_occupations': {'FMS_24': 'PT10S', 'FMS-MELS_208': 'PT30S', 'FMS-MELS_204': 'PT30S'}, 'R': 30, 'section_marker': 'FMS', 'sequence_number': 540}
# Adding Edge from (540->545) to (545->550) with sequence number 545
# {'penalty': None, 'minimum_running_time': 'PT7S', 'resource_occupations': {'FMS-MELS_208': 'PT30S', 'FMS-MELS_204': 'PT30S'}, 'R': 30, 'section_marker': 'FMSO', 'sequence_number': 545}
# Adding Edge from (545->550) to (550->555) with sequence number 550
# {'penalty': None, 'minimum_running_time': 'PT1M6S', 'resource_occupations': {'FMS-MELS_204': 'PT30S', 'MELS_74': 'PT10S', 'MELS_4': 'PT10S'}, 'R': 30, 'section_marker': 'FMS-MELS08', 'sequence_number': 550}
# Adding Edge from (550->555) to (555->560) with sequence number 555
# {'penalty': None, 'minimum_running_time': 'PT1M24S', 'resource_occupations': {'MELS_74': 'PT10S', 'MELS_4': 'PT10S'}, 'R': 10, 'section_marker': 'FMS-MELS04', 'sequence_number': 555}
# Adding Edge from (555->560) to (560->562) with sequence number 560
# {'penalty': None, 'minimum_running_time': 'PT16S', 'resource_occupations': {'MELS_4': 'PT10S'}, 'R': 10, 'section_marker': 'MELSW', 'sequence_number': 560}
# Adding Edge from (560->562) to (562->565) with sequence number 562
# {'penalty': None, 'minimum_running_time': 'PT10S', 'resource_occupations': {'MELS_4': 'PT10S'}, 'R': 10, 'section_marker': 'MELS_Halt', 'start_end': None, 'min_stopping_time': 'PT24S', 'exit_earliest': '07:54:00', 'exit_delay_weight': 1, 'sequence_number': 562}
# Adding Edge from (562->565) to (565->570) with sequence number 565
# {'penalty': None, 'minimum_running_time': 'PT1M', 'resource_occupations': {'MELS_24': 'PT10S', 'MELS-SA_201': 'PT30S'}, 'R': 30, 'section_marker': 'MELS', 'sequence_number': 565}
# Adding Edge from (565->570) to (570->575) with sequence number 570
# {'penalty': None, 'minimum_running_time': 'PT8S', 'resource_occupations': {'MELS-SA_201': 'PT30S', 'SA_82': 'PT10S', 'SA_5': 'PT10S'}, 'R': 30, 'section_marker': 'MELSO', 'sequence_number': 570}
# Adding Edge from (570->575) to (575->580) with sequence number 575
# {'penalty': None, 'minimum_running_time': 'PT34S', 'resource_occupations': {'SA_82': 'PT10S', 'SA_5': 'PT10S'}, 'R': 10, 'section_marker': 'MELS-SA01', 'sequence_number': 575}
# Adding Edge from (575->580) to (580->585) with sequence number 580
# {'penalty': None, 'minimum_running_time': 'PT17S', 'resource_occupations': {'SA_5': 'PT10S'}, 'R': 10, 'section_marker': 'SAW', 'sequence_number': 580}
# Adding Edge from (580->585) to (585_end) with sequence number 585
# {'penalty': None, 'minimum_running_time': 'PT10S', 'resource_occupations': {'SA_5': 'PT10S'}, 'R': 10, 'section_marker': 'SA_Halt', 'start_end': 'end', 'min_stopping_time': 'PT48S', 'entry_latest': '07:59:00', 'exit_latest': '08:03:00', 'entry_delay_weight': 1, 'exit_delay_weight': 1, 'sequence_number': 585}
#
# Constructing route graph for route 23617
# new route
# Adding Edge from (315_beginning) to (315->320) with sequence number 315
# {'penalty': None, 'minimum_running_time': 'PT10S', 'resource_occupations': {'UZ_2': 'PT10S'}, 'R': 10, 'section_marker': 'UZ_Halt', 'start_end': 'start', 'min_stopping_time': 'PT24S', 'entry_earliest': '06:44:00', 'exit_earliest': '06:46:00', 'entry_delay_weight': 1, 'exit_delay_weight': 1, 'sequence_number': 315}
# Adding Edge from (315->320) to (320->325) with sequence number 320
# {'penalty': None, 'minimum_running_time': 'PT22S', 'resource_occupations': {'SCAE-ZB_735': 'PT30S'}, 'R': 30, 'section_marker': 'UZ', 'sequence_number': 320}
# Adding Edge from (320->325) to (325->330) with sequence number 325
# {'penalty': None, 'minimum_running_time': 'PT10S', 'resource_occupations': {'SCAE-ZB_735': 'PT30S'}, 'R': 30, 'section_marker': 'BNK_Halt', 'start_end': None, 'min_stopping_time': 'PT24S', 'exit_earliest': '06:48:00', 'exit_delay_weight': 1, 'sequence_number': 325}
# Adding Edge from (325->330) to (330->335) with sequence number 330
# {'penalty': None, 'minimum_running_time': 'PT2M31S', 'resource_occupations': {'SCAE-ZB_735': 'PT30S'}, 'R': 30, 'section_marker': 'BNK', 'sequence_number': 330}
# Adding Edge from (330->335) to (335->340) with sequence number 335
# {'penalty': None, 'minimum_running_time': 'PT1M43S', 'resource_occupations': {'SCAE-ZB_735': 'PT30S'}, 'R': 30, 'section_marker': 'BNK-SCAE01', 'sequence_number': 335}
# Adding Edge from (335->340) to (340->345) with sequence number 340
# {'penalty': None, 'minimum_running_time': 'PT1M24S', 'resource_occupations': {'SCAE-ZB_735': 'PT30S'}, 'R': 30, 'section_marker': 'BNK-SCAE02', 'sequence_number': 340}
# Adding Edge from (340->345) to (345->350) with sequence number 345
# {'penalty': None, 'minimum_running_time': 'PT10S', 'resource_occupations': {'SCAE-ZB_735': 'PT30S'}, 'R': 30, 'section_marker': 'SCAE_Halt', 'start_end': None, 'min_stopping_time': 'PT24S', 'exit_earliest': '06:52:00', 'exit_delay_weight': 1, 'sequence_number': 345}
# Adding Edge from (345->350) to (350->355) with sequence number 350
# {'penalty': None, 'minimum_running_time': 'PT1M4S', 'resource_occupations': {'SCAE-ZB_735': 'PT30S'}, 'R': 30, 'section_marker': 'SCAE', 'sequence_number': 350}
# Adding Edge from (350->355) to (355->400) with sequence number 355
# {'penalty': None, 'minimum_running_time': 'PT1M2S', 'resource_occupations': {'ZB_40': 'PT10S', 'ZB_10': 'PT10S', 'ZB_60': 'PT10S'}, 'R': 10, 'section_marker': 'SCAE-ZB01', 'sequence_number': 355}
# Adding Edge from (355->400) to (400->402) with sequence number 400
# {'penalty': None, 'minimum_running_time': 'PT1M7S', 'resource_occupations': {'ZB_10': 'PT10S', 'ZB_60': 'PT10S'}, 'R': 10, 'section_marker': 'ZBW', 'sequence_number': 400}
# Adding Edge from (400->402) to (402->405) with sequence number 402
# {'penalty': None, 'minimum_running_time': 'PT10S', 'resource_occupations': {'ZB_10': 'PT10S', 'ZB_60': 'PT10S'}, 'R': 10, 'section_marker': 'ZB_Halt', 'start_end': None, 'min_stopping_time': 'PT48S', 'entry_latest': '06:59:00', 'exit_earliest': '07:03:00', 'entry_delay_weight': 1, 'exit_delay_weight': 1, 'sequence_number': 402}
# Adding Edge from (402->405) to (405->410) with sequence number 405
# {'penalty': None, 'minimum_running_time': 'PT1M6S', 'resource_occupations': {'ZB_89': 'PT10S', 'ZB_86': 'PT10S', 'ZB_75': 'PT10S', 'ZB-NOU_557': 'PT30S'}, 'R': 30, 'section_marker': 'ZB', 'sequence_number': 405}
# Adding Edge from (405->410) to (410->415) with sequence number 410
# {'penalty': None, 'minimum_running_time': 'PT27S', 'resource_occupations': {'ZB-NOU_557': 'PT30S'}, 'R': 30, 'section_marker': 'ZBO', 'sequence_number': 410}
# Adding Edge from (410->415) to (415->420) with sequence number 415
# {'penalty': None, 'minimum_running_time': 'PT24S', 'resource_occupations': {'ZB-NOU_557': 'PT30S'}, 'R': 30, 'section_marker': 'ZB-NOU57', 'sequence_number': 415}
# Adding Edge from (415->420) to (420_end) with sequence number 420
# {'penalty': None, 'minimum_running_time': 'PT10S', 'resource_occupations': {'ZB-NOU_557': 'PT30S'}, 'R': 30, 'section_marker': 'NOU', 'start_end': 'end', 'min_stopping_time': 'PT24S', 'entry_latest': '07:07:00', 'exit_latest': '07:08:00', 'entry_delay_weight': 1, 'exit_delay_weight': 1, 'sequence_number': 420}
#
# Constructing route graph for route 23621
# new route
# Adding Edge from (315_beginning) to (315->320) with sequence number 315
# {'penalty': None, 'minimum_running_time': 'PT10S', 'resource_occupations': {'UZ_2': 'PT10S'}, 'R': 10, 'section_marker': 'UZ_Halt', 'start_end': 'start', 'min_stopping_time': 'PT24S', 'entry_earliest': '07:44:00', 'exit_earliest': '07:46:00', 'entry_delay_weight': 1, 'exit_delay_weight': 1, 'sequence_number': 315}
# Adding Edge from (315->320) to (320->325) with sequence number 320
# {'penalty': None, 'minimum_running_time': 'PT22S', 'resource_occupations': {'SCAE-ZB_735': 'PT30S'}, 'R': 30, 'section_marker': 'UZ', 'sequence_number': 320}
# Adding Edge from (320->325) to (325->330) with sequence number 325
# {'penalty': None, 'minimum_running_time': 'PT10S', 'resource_occupations': {'SCAE-ZB_735': 'PT30S'}, 'R': 30, 'section_marker': 'BNK_Halt', 'start_end': None, 'min_stopping_time': 'PT24S', 'exit_earliest': '07:48:00', 'exit_delay_weight': 1, 'sequence_number': 325}
# Adding Edge from (325->330) to (330->335) with sequence number 330
# {'penalty': None, 'minimum_running_time': 'PT2M31S', 'resource_occupations': {'SCAE-ZB_735': 'PT30S'}, 'R': 30, 'section_marker': 'BNK', 'sequence_number': 330}
# Adding Edge from (330->335) to (335->340) with sequence number 335
# {'penalty': None, 'minimum_running_time': 'PT1M43S', 'resource_occupations': {'SCAE-ZB_735': 'PT30S'}, 'R': 30, 'section_marker': 'BNK-SCAE01', 'sequence_number': 335}
# Adding Edge from (335->340) to (340->345) with sequence number 340
# {'penalty': None, 'minimum_running_time': 'PT1M24S', 'resource_occupations': {'SCAE-ZB_735': 'PT30S'}, 'R': 30, 'section_marker': 'BNK-SCAE02', 'sequence_number': 340}
# Adding Edge from (340->345) to (345->350) with sequence number 345
# {'penalty': None, 'minimum_running_time': 'PT10S', 'resource_occupations': {'SCAE-ZB_735': 'PT30S'}, 'R': 30, 'section_marker': 'SCAE_Halt', 'start_end': None, 'min_stopping_time': 'PT24S', 'exit_earliest': '07:52:00', 'exit_delay_weight': 1, 'sequence_number': 345}
# Adding Edge from (345->350) to (350->355) with sequence number 350
# {'penalty': None, 'minimum_running_time': 'PT1M4S', 'resource_occupations': {'SCAE-ZB_735': 'PT30S'}, 'R': 30, 'section_marker': 'SCAE', 'sequence_number': 350}
# Adding Edge from (350->355) to (355->400) with sequence number 355
# {'penalty': None, 'minimum_running_time': 'PT1M2S', 'resource_occupations': {'ZB_40': 'PT10S', 'ZB_10': 'PT10S', 'ZB_60': 'PT10S'}, 'R': 10, 'section_marker': 'SCAE-ZB01', 'sequence_number': 355}
# Adding Edge from (355->400) to (400->402) with sequence number 400
# {'penalty': None, 'minimum_running_time': 'PT1M7S', 'resource_occupations': {'ZB_10': 'PT10S', 'ZB_60': 'PT10S'}, 'R': 10, 'section_marker': 'ZBW', 'sequence_number': 400}
# Adding Edge from (400->402) to (402->405) with sequence number 402
# {'penalty': None, 'minimum_running_time': 'PT10S', 'resource_occupations': {'ZB_10': 'PT10S', 'ZB_60': 'PT10S'}, 'R': 10, 'section_marker': 'ZB_Halt', 'start_end': None, 'min_stopping_time': 'PT48S', 'entry_latest': '07:59:00', 'exit_earliest': '08:03:00', 'entry_delay_weight': 1, 'exit_delay_weight': 1, 'sequence_number': 402}
# Adding Edge from (402->405) to (405->410) with sequence number 405
# {'penalty': None, 'minimum_running_time': 'PT1M6S', 'resource_occupations': {'ZB_89': 'PT10S', 'ZB_86': 'PT10S', 'ZB_75': 'PT10S', 'ZB-NOU_557': 'PT30S'}, 'R': 30, 'section_marker': 'ZB', 'sequence_number': 405}
# Adding Edge from (405->410) to (410->415) with sequence number 410
# {'penalty': None, 'minimum_running_time': 'PT27S', 'resource_occupations': {'ZB-NOU_557': 'PT30S'}, 'R': 30, 'section_marker': 'ZBO', 'sequence_number': 410}
# Adding Edge from (410->415) to (415->420) with sequence number 415
# {'penalty': None, 'minimum_running_time': 'PT24S', 'resource_occupations': {'ZB-NOU_557': 'PT30S'}, 'R': 30, 'section_marker': 'ZB-NOU57', 'sequence_number': 415}
# Adding Edge from (415->420) to (420_end) with sequence number 420
# {'penalty': None, 'minimum_running_time': 'PT10S', 'resource_occupations': {'ZB-NOU_557': 'PT30S'}, 'R': 30, 'section_marker': 'NOU', 'start_end': 'end', 'min_stopping_time': 'PT24S', 'entry_latest': '08:07:00', 'exit_latest': '08:08:00', 'entry_delay_weight': 1, 'exit_delay_weight': 1, 'sequence_number': 420}
# Finished building fahrweg-graphen in 1.1753747463226318 seconds

# %%
Lats = {}
for si in route_graphs:
    Latins = {}
    Latouts = {}
    for e in route_graphs[si].edges(data=True):
        if 'entry_latest' in e[2]['edge_data']:
            Latins[f'{e[0]},{e[1]}'] = e[2]['edge_data']['entry_latest']
        if 'exit_latest' in e[2]['edge_data']:
            Latouts[f'{e[0]},{e[1]}'] = e[2]['edge_data']['exit_latest']
        Lats[si] = {'LatIn': None, 'LatOut':None}
        Lats[si]['LatIn'] = Latins
        Lats[si]['LatOut'] = Latouts

# %% [markdown]
# ### Draw Graphs

# %% [markdown]
# for route in route_graphs:
#     route_graph = route_graphs[route]
#
#     """
#     for node in route_graph.nodes():
#         route_graph.node[node]['label'] = node
#
#     edge_labels = {}
#     for node1, node2, data in route_graph.edges(data=True):
#         edge_labels[(node1, node2)] = data['sequence_number']
#
#     for edge in route_graph.edges():
#         route_graph.edges[edge]['label'] = edge_labels[edge]
#
#     # export as graphML file, see below
#     nx.write_graphml(route_graph, "graph-111"+".graphml")
#     """
#     edge_labels = {}
#     for node1, node2, data in route_graph.edges(data=True):
#
#         edge_labels[(node1, node2)] = data['edge_data']['sequence_number']
#
#     # draw directly from networkx
#     pos = nx.spring_layout(route_graph)
#     nx.draw(route_graph, pos, edge_color='black', width=1, linewidths=1, node_size=500, node_color='pink', alpha=0.9)
#     nx.draw_networkx_edge_labels(route_graph,pos,edge_labels=edge_labels,font_color='red')
#     plt.show()

# %% [markdown]
# ### Find all admissible routes

# %%
paths = {}
for si in service_intentions:
    startnodes=[]
    endnodes = []
    G = route_graphs[si]
    for edge in G.edges(data=True):
        if 'start_end' in edge[2]['edge_data']:
            if edge[2]['edge_data']['start_end'] == 'start':
                startnodes.append(edge[0])
            if edge[2]['edge_data']['start_end'] == 'end':
                endnodes.append(edge[1])
    paths_si = []
    for s in startnodes:
        for e in endnodes:
            for path in nx.all_simple_paths(G, source=s, target=e):
                paths_si.append([(path[i], path[i+1]) for i in range(len(path)-1)])
    paths[si] = paths_si

# %%
si_list = []
t_index_by_edge = {}
delta_index_by_edge = {}
edges_by_path = {}
get_index_by_delta = {}
j=0
k=0
for si in paths:
    pathlist = []
    ttemp = {}
    dtemp = {}
    for i,path in enumerate(paths[si]):
        srlist = []
        etemp = {}
        for sr in path:
            srlist.append((si,i,sr))
            if sr in ttemp:
                ttemp[sr].append(j)
            else:
                ttemp[sr] = [j]
            
            
            if sr in dtemp:
                dtemp[sr].append(k)
            else:
                dtemp[sr] = [k]
            
            etemp[sr] = j
            if k in get_index_by_delta:
                get_index_by_delta[k].append(j)
            else:
                get_index_by_delta[k] = [j]
            j+=1
        edges_by_path[k] = etemp
            
        k+=1
        pathlist.append(srlist)
    t_index_by_edge[si] = ttemp
    delta_index_by_edge[si] = dtemp
    si_list.append(pathlist)

# %%
xindex = {}
enum = 0
for si in service_intentions:
    xindexsi = {}
    for i,e in enumerate(route_graphs[si].edges):
        xindexsi[e] = i+enum
    enum+=i+1
    xindex[si] = xindexsi

# %%
import itertools
betaindex = []
for (si1, si2) in list(itertools.combinations([key for key in service_intentions],2)):
    intsc = list(set.intersection(set(route_graphs[si1].edges), set(route_graphs[si2].edges)))
    for e in intsc:
        betaindex.append((si1, si2, e))

# %%
def recursive_len(item):
    if type(item) == list:
        return sum(recursive_len(subitem) for subitem in item)
    else:
        return 1

# %%
t_len = recursive_len(si_list)
x_len = 0
delta_len = 0
for si in service_intentions:
    x_len += len(route_graphs[si].edges)
    delta_len += len(paths[si])
beta_len = len(betaindex)
total_length = t_len*2 + x_len + delta_len + beta_len
total_length
# Out:
# 59874

# %%
TL={}
i = 0
for si, si_id in zip(si_list, service_intentions):
    temp = {} 
    temp['t'] = recursive_len(si)
    temp['x'] = len(route_graphs[si_id].edges)
    temp['delta'] = len(paths[si_id])
    slacknum = 0
    for r in si:
        for rs in r:
            edge_data = route_graphs[si_id].edges[rs[2]]['edge_data']
            if 'entry_delay_weight' in edge_data and 'entry_latest' in edge_data:
                slacknum+=1
            if 'exit_delay_weight' in edge_data and 'exit_latest' in edge_data:
                slacknum+=1
            if 'entry_earliest' in edge_data:
                slacknum+=1
            if 'exit_earliest' in edge_data:
                slacknum+=1
            i+=1
    temp['slack'] = slacknum
    TL[si_id] = temp
slack_len = sum([TL[si]['slack'] for si in service_intentions])
total_length+=slack_len
TL
# Out:
# {2408: {'t': 55, 'x': 55, 'delta': 1, 'slack': 5},
#  856: {'t': 55, 'x': 55, 'delta': 1, 'slack': 5},
#  2620: {'t': 56, 'x': 56, 'delta': 1, 'slack': 7},
#  2622: {'t': 57, 'x': 57, 'delta': 1, 'slack': 8},
#  2624: {'t': 56, 'x': 56, 'delta': 1, 'slack': 7},
#  2626: {'t': 57, 'x': 57, 'delta': 1, 'slack': 8},
#  558: {'t': 148, 'x': 148, 'delta': 1, 'slack': 7},
#  560: {'t': 148, 'x': 148, 'delta': 1, 'slack': 7},
#  562: {'t': 148, 'x': 148, 'delta': 1, 'slack': 7},
#  464: {'t': 120, 'x': 120, 'delta': 1, 'slack': 4},
#  466: {'t': 120, 'x': 120, 'delta': 1, 'slack': 4},
#  912: {'t': 148, 'x': 148, 'delta': 1, 'slack': 7},
#  916: {'t': 148, 'x': 148, 'delta': 1, 'slack': 7},
#  911: {'t': 147, 'x': 147, 'delta': 1, 'slack': 7},
#  913: {'t': 147, 'x': 147, 'delta': 1, 'slack': 7},
#  5059: {'t': 154, 'x': 154, 'delta': 1, 'slack': 18},
#  5061: {'t': 154, 'x': 154, 'delta': 1, 'slack': 18},
#  2623: {'t': 53, 'x': 53, 'delta': 1, 'slack': 7},
#  2625: {'t': 52, 'x': 52, 'delta': 1, 'slack': 7},
#  2627: {'t': 53, 'x': 53, 'delta': 1, 'slack': 7},
#  2629: {'t': 52, 'x': 52, 'delta': 1, 'slack': 6},
#  2631: {'t': 53, 'x': 53, 'delta': 1, 'slack': 7},
#  2633: {'t': 52, 'x': 52, 'delta': 1, 'slack': 6},
#  559: {'t': 147, 'x': 147, 'delta': 1, 'slack': 7},
#  1255: {'t': 147, 'x': 147, 'delta': 1, 'slack': 7},
#  163: {'t': 118, 'x': 118, 'delta': 1, 'slack': 4},
#  18223: {'t': 103, 'x': 103, 'delta': 1, 'slack': 15},
#  18225: {'t': 103, 'x': 103, 'delta': 1, 'slack': 15},
#  18224: {'t': 103, 'x': 103, 'delta': 1, 'slack': 16},
#  18226: {'t': 103, 'x': 103, 'delta': 1, 'slack': 16},
#  18823: {'t': 150, 'x': 81, 'delta': 2, 'slack': 36},
#  18825: {'t': 150, 'x': 81, 'delta': 2, 'slack': 36},
#  18824: {'t': 74, 'x': 74, 'delta': 1, 'slack': 18},
#  18826: {'t': 74, 'x': 74, 'delta': 1, 'slack': 18},
#  20423: {'t': 139, 'x': 78, 'delta': 2, 'slack': 28},
#  20425: {'t': 139, 'x': 78, 'delta': 2, 'slack': 20},
#  20424: {'t': 139, 'x': 78, 'delta': 2, 'slack': 26},
#  20426: {'t': 139, 'x': 78, 'delta': 2, 'slack': 26},
#  20523: {'t': 90, 'x': 90, 'delta': 1, 'slack': 11},
#  20527: {'t': 90, 'x': 90, 'delta': 1, 'slack': 11},
#  20524: {'t': 93, 'x': 93, 'delta': 1, 'slack': 10},
#  20528: {'t': 93, 'x': 93, 'delta': 1, 'slack': 10},
#  8224: {'t': 30, 'x': 30, 'delta': 1, 'slack': 7},
#  8226: {'t': 30, 'x': 30, 'delta': 1, 'slack': 7},
#  8221: {'t': 30, 'x': 30, 'delta': 1, 'slack': 7},
#  8223: {'t': 30, 'x': 30, 'delta': 1, 'slack': 7},
#  19320: {'t': 5, 'x': 5, 'delta': 1, 'slack': 3},
#  19322: {'t': 5, 'x': 5, 'delta': 1, 'slack': 3},
#  19319: {'t': 4, 'x': 4, 'delta': 1, 'slack': 3},
#  18013: {'t': 4, 'x': 4, 'delta': 1, 'slack': 3},
#  16919: {'t': 9, 'x': 9, 'delta': 1, 'slack': 4},
#  16920: {'t': 9, 'x': 9, 'delta': 1, 'slack': 4},
#  16921: {'t': 9, 'x': 9, 'delta': 1, 'slack': 4},
#  16922: {'t': 9, 'x': 9, 'delta': 1, 'slack': 4},
#  23428: {'t': 54, 'x': 54, 'delta': 1, 'slack': 14},
#  23432: {'t': 54, 'x': 54, 'delta': 1, 'slack': 14},
#  23617: {'t': 15, 'x': 15, 'delta': 1, 'slack': 8},
#  23621: {'t': 15, 'x': 15, 'delta': 1, 'slack': 8}}

# %% [markdown]
# ### Variables
#
# |t_in| = sum of the length of all service intentions, total number of paths per si and route sections per path
# |t_out| same as t_in
#
# |x| all service intentions and their route sections
#
# |delta| all service intentions and their paths
#
# $v = [t_{in}, t_{out} , x, \delta]$

# %% [markdown]
# #### Minimize objective function

# %% [markdown]
# $J(x)=\{ \frac{1}{60} \sum_{SI, R, RS} win_{rs}max(0,
# t_{si,r,rs}^{in} - LatIn_{si,rs}) + wout_{rs} max(0, t_{si,r,rs}^{out} - LatOut_{si,rs}) + p_{si,rs}x_{si,rs} \}$

# %% [markdown]
# #### Subject to

# %% [markdown]
# time into a section comes before time out:
#
#
# (1)  $t_{si,r,rs}^{in} \leq t_{si,r,rs}^{out}$
#
# time into next section comes after time out from previous section:
# (2)  $t_{si,r,rs}^{out} = t_{si,r,rs+1}^{in}$
#
# if r is the selected path, satisfy minimum running and stopping time:
# (3)  $t_{si,r,rs}^{out} - t_{si,r,rs}^{in} \geq mrt_{si, r, rs} + mst_{si, r, rs} - M(1-\delta_{si,r})$
#
# Earliest in constraint:
# (4)  $t_{si,r,rs}^{in} \geq EarIn_{si,r,rs} - M(1-\delta_{si,r})$
#
# Earliest out constraint:
# (5)  $t_{si,r,rs}^{out} \geq EarOut_{si,r,rs} - M(1-\delta_{si,r})$
#
# Select only one path to every service:
# (6)  $\sum_{r \in P} \delta_{si,r} = 1$
#
# All route sections on the chosen track are occupied
# (7)  $x_{si, re} \geq \delta_{si, r}$
#
# (8) $t_{si_1,r_1,re}^{in} - t_{si_2,r_2,re}^{in} \leq M(1-\beta_{si_1,si_2,re}) + M(2- \delta_{si_1,r_1} - \delta_{si_2,r_2})$
#
# (9) $t_{si_2,r_2,re}^{in} - t_{si_1,r_1,re}^{in} + \epsilon \leq M\beta_{si_1,si_2,re} + M(2- \delta_{si_1,r_1} - \delta_{si_2,r_2})$
#
# (10) $t_{si_1,r_1,re}^{out} - t_{si_2,r_2,re}^{in} + R \leq M(1-\beta_{si_1,si_2,re}) + M(2- \delta_{si_1,r_1} - \delta_{si_2,r_2})$
#
# (11) $t_{si_2,r_2,re}^{out} - t_{si_1,r_1,re}^{in} + R \leq M\beta_{si_1,si_2,re} + M(2- \delta_{si_1,r_1} - \delta_{si_2,r_2})$

# %% [markdown]
# LatIn = entry_latest
# EarOut = exit_earliest
# EarIn = entry_earliest
# LatOut = exit_latest

# %%
from time import strftime
from time import gmtime

def str_to_sec(s):
    s=s.split(':')
    return int(s[0])*60*60+int(s[1])*60+int(s[2])
def sec_to_str(x):
    return strftime("%H:%M:%S", gmtime(x))

# %% [markdown]
# ## Modelling approach

# %% [markdown]
# ### Display solution

# %%
def display_solution(x):
    x = list(x)
    slack, tin, tout, deltas, xs, betas = [],[],[],[],[],[]
    currlen = 0
    for si_id in service_intentions:
        tin += x[currlen + TL[si_id]['slack']:currlen + TL[si_id]['slack'] + TL[si_id]['t']]
        tout += x[currlen + TL[si_id]['slack'] +  TL[si_id]['t']:currlen + TL[si_id]['slack'] + 2*TL[si_id]['t']]
        deltas +=x[currlen + TL[si_id]['slack'] +  2*TL[si_id]['t']:currlen + TL[si_id]['slack'] + 2*TL[si_id]['t'] + TL[si_id]['delta']]
        currlen += TL[si_id]['slack'] + 2*TL[si_id]['t'] + TL[si_id]['delta'] + TL[si_id]['x']

    tin = np.array(tin)
    tout = np.array(tout)
    deltas = np.array(deltas)
    #betas = betas.value
    ad_paths = np.where(deltas==1)[0]
    paths_flat = []
    timetable = {}
    penalty = 0
    for si in paths:
        paths_flat += paths[si]
    for (si,ad_path) in zip(service_intentions, ad_paths):
        p = paths_flat[ad_path]
        timetable[si] = {'tin': [], 'tout':[]}
        for idx,e in zip(get_index_by_delta[ad_path],p):
            timetable[si]['tin'].append((tin[idx]))
            timetable[si]['tout'].append((tout[idx]))
            estr = e[0]+','+e[1]
            print(f'si: {si}, edge: {estr}, tin: {sec_to_str(tin[idx])}, tout: {sec_to_str(tout[idx])}')
            if estr in Lats[si]['LatIn']:
                #print('LatIn', Lats[si]['LatIn'][estr])
                pen = max(0,tin[idx] - str_to_sec(Lats[si]['LatIn'][estr]))
                penalty+=pen
                print('penalty:', pen)
            if estr in Lats[si]['LatOut']:
                #print('LatOut', Lats[si]['LatOut'][estr])
                pen= max(0,tout[idx] - str_to_sec(Lats[si]['LatOut'][estr]))
                print('penalty:', pen)
                penalty+=pen
            #print(route_graphs[si].edges[e])
    import matplotlib.pyplot as plt
    plt.figure(figsize = (20,15))
    s=100
    for si in timetable:
        plt.scatter(range(len(timetable[si]['tin'])),timetable[si]['tin'], marker = 'o', label = si, s=s)
        plt.scatter(range(1,len(timetable[si]['tout'])+1),timetable[si]['tout'], marker = 'x', label = si, s=s)
    plt.legend()

# %% [markdown]
# ### Constraints

# %%
Mmrtmst = [1]
MEarOut = [1]
MEarIn = [1]
for si in route_graphs:
    for e in route_graphs[si].edges(data=True):
        edge_data = e[2]['edge_data']
        if ('exit_earliest' in edge_data):
            EarOut = str_to_sec(edge_data['exit_earliest'])
            MEarOut.append(EarOut)
        if ('entry_earliest' in edge_data):
            EarIn = str_to_sec(edge_data['entry_earliest'])
            MEarIn.append(EarIn)
        if ('min_stopping_time' in edge_data) or ('minimum_running_time' in edge_data):
            mst = 0
            mrt = 0
            if 'min_stopping_time' in edge_data:
                mst = isodate.parse_duration(edge_data['min_stopping_time']).seconds
            if 'minimum_running_time' in edge_data:
                mrt = isodate.parse_duration(edge_data['minimum_running_time']).seconds
            Mmrtmst.append(mrt+mst)

# %%
from scipy.sparse import csr_matrix, vstack, lil_matrix,coo_matrix

# %% [markdown]
# ub_numCons_nor = recursive_len(si_list)*11
# ub_numCons_coup =  4*sum([len(delta_index_by_edge[si1][e])*len(delta_index_by_edge[si2][e]) for (si1, si2, e) in betaindex])
#
# c = np.zeros(total_length)
# testv = [None]*total_length
#
# #A = lil_matrix((ub_numCons_nor, total_length))
# row = []
# col = []
# data = []
# b = np.zeros(ub_numCons_nor)
# cnum = 0
# cnums = []
# currlen = 0
# bool_idx = []
# for si, si_id in zip(si_list, service_intentions):
#     tempsum = 0
#     j=0
#     coltemp = []
#     datatemp = []
#     i =0
#     s=0
#     for r, path in zip(si, paths[si_id]):
#         for enum, rs in enumerate(r):
#             edge_data = route_graphs[si_id].edges[rs[2]]['edge_data']
#             #slack
#             tin_idx = currlen + i + TL[si_id]['slack']
#             tout_idx = currlen + i + TL[si_id]['slack'] + TL[si_id]['t']
#             delta_idx = currlen + j + TL[si_id]['slack'] + 2*TL[si_id]['t']
#             ad_x = 0
#             for t in service_intentions:
#                 if t==si_id:
#                     break
#                 ad_x += TL[t]['x']
#             x_idx = currlen + xindex[si_id][rs[2]] + TL[si_id]['slack'] + 2*TL[si_id]['t'] + TL[si_id]['delta'] -ad_x
#
#
#             if 'entry_delay_weight' in edge_data and 'entry_latest' in edge_data:
#                 b[cnum] = float(edge_data['entry_delay_weight'])*str_to_sec(edge_data['entry_latest'])
#                 row += [cnum, cnum]
#                 col += [currlen + s, tin_idx]
#                 data += [-1, float(edge_data['entry_delay_weight'])]
#                 cnum +=1
#                 b[cnum] = 0
#                 row.append(cnum)
#                 col.append(currlen + s)
#                 data.append(-1)
#                 cnum +=1
#
#                 c[currlen + s] = 1
#
#                 testv[currlen + s] = f'slack_{s}_{si_id}'
#                 s+=1
#
#             if 'exit_delay_weight' in edge_data and 'exit_latest' in edge_data:
#                 b[cnum] = float(edge_data['exit_delay_weight'])*str_to_sec(edge_data['exit_latest'])
#                 row += [cnum, cnum]
#                 col += [currlen + s, tout_idx]
#                 data += [-1, float(edge_data['exit_delay_weight'])]
#                 cnum+=1
#
#                 b[cnum] = 0
#                 row.append(cnum)
#                 col.append(currlen + s)
#                 data.append(-1)
#                 cnum += 1
#
#                 c[currlen + s] = 1
#                 testv[currlen + s] = f'slack_{s}_{si_id}'
#                 s+=1
#
#
#             b[cnum] = 0
#             row.append(cnum)
#             col.append(tin_idx)
#             data.append(-1)
#             cnum+=1
#             testv[tin_idx] = f'tin_{i}_{si_id}'
#
#             b[cnum] = 0
#             row.append(cnum)
#             col.append(tout_idx)
#             data.append(-1)
#             cnum += 1
#             testv[tout_idx] = f'tout_{i}_{si_id}'
#
#             #(1)
#             row += [cnum, cnum]
#             col += [tin_idx, tout_idx]
#             data += [1,-1]
#             b[cnum] = 0
#             cnum += 1
#
#             # (2)
#             if enum!=len(r)-1:
#                 b[cnum] = 0
#                 row+=[cnum, cnum]
#                 col+=[tin_idx+1, tout_idx]
#                 data += [1,-1]
#                 cnum += 1
#
#                 row+=[cnum, cnum]
#                 col+=[tin_idx+1, tout_idx]
#                 data += [-1,1]
#                 b[cnum] = 0
#                 cnum+=1
#
#             #(3)
#             #M=10000000
#             M=max(Mmrtmst)
#             if ('min_stopping_time' in edge_data) or ('minimum_running_time' in edge_data):
#                 mst = 0
#                 mrt = 0
#                 if 'min_stopping_time' in edge_data:
#                     mst = isodate.parse_duration(edge_data['min_stopping_time']).seconds
#                 if 'minimum_running_time' in edge_data:
#                     mrt = isodate.parse_duration(edge_data['minimum_running_time']).seconds
#
#                 #b[cnum] = M-mrt-mst
#                 #row += [cnum, cnum, cnum]
#                 #col+=[tin_idx, tout_idx, delta_idx]
#                 #data+=[1,-1,M]
#                 #cnum += 1
#
#             # (4)
#             M=max(MEarIn)
#             if ('entry_earliest' in edge_data):
#                 EarIn = str_to_sec(edge_data['entry_earliest'])
#
#                 b[cnum] = M-EarIn
#                 row += [cnum, cnum]
#                 col += [tin_idx, delta_idx]
#                 data += [-1, M]
#                 cnum += 1
#
#             #(5)
#             M=max(MEarOut)
#             if ('exit_earliest' in edge_data):
#                 EarOut = str_to_sec(edge_data['exit_earliest'])
#
#                 row +=[cnum, cnum]
#                 col += [tout_idx, delta_idx]
#                 data += [-1, M]
#                 b[cnum] = M-EarOut
#                 cnum += 1
#             # (7)
#             b[cnum] = 0
#             row += [cnum, cnum]
#             col += [delta_idx, x_idx]
#             data+= [1,-1]
#             cnum += 1
#
#             bool_idx.append(delta_idx)
#             bool_idx.append(x_idx)
#             testv[x_idx] = f'x_{xindex[si_id][rs[2]] - ad_x}_{si_id}'
#             testv[delta_idx] = f'delta_{j}_{si_id}'
#
#             i+=1
#         # (6)
#         coltemp.append(delta_idx)
#         datatemp.append(1)
#         j+=1
#
#     tempb = np.array([1])
#     b = np.hstack((b[:cnum],tempb,b[cnum:]))
#     row += [cnum]*len(coltemp)
#     col+= coltemp
#     data+=datatemp
#     cnum += 1
#
#     row += [cnum]*len(coltemp)
#     datatemp = [-1*x for x in datatemp]
#     col+=coltemp
#     data+=datatemp
#     tempb = -1*tempb.copy()
#     b = np.hstack((b[:cnum],tempb,b[cnum:]))
#     cnum += 1
#     if len(cnums)==0:
#         cnums.append(cnum)
#     else:
#         cnums.append(cnum - cnums[-1])
#     currlen += TL[si_id]['slack'] + 2*TL[si_id]['t'] + TL[si_id]['delta'] + TL[si_id]['x']
#
# print(cnum)
# b = b[:cnum]
# A = coo_matrix((data, (row, col)), shape=(cnum, total_length))
#
#
# #objective
# currlen = 0
# for si, si_id in zip(si_list, service_intentions):
#     for edge in route_graphs[si_id].edges(data=True):
#         ad_x = 0
#         for t in service_intentions:
#             if t==si_id:
#                 break
#             ad_x += TL[t]['x']
#         e = (edge[0],edge[1])
#         x_idx = currlen + xindex[si_id][e] + TL[si_id]['slack'] + 2*TL[si_id]['t'] + TL[si_id]['delta'] - ad_x
#         p = 0
#         if 'penalty' in edge[2]['edge_data']:
#             p = edge[2]['edge_data']['penalty']
#             if p == None:
#                 p = 0
#             else:
#                 p = float(p)
#             c[x_idx]= p
#         i+=1
#
#
# #coupling
# cnum = 0
# #A_coup = csr_matrix((ub_numCons_coup, total_length))
# b_coup = np.zeros(ub_numCons_coup)
# row, col, data = [], [], []
#
# i = 0
# eps = 0
# M = 100000
# R=0
# LenSI = total_length - beta_len
# for (si1, si2, e) in betaindex:
#     deltaidx1 = delta_index_by_edge[si1][e]
#     deltaidx2 = delta_index_by_edge[si2][e]
#
#
#     prevsi = []
#     for siprevel in [si for si in service_intentions]:
#         if siprevel==si1:
#             break
#         prevsi.append(siprevel)
#     adjuster1 = sum([TL[siprevel]['t'] for siprevel in prevsi])
#
#     prevsi = []
#     for siprevel in [si for si in service_intentions]:
#         if siprevel==si2:
#             break
#         prevsi.append(siprevel)
#     adjuster2 = sum([TL[siprevel]['t'] for siprevel in prevsi])
#
#     prevsi = []
#     for siprevel in [si for si in service_intentions]:
#         if siprevel==si1:
#             break
#         prevsi.append(siprevel)
#     adjuster1d = sum([TL[siprevel]['delta'] for siprevel in prevsi])
#
#     prevsi = []
#     for siprevel in [si for si in service_intentions]:
#         if siprevel==si2:
#             break
#         prevsi.append(siprevel)
#     adjuster2d = sum([TL[siprevel]['delta'] for siprevel in prevsi])
#
#     sumtil1 = 0
#     prevsi = []
#     for siprevel in [si for si in service_intentions]:
#         if siprevel==si1:
#             break
#         prevsi.append(siprevel)
#     sumtil1 = sum([TL[siprevel]['slack'] + 2*TL[siprevel]['t'] + TL[siprevel]['delta'] + TL[siprevel]['x'] for siprevel in prevsi])
#
#
#     sumtil2 = 0
#     prevsi = []
#     for siprevel in [si for si in service_intentions]:
#         if siprevel==si2:
#             break
#         prevsi.append(siprevel)
#     sumtil2 = sum([TL[siprevel]['slack'] + 2*TL[siprevel]['t'] + TL[siprevel]['delta'] + TL[siprevel]['x'] for siprevel in prevsi])
#
#
#     for idx1 in deltaidx1:
#         for idx2 in deltaidx2:
#             tin1_idx = edges_by_path[idx1][e] - adjuster1 + sumtil1 + TL[si1]['slack']
#             tin2_idx = edges_by_path[idx2][e] - adjuster2 + sumtil2 + TL[si2]['slack']
#             tout1_idx = edges_by_path[idx1][e] - adjuster1 + sumtil1 + TL[si1]['slack'] + TL[si1]['t']
#             tout2_idx = edges_by_path[idx2][e] - adjuster2 + sumtil2 + TL[si2]['slack'] + TL[si2]['t']
#             delta1_idx = idx1+TL[si_id]['slack']+2*TL[si1]['t'] - adjuster1d + sumtil1
#             delta2_idx = idx2+TL[si_id]['slack']+2*TL[si2]['t'] - adjuster2d + sumtil2
#
#             #print(f'tin1 {tin1_idx}, tin2 {tin2_idx}, delta1 {delta1_idx}, delta2 {delta2_idx}, beta {LenSI+i}')
#             row+=[cnum,cnum, cnum, cnum, cnum]
#             col+=[tin1_idx, tin2_idx, delta1_idx, delta2_idx,LenSI+i]
#             data += [1,-1,M,M,M]
#             b_coup[cnum]=3*M
#             cnum += 1
#
#
#             row+=[cnum,cnum, cnum, cnum, cnum]
#             col+=[tin1_idx, tin2_idx, delta1_idx, delta2_idx,LenSI+i]
#             data += [-1,1,M,M,-M]
#             b_coup[cnum]=2*M-eps
#             cnum += 1
#
#
#             row+=[cnum,cnum, cnum, cnum, cnum]
#             col+=[tin2_idx, tout1_idx, delta1_idx, delta2_idx,LenSI+i]
#             data += [-1,1,M,M,M]
#             b_coup[cnum]=3*M-R
#             cnum += 1
#
#
#             row+=[cnum,cnum, cnum, cnum, cnum]
#             col+=[tin1_idx, tout2_idx, delta1_idx, delta2_idx,LenSI+i]
#             data += [-1,1,M,M,-M]
#             b_coup[cnum]=2*M-R
#             cnum += 1
#     testv[LenSI+i] = f'beta_{i}'
#     bool_idx.append(LenSI+i)
#     i+=1
#
# bool_idx =list(set(bool_idx))
# print(cnum)
#
#
#
# A_coup = coo_matrix((data, (row, col)), shape=(cnum, total_length))
# b_coup = b_coup[:cnum].flatten()

# %%
ub_numCons_nor = recursive_len(si_list)*11
ub_numCons_coup =  4*sum([len(delta_index_by_edge[si1][e])*len(delta_index_by_edge[si2][e]) for (si1, si2, e) in betaindex])

c = np.zeros(total_length)
testv = [None]*total_length

#A = lil_matrix((ub_numCons_nor, total_length))
row = []
col = []
data = []
b = np.zeros(ub_numCons_nor)
cnum = 0
cnums = []
currlen = 0
bool_idx = []
wearin = 0.1
wearout = 0.1
for si, si_id in zip(si_list, service_intentions):
    tempsum = 0
    j=0
    coltemp = []
    datatemp = []
    i =0
    s=0
    for r, path in zip(si, paths[si_id]):
        for enum, rs in enumerate(r):
            edge_data = route_graphs[si_id].edges[rs[2]]['edge_data']
            #slack
            tin_idx = currlen + i + TL[si_id]['slack'] 
            tout_idx = currlen + i + TL[si_id]['slack'] + TL[si_id]['t']
            delta_idx = currlen + j + TL[si_id]['slack'] + 2*TL[si_id]['t']
            ad_x = 0
            for t in service_intentions:
                if t==si_id:
                    break
                ad_x += TL[t]['x']
            x_idx = currlen + xindex[si_id][rs[2]] + TL[si_id]['slack'] + 2*TL[si_id]['t'] + TL[si_id]['delta'] -ad_x
            
            
            if 'entry_delay_weight' in edge_data and 'entry_latest' in edge_data:
                b[cnum] = float(edge_data['entry_delay_weight'])*str_to_sec(edge_data['entry_latest'])
                row += [cnum, cnum]
                col += [currlen + s, tin_idx]
                data += [-1, float(edge_data['entry_delay_weight'])]
                cnum +=1
                b[cnum] = 0
                row.append(cnum)
                col.append(currlen + s)
                data.append(-1)
                cnum +=1
                
                c[currlen + s] = 1

                testv[currlen + s] = f'slack_{s}_{si_id}'
                s+=1
                
            if 'exit_delay_weight' in edge_data and 'exit_latest' in edge_data:
                b[cnum] = float(edge_data['exit_delay_weight'])*str_to_sec(edge_data['exit_latest'])
                row += [cnum, cnum]
                col += [currlen + s, tout_idx]
                data += [-1, float(edge_data['exit_delay_weight'])]
                cnum+=1
                
                b[cnum] = 0
                row.append(cnum)
                col.append(currlen + s)
                data.append(-1)
                cnum += 1
                
                c[currlen + s] = 1
                testv[currlen + s] = f'slack_{s}_{si_id}'
                s+=1
                
            if 'entry_earliest' in edge_data:
                EarIn = str_to_sec(edge_data['entry_earliest'])
                
                b[cnum] = wearin*EarIn
                row += [cnum, cnum]
                col += [currlen + s, tin_idx]
                data += [-1, wearin]
                cnum +=1
                b[cnum] = 0
                row.append(cnum)
                col.append(currlen + s)
                data.append(-1)
                cnum +=1
                
                c[currlen + s] = 1

                testv[currlen + s] = f'slack_{s}_{si_id}'
                s+=1
                
            if 'exit_earliest' in edge_data:
                EarOut = str_to_sec(edge_data['exit_earliest'])
                
                b[cnum] = wearout*EarOut
                row += [cnum, cnum]
                col += [currlen + s, tout_idx]
                data += [-1, wearout]
                cnum+=1
                
                b[cnum] = 0
                row.append(cnum)
                col.append(currlen + s)
                data.append(-1)
                cnum += 1
                
                c[currlen + s] = 1
                testv[currlen + s] = f'slack_{s}_{si_id}'
                s+=1


            
            b[cnum] = 0
            row.append(cnum)
            col.append(tin_idx)
            data.append(-1)
            cnum+=1
            testv[tin_idx] = f'tin_{i}_{si_id}'
            
            b[cnum] = 0
            row.append(cnum)
            col.append(tout_idx)
            data.append(-1)
            cnum += 1
            testv[tout_idx] = f'tout_{i}_{si_id}'
            
            #(1)
            row += [cnum, cnum]
            col += [tin_idx, tout_idx]
            data += [1,-1]
            b[cnum] = 0
            cnum += 1
            
            # (2)
            if enum!=len(r)-1:
                b[cnum] = 0
                row+=[cnum, cnum]
                col+=[tin_idx+1, tout_idx]
                data += [1,-1]
                cnum += 1
                
                row+=[cnum, cnum]
                col+=[tin_idx+1, tout_idx]
                data += [-1,1]
                b[cnum] = 0
                cnum+=1

            #(3)
            #M=10000000
            M=max(Mmrtmst)
            if ('min_stopping_time' in edge_data) or ('minimum_running_time' in edge_data):
                mst = 0
                mrt = 0
                if 'min_stopping_time' in edge_data:
                    mst = isodate.parse_duration(edge_data['min_stopping_time']).seconds
                if 'minimum_running_time' in edge_data:
                    mrt = isodate.parse_duration(edge_data['minimum_running_time']).seconds

                #b[cnum] = M-mrt-mst
                #row += [cnum, cnum, cnum]
                #col+=[tin_idx, tout_idx, delta_idx]
                #data+=[1,-1,M]
                #cnum += 1

            # (4)

            #(5)
            M=max(MEarOut)    
            if ('exit_earliest' in edge_data):
                EarOut = str_to_sec(edge_data['exit_earliest'])
                
                row +=[cnum, cnum]
                col += [tout_idx, delta_idx]
                data += [-1, M]
                b[cnum] = M-EarOut
                cnum += 1
            # (7)
            b[cnum] = 0
            row += [cnum, cnum]
            col += [delta_idx, x_idx]
            data+= [1,-1]
            cnum += 1
            
            bool_idx.append(delta_idx)
            bool_idx.append(x_idx)
            testv[x_idx] = f'x_{xindex[si_id][rs[2]] - ad_x}_{si_id}'
            testv[delta_idx] = f'delta_{j}_{si_id}'
            
            i+=1
        # (6)
        coltemp.append(delta_idx)
        datatemp.append(1)
        j+=1
    
    tempb = np.array([1])
    b = np.hstack((b[:cnum],tempb,b[cnum:]))
    row += [cnum]*len(coltemp)
    col+= coltemp
    data+=datatemp
    cnum += 1
    
    row += [cnum]*len(coltemp)
    datatemp = [-1*x for x in datatemp]
    col+=coltemp
    data+=datatemp
    tempb = -1*tempb.copy()
    b = np.hstack((b[:cnum],tempb,b[cnum:]))
    cnum += 1
    if len(cnums)==0:
        cnums.append(cnum)
    else:
        cnums.append(cnum - cnums[-1])
    currlen += TL[si_id]['slack'] + 2*TL[si_id]['t'] + TL[si_id]['delta'] + TL[si_id]['x']

print(cnum)
b = b[:cnum]
A = coo_matrix((data, (row, col)), shape=(cnum, total_length))


#objective
currlen = 0    
for si, si_id in zip(si_list, service_intentions):
    for edge in route_graphs[si_id].edges(data=True):
        ad_x = 0
        for t in service_intentions:
            if t==si_id:
                break
            ad_x += TL[t]['x']
        e = (edge[0],edge[1])
        x_idx = currlen + xindex[si_id][e] + TL[si_id]['slack'] + 2*TL[si_id]['t'] + TL[si_id]['delta'] - ad_x
        p = 0
        if 'penalty' in edge[2]['edge_data']:
            p = edge[2]['edge_data']['penalty']
            if p == None:
                p = 0
            else:
                p = float(p)
            c[x_idx]= p
        i+=1   


#coupling
cnum = 0
#A_coup = csr_matrix((ub_numCons_coup, total_length))
b_coup = np.zeros(ub_numCons_coup)
row, col, data = [], [], []

i = 0
eps = 0
M = 100000
R=0
LenSI = total_length - beta_len
for (si1, si2, e) in betaindex:
    deltaidx1 = delta_index_by_edge[si1][e]
    deltaidx2 = delta_index_by_edge[si2][e]
    
    
    prevsi = []
    for siprevel in [si for si in service_intentions]:
        if siprevel==si1:
            break
        prevsi.append(siprevel)
    adjuster1 = sum([TL[siprevel]['t'] for siprevel in prevsi])
    
    prevsi = []
    for siprevel in [si for si in service_intentions]:
        if siprevel==si2:
            break
        prevsi.append(siprevel)
    adjuster2 = sum([TL[siprevel]['t'] for siprevel in prevsi])
    
    prevsi = []
    for siprevel in [si for si in service_intentions]:
        if siprevel==si1:
            break
        prevsi.append(siprevel)
    adjuster1d = sum([TL[siprevel]['delta'] for siprevel in prevsi])
    
    prevsi = []
    for siprevel in [si for si in service_intentions]:
        if siprevel==si2:
            break
        prevsi.append(siprevel)
    adjuster2d = sum([TL[siprevel]['delta'] for siprevel in prevsi])
    
    sumtil1 = 0
    prevsi = []
    for siprevel in [si for si in service_intentions]:
        if siprevel==si1:
            break
        prevsi.append(siprevel)
    sumtil1 = sum([TL[siprevel]['slack'] + 2*TL[siprevel]['t'] + TL[siprevel]['delta'] + TL[siprevel]['x'] for siprevel in prevsi])

    
    sumtil2 = 0
    prevsi = []
    for siprevel in [si for si in service_intentions]:
        if siprevel==si2:
            break
        prevsi.append(siprevel)
    sumtil2 = sum([TL[siprevel]['slack'] + 2*TL[siprevel]['t'] + TL[siprevel]['delta'] + TL[siprevel]['x'] for siprevel in prevsi])
        
    
    for idx1 in deltaidx1:
        for idx2 in deltaidx2:
            tin1_idx = edges_by_path[idx1][e] - adjuster1 + sumtil1 + TL[si1]['slack']
            tin2_idx = edges_by_path[idx2][e] - adjuster2 + sumtil2 + TL[si2]['slack']
            tout1_idx = edges_by_path[idx1][e] - adjuster1 + sumtil1 + TL[si1]['slack'] + TL[si1]['t']
            tout2_idx = edges_by_path[idx2][e] - adjuster2 + sumtil2 + TL[si2]['slack'] + TL[si2]['t']
            delta1_idx = idx1+TL[si_id]['slack']+2*TL[si1]['t'] - adjuster1d + sumtil1
            delta2_idx = idx2+TL[si_id]['slack']+2*TL[si2]['t'] - adjuster2d + sumtil2
            
            #print(f'tin1 {tin1_idx}, tin2 {tin2_idx}, delta1 {delta1_idx}, delta2 {delta2_idx}, beta {LenSI+i}')
            row+=[cnum,cnum, cnum, cnum, cnum]
            col+=[tin1_idx, tin2_idx, delta1_idx, delta2_idx,LenSI+i]
            data += [1,-1,M,M,M]
            b_coup[cnum]=3*M
            cnum += 1
            
            
            row+=[cnum,cnum, cnum, cnum, cnum]
            col+=[tin1_idx, tin2_idx, delta1_idx, delta2_idx,LenSI+i]
            data += [-1,1,M,M,-M]
            b_coup[cnum]=2*M-eps
            cnum += 1
            
            
            row+=[cnum,cnum, cnum, cnum, cnum]
            col+=[tin2_idx, tout1_idx, delta1_idx, delta2_idx,LenSI+i]
            data += [-1,1,M,M,M]
            b_coup[cnum]=3*M-R
            cnum += 1
            
            
            row+=[cnum,cnum, cnum, cnum, cnum]
            col+=[tin1_idx, tout2_idx, delta1_idx, delta2_idx,LenSI+i]
            data += [-1,1,M,M,-M]
            b_coup[cnum]=2*M-R
            cnum += 1
    testv[LenSI+i] = f'beta_{i}'       
    bool_idx.append(LenSI+i)
    i+=1

bool_idx =list(set(bool_idx))
print(cnum)



A_coup = coo_matrix((data, (row, col)), shape=(cnum, total_length))
b_coup = b_coup[:cnum].flatten()
# Out:
# 29987
# 211480

# %%
At = vstack((A,A_coup))
bt = np.hstack((b,b_coup))

# %%
def len_si(si_id):
    lb = 0
    ub=0
    for si in service_intentions:
        s = 2*TL[si]['t'] + TL[si]['x'] + TL[si]['delta'] + TL[si]['slack']
        ub += s
        if si_id == si:
            return (lb, ub)
        lb+=s
        
def len_cons(si_id):
    lb = 0
    ub=0
    for si,cnum in zip(service_intentions,cnums):
        ub += cnum
        print(lb,ub)
        if si_id == si:
            return (lb, ub)
        lb+=cnum

# %% [markdown]
# Next one up
#
# Check relaxed constraints
#
#
# Sparse matrix

# %%
lam = np.zeros(len(b_coup))

bool_vars_idx = [(x,) for x in bool_idx]

x = cp.Variable(A.shape[1], boolean = bool_vars_idx)


p = cp.Problem(cp.Minimize(c.T@x ),
                 [At@x<=bt])
p = p.solve(solver = 'MOSEK', verbose = True)
            #,mosek_params={mosek.iparam.intpnt_solve_form: mosek.solve.primal})
# Out:
# ===============================================================================
#                                      CVXPY
#                                     v1.1.14
# ===============================================================================
# (CVXPY) Aug 24 03:34:38 AM: Your problem has 60657 variables, 1 constraints, and 0 parameters.
# (CVXPY) Aug 24 03:34:38 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Aug 24 03:34:38 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Aug 24 03:34:38 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Aug 24 03:34:38 AM: Compiling problem (target solver=MOSEK).
# (CVXPY) Aug 24 03:34:38 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Aug 24 03:34:38 AM: Applying reduction Dcp2Cone
# (CVXPY) Aug 24 03:34:38 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Aug 24 03:34:38 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Aug 24 03:34:47 AM: Applying reduction MOSEK
# (CVXPY) Aug 24 03:34:47 AM: Finished problem compilation (took 9.871e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Aug 24 03:34:47 AM: Invoking solver MOSEK  to obtain a solution.
#
#
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : LO (linear optimization problem)
#   Constraints            : 241467
#   Cones                  : 0
#   Scalar variables       : 60657
#   Matrix variables       : 0
#   Integer variables      : 50396
#
# Optimizer started.
# Mixed integer optimizer started.
# Threads used: 4
# Presolve started.
# Presolve terminated. Time = 1.12
# Clique table size: 0
# BRANCHES RELAXS   ACT_NDS  DEPTH    BEST_INT_OBJ         BEST_RELAX_OBJ       REL_GAP(%)  TIME
#
# Objective of best integer solution : Not available.
# Best objective bound               : Not available.
# Construct solution objective       : Not employed
# User objective cut value           : Not employed
# Number of cuts generated           : 0
# Number of branches                 : 0
# Number of relaxations solved       : 0
# Number of interior point iterations: 0
# Number of simplex iterations       : 0
# Time spend presolving the root     : 1.12
# Time spend optimizing the root     : 0.00
# Mixed integer optimizer terminated. Time: 1.51
#
# Optimizer terminated. Time: 1.67
#
#
# Integer solution solution summary
#   Problem status  : PRIMAL_INFEASIBLE
#   Solution status : UNKNOWN
#   Primal.  obj: 0.0000000000e+00    nrm: 0e+00    Viol.  con: 1e+00    var: 0e+00    itg: 0e+00
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Aug 24 03:34:50 AM: Problem status: infeasible
# (CVXPY) Aug 24 03:34:50 AM: Optimal value: inf
# (CVXPY) Aug 24 03:34:50 AM: Compilation took 9.871e+00 seconds
# (CVXPY) Aug 24 03:34:50 AM: Solver (including time spent in interface) took 2.001e+00 seconds

# %%
display_solution(x.value)
# Out:
# si: 2408, edge: (1_beginning),(1->5), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (1->5),(5->10), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (5->10),(10->12), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (10->12),(12->15), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# si: 2408, edge: (12->15),(15->20), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (15->20),(20->25), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (20->25),(25->30), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (25->30),(30->35), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (30->35),(35->40), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (35->40),(40->45), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (40->45),(45->50), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (45->50),(50->55), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (50->55),(55->60), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (55->60),(60->65), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (60->65),(65->70), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (65->70),(70->75), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (70->75),(75->80), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (75->80),(80->85), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (80->85),(85->90), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (85->90),(90->95), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (90->95),(95->100), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (95->100),(100->105), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (100->105),(105->110), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (105->110),(110->115), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (110->115),(115->120), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (115->120),(120->125), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (120->125),(125->130), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (125->130),(130->135), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (130->135),(135->140), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (135->140),(140->145), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (140->145),(145->150), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (145->150),(150->155), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (150->155),(155->160), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (155->160),(160->165), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (160->165),(165->170), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (165->170),(170->175), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (170->175),(175->180), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (175->180),(180->185), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (180->185),(185->190), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (185->190),(190->195), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (190->195),(195->200), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (195->200),(200->205), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (200->205),(205->210), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (205->210),(210->215), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (210->215),(215->220), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (215->220),(220->225), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (220->225),(225->230), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (225->230),(230->235), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (230->235),(235->240), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (235->240),(240->245), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (240->245),(245->250), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (245->250),(250->255), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (250->255),(255->260), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (255->260),(260->265), tin: 00:00:00, tout: 00:00:00
# si: 2408, edge: (260->265),(265_end), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# penalty: 0
# si: 856, edge: (1_beginning),(1->5), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (1->5),(5->10), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (5->10),(10->12), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (10->12),(12->15), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# si: 856, edge: (12->15),(15->20), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (15->20),(20->25), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (20->25),(25->30), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (25->30),(30->35), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (30->35),(35->40), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (35->40),(40->45), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (40->45),(45->50), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (45->50),(50->55), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (50->55),(55->60), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (55->60),(60->65), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (60->65),(65->70), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (65->70),(70->75), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (70->75),(75->80), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (75->80),(80->85), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (80->85),(85->90), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (85->90),(90->95), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (90->95),(95->100), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (95->100),(100->105), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (100->105),(105->110), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (105->110),(110->115), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (110->115),(115->120), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (115->120),(120->125), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (120->125),(125->130), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (125->130),(130->135), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (130->135),(135->140), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (135->140),(140->145), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (140->145),(145->150), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (145->150),(150->155), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (150->155),(155->160), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (155->160),(160->165), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (160->165),(165->170), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (165->170),(170->175), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (170->175),(175->180), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (175->180),(180->185), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (180->185),(185->190), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (185->190),(190->195), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (190->195),(195->200), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (195->200),(200->205), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (200->205),(205->210), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (205->210),(210->215), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (210->215),(215->220), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (215->220),(220->225), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (220->225),(225->230), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (225->230),(230->235), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (230->235),(235->240), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (235->240),(240->245), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (240->245),(245->250), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (245->250),(250->255), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (250->255),(255->260), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (255->260),(260->265), tin: 00:00:00, tout: 00:00:00
# si: 856, edge: (260->265),(265_end), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# penalty: 0
# si: 2620, edge: (1_beginning),(1->5), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (1->5),(5->10), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (5->10),(10->12), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (10->12),(12->15), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# si: 2620, edge: (12->15),(15->20), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (15->20),(20->25), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (20->25),(25->30), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (25->30),(30->35), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (30->35),(35->40), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (35->40),(40->45), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (40->45),(45->50), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (45->50),(50->55), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (50->55),(55->60), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (55->60),(60->65), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (60->65),(65->70), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (65->70),(70->75), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (70->75),(75->80), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (75->80),(80->85), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (80->85),(85->90), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (85->90),(90->95), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (90->95),(95->100), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (95->100),(100->105), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (100->105),(105->110), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (105->110),(110->115), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (110->115),(115->120), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (115->120),(120->125), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (120->125),(125->130), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (125->130),(130->135), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (130->135),(135->140), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (135->140),(140->145), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (140->145),(145->150), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (145->150),(150->155), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (150->155),(155->160), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (155->160),(160->165), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (160->165),(165->167), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (165->167),(167->170), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# si: 2620, edge: (167->170),(170->175), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (170->175),(175->180), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (175->180),(180->185), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (180->185),(185->190), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (185->190),(190->195), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (190->195),(195->200), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (195->200),(200->205), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (200->205),(205->210), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (205->210),(210->215), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (210->215),(215->220), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (215->220),(220->225), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (220->225),(225->230), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (225->230),(230->235), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (230->235),(235->240), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (235->240),(240->245), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (240->245),(245->250), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (245->250),(250->255), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (250->255),(255->260), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (255->260),(260->265), tin: 00:00:00, tout: 00:00:00
# si: 2620, edge: (260->265),(265_end), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# penalty: 0
# si: 2622, edge: (1_beginning),(1->5), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (1->5),(5->10), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (5->10),(10->12), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (10->12),(12->15), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# si: 2622, edge: (12->15),(15->20), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (15->20),(20->25), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (20->25),(25->30), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (25->30),(30->35), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (30->35),(35->40), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (35->40),(40->45), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (40->45),(45->50), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (45->50),(50->52), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (50->52),(52->55), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (52->55),(55->60), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (55->60),(60->65), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (60->65),(65->70), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (65->70),(70->75), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (70->75),(75->80), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (75->80),(80->85), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (80->85),(85->90), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (85->90),(90->95), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (90->95),(95->100), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (95->100),(100->105), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (100->105),(105->110), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (105->110),(110->115), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (110->115),(115->120), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (115->120),(120->125), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (120->125),(125->130), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (125->130),(130->135), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (130->135),(135->140), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (135->140),(140->145), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (140->145),(145->150), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (145->150),(150->155), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (150->155),(155->160), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (155->160),(160->165), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (160->165),(165->167), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (165->167),(167->170), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# si: 2622, edge: (167->170),(170->175), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (170->175),(175->180), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (175->180),(180->185), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (180->185),(185->190), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (185->190),(190->195), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (190->195),(195->200), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (195->200),(200->205), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (200->205),(205->210), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (205->210),(210->215), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (210->215),(215->220), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (215->220),(220->225), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (220->225),(225->230), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (225->230),(230->235), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (230->235),(235->240), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (235->240),(240->245), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (240->245),(245->250), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (245->250),(250->255), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (250->255),(255->260), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (255->260),(260->265), tin: 00:00:00, tout: 00:00:00
# si: 2622, edge: (260->265),(265_end), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# penalty: 0
# si: 2624, edge: (1_beginning),(1->5), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (1->5),(5->10), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (5->10),(10->12), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (10->12),(12->15), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# si: 2624, edge: (12->15),(15->20), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (15->20),(20->25), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (20->25),(25->30), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (25->30),(30->35), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (30->35),(35->40), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (35->40),(40->45), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (40->45),(45->50), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (45->50),(50->55), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (50->55),(55->60), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (55->60),(60->65), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (60->65),(65->70), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (65->70),(70->75), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (70->75),(75->80), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (75->80),(80->85), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (80->85),(85->90), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (85->90),(90->95), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (90->95),(95->100), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (95->100),(100->105), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (100->105),(105->110), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (105->110),(110->115), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (110->115),(115->120), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (115->120),(120->125), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (120->125),(125->130), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (125->130),(130->135), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (130->135),(135->140), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (135->140),(140->145), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (140->145),(145->150), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (145->150),(150->155), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (150->155),(155->160), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (155->160),(160->165), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (160->165),(165->167), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (165->167),(167->170), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# si: 2624, edge: (167->170),(170->175), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (170->175),(175->180), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (175->180),(180->185), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (180->185),(185->190), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (185->190),(190->195), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (190->195),(195->200), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (195->200),(200->205), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (200->205),(205->210), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (205->210),(210->215), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (210->215),(215->220), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (215->220),(220->225), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (220->225),(225->230), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (225->230),(230->235), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (230->235),(235->240), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (235->240),(240->245), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (240->245),(245->250), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (245->250),(250->255), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (250->255),(255->260), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (255->260),(260->265), tin: 00:00:00, tout: 00:00:00
# si: 2624, edge: (260->265),(265_end), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# penalty: 0
# si: 2626, edge: (1_beginning),(1->5), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (1->5),(5->10), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (5->10),(10->12), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (10->12),(12->15), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# si: 2626, edge: (12->15),(15->20), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (15->20),(20->25), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (20->25),(25->30), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (25->30),(30->35), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (30->35),(35->40), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (35->40),(40->45), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (40->45),(45->50), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (45->50),(50->52), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (50->52),(52->55), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (52->55),(55->60), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (55->60),(60->65), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (60->65),(65->70), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (65->70),(70->75), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (70->75),(75->80), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (75->80),(80->85), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (80->85),(85->90), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (85->90),(90->95), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (90->95),(95->100), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (95->100),(100->105), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (100->105),(105->110), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (105->110),(110->115), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (110->115),(115->120), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (115->120),(120->125), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (120->125),(125->130), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (125->130),(130->135), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (130->135),(135->140), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (135->140),(140->145), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (140->145),(145->150), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (145->150),(150->155), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (150->155),(155->160), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (155->160),(160->165), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (160->165),(165->167), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (165->167),(167->170), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# si: 2626, edge: (167->170),(170->175), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (170->175),(175->180), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (175->180),(180->185), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (180->185),(185->190), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (185->190),(190->195), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (190->195),(195->200), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (195->200),(200->205), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (200->205),(205->210), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (205->210),(210->215), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (210->215),(215->220), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (215->220),(220->225), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (220->225),(225->230), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (225->230),(230->235), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (230->235),(235->240), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (235->240),(240->245), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (240->245),(245->250), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (245->250),(250->255), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (250->255),(255->260), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (255->260),(260->265), tin: 00:00:00, tout: 00:00:00
# si: 2626, edge: (260->265),(265_end), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# penalty: 0
# si: 558, edge: (1_beginning),(1->5), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (1->5),(5->10), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (5->10),(10->15), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (10->15),(15->20), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (15->20),(20->25), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (20->25),(25->30), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (25->30),(30->35), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (30->35),(35->40), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (35->40),(40->45), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (40->45),(45->50), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (45->50),(50->55), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (50->55),(55->60), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (55->60),(60->65), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (60->65),(65->67), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (65->67),(67->70), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (67->70),(70->75), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (70->75),(75->80), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (75->80),(80->85), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (80->85),(85->90), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (85->90),(90->95), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (90->95),(95->100), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (95->100),(100->105), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (100->105),(105->110), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (105->110),(110->115), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (110->115),(115->120), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (115->120),(120->125), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (120->125),(125->130), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (125->130),(130->132), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (130->132),(132->135), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# si: 558, edge: (132->135),(135->140), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (135->140),(140->145), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (140->145),(145->150), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (145->150),(150->155), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (150->155),(155->160), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (155->160),(160->165), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (160->165),(165->170), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (165->170),(170->175), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (170->175),(175->180), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (175->180),(180->185), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (180->185),(185->190), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (185->190),(190->195), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (190->195),(195->200), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (195->200),(200->205), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (200->205),(205->210), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (205->210),(210->215), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (210->215),(215->220), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (215->220),(220->225), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (220->225),(225->230), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (225->230),(230->235), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (230->235),(235->240), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (235->240),(240->245), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (240->245),(245->250), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (245->250),(250->255), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (250->255),(255->260), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (255->260),(260->265), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (260->265),(265->270), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (265->270),(270->275), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (270->275),(275->280), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (275->280),(280->285), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (280->285),(285->290), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (285->290),(290->295), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (290->295),(295->300), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (295->300),(300->305), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (300->305),(305->310), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (305->310),(310->315), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (310->315),(315->320), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (315->320),(320->325), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (320->325),(325->330), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (325->330),(330->335), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (330->335),(335->340), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (335->340),(340->345), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (340->345),(345->350), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (345->350),(350->355), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (350->355),(355->360), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (355->360),(360->365), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (360->365),(365->370), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (365->370),(370->375), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (370->375),(375->380), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (375->380),(380->385), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (380->385),(385->390), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (385->390),(390->395), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (390->395),(395->400), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (395->400),(400->405), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (400->405),(405->410), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (405->410),(410->415), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (410->415),(415->420), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (415->420),(420->425), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (420->425),(425->430), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (425->430),(430->435), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (430->435),(435->440), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (435->440),(440->445), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (440->445),(445->450), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (445->450),(450->455), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (450->455),(455->460), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (455->460),(460->465), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (460->465),(465->470), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (465->470),(470->475), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (470->475),(475->480), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (475->480),(480->485), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (480->485),(485->490), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (485->490),(490->495), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (490->495),(495->500), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (495->500),(500->505), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (500->505),(505->510), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (505->510),(510->515), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (510->515),(515->520), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (515->520),(520->525), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (520->525),(525->530), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (525->530),(530->535), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (530->535),(535->540), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (535->540),(540->545), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (540->545),(545->550), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (545->550),(550->555), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (550->555),(555->560), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (555->560),(560->565), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (560->565),(565->570), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (565->570),(570->575), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (570->575),(575->580), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (575->580),(580->585), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (580->585),(585->590), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (585->590),(590->595), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (590->595),(595->600), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (595->600),(600->605), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (600->605),(605->610), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (605->610),(610->615), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (610->615),(615->620), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (615->620),(620->625), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (620->625),(625->630), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (625->630),(630->635), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (630->635),(635->640), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (635->640),(640->645), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (640->645),(645->650), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (645->650),(650->655), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (650->655),(655->660), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (655->660),(660->665), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (660->665),(665->670), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (665->670),(670->675), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (670->675),(675->680), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (675->680),(680->685), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (680->685),(685->690), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (685->690),(690->695), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (690->695),(695->700), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (695->700),(700->705), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (700->705),(705->710), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (705->710),(710->715), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (710->715),(715->720), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (715->720),(720->725), tin: 00:00:00, tout: 00:00:00
# si: 558, edge: (720->725),(725_end), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# penalty: 0
# si: 560, edge: (1_beginning),(1->5), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (1->5),(5->10), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (5->10),(10->15), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (10->15),(15->20), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (15->20),(20->25), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (20->25),(25->30), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (25->30),(30->35), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (30->35),(35->40), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (35->40),(40->45), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (40->45),(45->50), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (45->50),(50->55), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (50->55),(55->60), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (55->60),(60->65), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (60->65),(65->67), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (65->67),(67->70), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (67->70),(70->75), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (70->75),(75->80), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (75->80),(80->85), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (80->85),(85->90), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (85->90),(90->95), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (90->95),(95->100), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (95->100),(100->105), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (100->105),(105->110), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (105->110),(110->115), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (110->115),(115->120), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (115->120),(120->125), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (120->125),(125->130), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (125->130),(130->132), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (130->132),(132->135), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# si: 560, edge: (132->135),(135->140), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (135->140),(140->145), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (140->145),(145->150), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (145->150),(150->155), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (150->155),(155->160), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (155->160),(160->165), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (160->165),(165->170), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (165->170),(170->175), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (170->175),(175->180), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (175->180),(180->185), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (180->185),(185->190), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (185->190),(190->195), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (190->195),(195->200), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (195->200),(200->205), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (200->205),(205->210), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (205->210),(210->215), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (210->215),(215->220), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (215->220),(220->225), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (220->225),(225->230), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (225->230),(230->235), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (230->235),(235->240), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (235->240),(240->245), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (240->245),(245->250), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (245->250),(250->255), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (250->255),(255->260), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (255->260),(260->265), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (260->265),(265->270), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (265->270),(270->275), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (270->275),(275->280), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (275->280),(280->285), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (280->285),(285->290), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (285->290),(290->295), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (290->295),(295->300), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (295->300),(300->305), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (300->305),(305->310), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (305->310),(310->315), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (310->315),(315->320), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (315->320),(320->325), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (320->325),(325->330), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (325->330),(330->335), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (330->335),(335->340), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (335->340),(340->345), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (340->345),(345->350), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (345->350),(350->355), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (350->355),(355->360), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (355->360),(360->365), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (360->365),(365->370), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (365->370),(370->375), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (370->375),(375->380), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (375->380),(380->385), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (380->385),(385->390), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (385->390),(390->395), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (390->395),(395->400), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (395->400),(400->405), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (400->405),(405->410), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (405->410),(410->415), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (410->415),(415->420), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (415->420),(420->425), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (420->425),(425->430), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (425->430),(430->435), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (430->435),(435->440), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (435->440),(440->445), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (440->445),(445->450), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (445->450),(450->455), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (450->455),(455->460), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (455->460),(460->465), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (460->465),(465->470), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (465->470),(470->475), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (470->475),(475->480), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (475->480),(480->485), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (480->485),(485->490), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (485->490),(490->495), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (490->495),(495->500), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (495->500),(500->505), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (500->505),(505->510), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (505->510),(510->515), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (510->515),(515->520), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (515->520),(520->525), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (520->525),(525->530), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (525->530),(530->535), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (530->535),(535->540), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (535->540),(540->545), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (540->545),(545->550), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (545->550),(550->555), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (550->555),(555->560), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (555->560),(560->565), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (560->565),(565->570), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (565->570),(570->575), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (570->575),(575->580), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (575->580),(580->585), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (580->585),(585->590), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (585->590),(590->595), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (590->595),(595->600), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (595->600),(600->605), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (600->605),(605->610), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (605->610),(610->615), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (610->615),(615->620), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (615->620),(620->625), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (620->625),(625->630), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (625->630),(630->635), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (630->635),(635->640), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (635->640),(640->645), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (640->645),(645->650), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (645->650),(650->655), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (650->655),(655->660), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (655->660),(660->665), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (660->665),(665->670), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (665->670),(670->675), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (670->675),(675->680), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (675->680),(680->685), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (680->685),(685->690), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (685->690),(690->695), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (690->695),(695->700), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (695->700),(700->705), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (700->705),(705->710), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (705->710),(710->715), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (710->715),(715->720), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (715->720),(720->725), tin: 00:00:00, tout: 00:00:00
# si: 560, edge: (720->725),(725_end), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# penalty: 0
# si: 562, edge: (1_beginning),(1->5), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (1->5),(5->10), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (5->10),(10->15), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (10->15),(15->20), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (15->20),(20->25), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (20->25),(25->30), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (25->30),(30->35), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (30->35),(35->40), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (35->40),(40->45), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (40->45),(45->50), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (45->50),(50->55), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (50->55),(55->60), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (55->60),(60->65), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (60->65),(65->67), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (65->67),(67->70), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (67->70),(70->75), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (70->75),(75->80), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (75->80),(80->85), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (80->85),(85->90), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (85->90),(90->95), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (90->95),(95->100), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (95->100),(100->105), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (100->105),(105->110), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (105->110),(110->115), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (110->115),(115->120), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (115->120),(120->125), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (120->125),(125->130), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (125->130),(130->132), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (130->132),(132->135), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# si: 562, edge: (132->135),(135->140), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (135->140),(140->145), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (140->145),(145->150), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (145->150),(150->155), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (150->155),(155->160), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (155->160),(160->165), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (160->165),(165->170), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (165->170),(170->175), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (170->175),(175->180), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (175->180),(180->185), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (180->185),(185->190), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (185->190),(190->195), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (190->195),(195->200), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (195->200),(200->205), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (200->205),(205->210), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (205->210),(210->215), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (210->215),(215->220), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (215->220),(220->225), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (220->225),(225->230), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (225->230),(230->235), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (230->235),(235->240), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (235->240),(240->245), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (240->245),(245->250), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (245->250),(250->255), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (250->255),(255->260), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (255->260),(260->265), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (260->265),(265->270), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (265->270),(270->275), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (270->275),(275->280), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (275->280),(280->285), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (280->285),(285->290), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (285->290),(290->295), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (290->295),(295->300), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (295->300),(300->305), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (300->305),(305->310), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (305->310),(310->315), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (310->315),(315->320), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (315->320),(320->325), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (320->325),(325->330), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (325->330),(330->335), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (330->335),(335->340), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (335->340),(340->345), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (340->345),(345->350), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (345->350),(350->355), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (350->355),(355->360), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (355->360),(360->365), tin: 00:00:00, tout: 00:00:00
# si: 562, edge: (360->365),(365->370), tin: 00:00:00, tout: 00:00:00
# ...
# si: 8221, edge: (445->450),(450->455), tin: 00:00:00, tout: 00:00:00
# si: 8221, edge: (450->455),(455->460), tin: 00:00:00, tout: 00:00:00
# si: 8221, edge: (455->460),(460->465), tin: 00:00:00, tout: 00:00:00
# si: 8221, edge: (460->465),(465_end), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# penalty: 0
# si: 8223, edge: (335_beginning),(335->340), tin: 00:00:00, tout: 00:00:00
# si: 8223, edge: (335->340),(340->345), tin: 00:00:00, tout: 00:00:00
# si: 8223, edge: (340->345),(345->350), tin: 00:00:00, tout: 00:00:00
# si: 8223, edge: (345->350),(350->355), tin: 00:00:00, tout: 00:00:00
# si: 8223, edge: (350->355),(355->360), tin: 00:00:00, tout: 00:00:00
# si: 8223, edge: (355->360),(360->365), tin: 00:00:00, tout: 00:00:00
# si: 8223, edge: (360->365),(365->370), tin: 00:00:00, tout: 00:00:00
# si: 8223, edge: (365->370),(370->375), tin: 00:00:00, tout: 00:00:00
# si: 8223, edge: (370->375),(375->380), tin: 00:00:00, tout: 00:00:00
# si: 8223, edge: (375->380),(380->385), tin: 00:00:00, tout: 00:00:00
# si: 8223, edge: (380->385),(385->390), tin: 00:00:00, tout: 00:00:00
# si: 8223, edge: (385->390),(390->392), tin: 00:00:00, tout: 00:00:00
# si: 8223, edge: (390->392),(392->395), tin: 00:00:00, tout: 00:00:00
# si: 8223, edge: (392->395),(395->400), tin: 00:00:00, tout: 00:00:00
# si: 8223, edge: (395->400),(400->405), tin: 00:00:00, tout: 00:00:00
# si: 8223, edge: (400->405),(405->410), tin: 00:00:00, tout: 00:00:00
# si: 8223, edge: (405->410),(410->412), tin: 00:00:00, tout: 00:00:00
# si: 8223, edge: (410->412),(412->415), tin: 00:00:00, tout: 00:00:00
# si: 8223, edge: (412->415),(415->420), tin: 00:00:00, tout: 00:00:00
# si: 8223, edge: (415->420),(420->425), tin: 00:00:00, tout: 00:00:00
# si: 8223, edge: (420->425),(425->430), tin: 00:00:00, tout: 00:00:00
# si: 8223, edge: (425->430),(430->435), tin: 00:00:00, tout: 00:00:00
# si: 8223, edge: (430->435),(435->440), tin: 00:00:00, tout: 00:00:00
# si: 8223, edge: (435->440),(440->442), tin: 00:00:00, tout: 00:00:00
# si: 8223, edge: (440->442),(442->445), tin: 00:00:00, tout: 00:00:00
# si: 8223, edge: (442->445),(445->450), tin: 00:00:00, tout: 00:00:00
# si: 8223, edge: (445->450),(450->455), tin: 00:00:00, tout: 00:00:00
# si: 8223, edge: (450->455),(455->460), tin: 00:00:00, tout: 00:00:00
# si: 8223, edge: (455->460),(460->465), tin: 00:00:00, tout: 00:00:00
# si: 8223, edge: (460->465),(465_end), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# penalty: 0
# si: 19320, edge: (5_beginning),(5->10), tin: 00:00:00, tout: 00:00:00
# si: 19320, edge: (5->10),(10->15), tin: 00:00:00, tout: 00:00:00
# si: 19320, edge: (10->15),(15->20), tin: 00:00:00, tout: 00:00:00
# si: 19320, edge: (15->20),(20->25), tin: 00:00:00, tout: 00:00:00
# si: 19320, edge: (20->25),(25_end), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# si: 19322, edge: (5_beginning),(5->10), tin: 00:00:00, tout: 00:00:00
# si: 19322, edge: (5->10),(10->15), tin: 00:00:00, tout: 00:00:00
# si: 19322, edge: (10->15),(15->20), tin: 00:00:00, tout: 00:00:00
# si: 19322, edge: (15->20),(20->25), tin: 00:00:00, tout: 00:00:00
# si: 19322, edge: (20->25),(25_end), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# si: 19319, edge: (10_beginning),(10->15), tin: 00:00:00, tout: 00:00:00
# si: 19319, edge: (10->15),(15->20), tin: 00:00:00, tout: 00:00:00
# si: 19319, edge: (15->20),(20->25), tin: 00:00:00, tout: 00:00:00
# si: 19319, edge: (20->25),(25_end), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# penalty: 0
# si: 18013, edge: (10_beginning),(10->15), tin: 00:00:00, tout: 00:00:00
# si: 18013, edge: (10->15),(15->20), tin: 00:00:00, tout: 00:00:00
# si: 18013, edge: (15->20),(20->25), tin: 00:00:00, tout: 00:00:00
# si: 18013, edge: (20->25),(25_end), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# penalty: 0
# si: 16919, edge: (5_beginning),(5->10), tin: 00:00:00, tout: 00:00:00
# si: 16919, edge: (5->10),(10->15), tin: 00:00:00, tout: 00:00:00
# si: 16919, edge: (10->15),(15->17), tin: 00:00:00, tout: 00:00:00
# si: 16919, edge: (15->17),(17->20), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# si: 16919, edge: (17->20),(20->25), tin: 00:00:00, tout: 00:00:00
# si: 16919, edge: (20->25),(25->30), tin: 00:00:00, tout: 00:00:00
# si: 16919, edge: (25->30),(30->35), tin: 00:00:00, tout: 00:00:00
# si: 16919, edge: (30->35),(35->40), tin: 00:00:00, tout: 00:00:00
# si: 16919, edge: (35->40),(40_end), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# si: 16920, edge: (5_beginning),(5->10), tin: 00:00:00, tout: 00:00:00
# si: 16920, edge: (5->10),(10->15), tin: 00:00:00, tout: 00:00:00
# si: 16920, edge: (10->15),(15->20), tin: 00:00:00, tout: 00:00:00
# si: 16920, edge: (15->20),(20->25), tin: 00:00:00, tout: 00:00:00
# si: 16920, edge: (20->25),(25->27), tin: 00:00:00, tout: 00:00:00
# si: 16920, edge: (25->27),(27->30), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# si: 16920, edge: (27->30),(30->35), tin: 00:00:00, tout: 00:00:00
# si: 16920, edge: (30->35),(35->40), tin: 00:00:00, tout: 00:00:00
# si: 16920, edge: (35->40),(40_end), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# si: 16921, edge: (5_beginning),(5->10), tin: 00:00:00, tout: 00:00:00
# si: 16921, edge: (5->10),(10->15), tin: 00:00:00, tout: 00:00:00
# si: 16921, edge: (10->15),(15->17), tin: 00:00:00, tout: 00:00:00
# si: 16921, edge: (15->17),(17->20), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# si: 16921, edge: (17->20),(20->25), tin: 00:00:00, tout: 00:00:00
# si: 16921, edge: (20->25),(25->30), tin: 00:00:00, tout: 00:00:00
# si: 16921, edge: (25->30),(30->35), tin: 00:00:00, tout: 00:00:00
# si: 16921, edge: (30->35),(35->40), tin: 00:00:00, tout: 00:00:00
# si: 16921, edge: (35->40),(40_end), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# si: 16922, edge: (5_beginning),(5->10), tin: 00:00:00, tout: 00:00:00
# si: 16922, edge: (5->10),(10->15), tin: 00:00:00, tout: 00:00:00
# si: 16922, edge: (10->15),(15->20), tin: 00:00:00, tout: 00:00:00
# si: 16922, edge: (15->20),(20->25), tin: 00:00:00, tout: 00:00:00
# si: 16922, edge: (20->25),(25->27), tin: 00:00:00, tout: 00:00:00
# si: 16922, edge: (25->27),(27->30), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# si: 16922, edge: (27->30),(30->35), tin: 00:00:00, tout: 00:00:00
# si: 16922, edge: (30->35),(35->40), tin: 00:00:00, tout: 00:00:00
# si: 16922, edge: (35->40),(40_end), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# si: 23428, edge: (315_beginning),(315->320), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (315->320),(320->330), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (320->330),(330->335), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (330->335),(335->340), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (335->340),(340->345), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (340->345),(345->350), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (345->350),(350->355), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (350->355),(355->400), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (355->400),(400->402), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (400->402),(402->405), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# si: 23428, edge: (402->405),(405->410), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (405->410),(410->415), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (410->415),(415->420), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (415->420),(420->425), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (420->425),(425->430), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (425->430),(430->435), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (430->435),(435->440), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (435->440),(440->445), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (440->445),(445->450), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (445->450),(450->452), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (450->452),(452->455), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (452->455),(455->460), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (455->460),(460->465), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (460->465),(465->470), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (465->470),(470->475), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (470->475),(475->477), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (475->477),(477->480), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (477->480),(480->485), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (480->485),(485->490), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (485->490),(490->492), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (490->492),(492->495), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (492->495),(495->500), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (495->500),(500->502), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (500->502),(502->505), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (502->505),(505->510), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (505->510),(510->515), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (510->515),(515->517), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (515->517),(517->520), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (517->520),(520->525), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (520->525),(525->530), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (525->530),(530->535), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (530->535),(535->537), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (535->537),(537->540), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (537->540),(540->545), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (540->545),(545->550), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (545->550),(550->555), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (550->555),(555->560), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (555->560),(560->562), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (560->562),(562->565), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (562->565),(565->570), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (565->570),(570->575), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (570->575),(575->580), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (575->580),(580->585), tin: 00:00:00, tout: 00:00:00
# si: 23428, edge: (580->585),(585_end), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# penalty: 0
# si: 23432, edge: (315_beginning),(315->320), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (315->320),(320->330), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (320->330),(330->335), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (330->335),(335->340), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (335->340),(340->345), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (340->345),(345->350), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (345->350),(350->355), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (350->355),(355->400), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (355->400),(400->402), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (400->402),(402->405), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# si: 23432, edge: (402->405),(405->410), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (405->410),(410->415), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (410->415),(415->420), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (415->420),(420->425), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (420->425),(425->430), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (425->430),(430->435), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (430->435),(435->440), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (435->440),(440->445), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (440->445),(445->450), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (445->450),(450->452), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (450->452),(452->455), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (452->455),(455->460), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (455->460),(460->465), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (460->465),(465->470), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (465->470),(470->475), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (470->475),(475->477), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (475->477),(477->480), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (477->480),(480->485), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (480->485),(485->490), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (485->490),(490->492), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (490->492),(492->495), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (492->495),(495->500), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (495->500),(500->502), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (500->502),(502->505), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (502->505),(505->510), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (505->510),(510->515), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (510->515),(515->517), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (515->517),(517->520), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (517->520),(520->525), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (520->525),(525->530), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (525->530),(530->535), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (530->535),(535->537), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (535->537),(537->540), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (537->540),(540->545), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (540->545),(545->550), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (545->550),(550->555), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (550->555),(555->560), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (555->560),(560->562), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (560->562),(562->565), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (562->565),(565->570), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (565->570),(570->575), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (570->575),(575->580), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (575->580),(580->585), tin: 00:00:00, tout: 00:00:00
# si: 23432, edge: (580->585),(585_end), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# penalty: 0
# si: 23617, edge: (315_beginning),(315->320), tin: 00:00:00, tout: 00:00:00
# si: 23617, edge: (315->320),(320->325), tin: 00:00:00, tout: 00:00:00
# si: 23617, edge: (320->325),(325->330), tin: 00:00:00, tout: 00:00:00
# si: 23617, edge: (325->330),(330->335), tin: 00:00:00, tout: 00:00:00
# si: 23617, edge: (330->335),(335->340), tin: 00:00:00, tout: 00:00:00
# si: 23617, edge: (335->340),(340->345), tin: 00:00:00, tout: 00:00:00
# si: 23617, edge: (340->345),(345->350), tin: 00:00:00, tout: 00:00:00
# si: 23617, edge: (345->350),(350->355), tin: 00:00:00, tout: 00:00:00
# si: 23617, edge: (350->355),(355->400), tin: 00:00:00, tout: 00:00:00
# si: 23617, edge: (355->400),(400->402), tin: 00:00:00, tout: 00:00:00
# si: 23617, edge: (400->402),(402->405), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# si: 23617, edge: (402->405),(405->410), tin: 00:00:00, tout: 00:00:00
# si: 23617, edge: (405->410),(410->415), tin: 00:00:00, tout: 00:00:00
# si: 23617, edge: (410->415),(415->420), tin: 00:00:00, tout: 00:00:00
# si: 23617, edge: (415->420),(420_end), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# penalty: 0
# si: 23621, edge: (315_beginning),(315->320), tin: 00:00:00, tout: 00:00:00
# si: 23621, edge: (315->320),(320->325), tin: 00:00:00, tout: 00:00:00
# si: 23621, edge: (320->325),(325->330), tin: 00:00:00, tout: 00:00:00
# si: 23621, edge: (325->330),(330->335), tin: 00:00:00, tout: 00:00:00
# si: 23621, edge: (330->335),(335->340), tin: 00:00:00, tout: 00:00:00
# si: 23621, edge: (335->340),(340->345), tin: 00:00:00, tout: 00:00:00
# si: 23621, edge: (340->345),(345->350), tin: 00:00:00, tout: 00:00:00
# si: 23621, edge: (345->350),(350->355), tin: 00:00:00, tout: 00:00:00
# si: 23621, edge: (350->355),(355->400), tin: 00:00:00, tout: 00:00:00
# si: 23621, edge: (355->400),(400->402), tin: 00:00:00, tout: 00:00:00
# si: 23621, edge: (400->402),(402->405), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# si: 23621, edge: (402->405),(405->410), tin: 00:00:00, tout: 00:00:00
# si: 23621, edge: (405->410),(410->415), tin: 00:00:00, tout: 00:00:00
# si: 23621, edge: (410->415),(415->420), tin: 00:00:00, tout: 00:00:00
# si: 23621, edge: (415->420),(420_end), tin: 00:00:00, tout: 00:00:00
# penalty: 0
# penalty: 0

# %%
non_binary = []
for i in range(total_length):
    if i not in bool_idx:
        non_binary.append(i)

# %%
#def solve_mosek(At, b, bool_idx):
from mosek.fusion import *
import sys

with Model() as M:
    

    x = M.variable('x',  total_length  , Domain.greaterThan(0.0))#Domain.binary())

    for idx in bool_idx:
        x.index(idx).makeInteger()
        M.constraint(x.index(idx), Domain.lessThan(1.5))
    M.constraint('c1', Expr.mul(At, x), Domain.lessThan(bt))
    print(x.getShape())
    # Set the objective function to (c^T * x)
    M.objective('obj', ObjectiveSense.Minimize, Expr.dot(c, x))

    # Assign values to integer variables.
    # We only set a slice of xx
    #init_sol = [1.0, 1.0, 0.0]
    #x.slice(0,3).setLevel(init_sol)

    # Solve the problem
    M.setLogHandler(sys.stdout)
    M.solve()

    # Get the solution values
    ss = M.getPrimalSolutionStatus()
    print("Solution status: {0}".format(ss))
    sol = x.level()
    print('x = {0}'.format(sol))

    # Was the initial solution used?
    constr = M.getSolverIntInfo("mioConstructSolution")
    constrVal = M.getSolverDoubleInfo("mioConstructSolutionObj")
    print("Initial solution utilization: {0}\nInitial solution objective: {1:.3f}\n".format(constr, constrVal))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-9a683e85c184> in <module>
#      11         x.index(idx).makeInteger()
#      12         M.constraint(x.index(idx), Domain.lessThan(1.5))
# ---> 13     M.constraint('c1', Expr.mul(At, x), Domain.lessThan(bt))
#      14     print(x.getShape())
#      15     # Set the objective function to (c^T * x)
#
# ~/.local/lib/python3.6/site-packages/mosek/fusion/impl/_implementation.py in mul(*args)
#   29964       return mosek_fusion_Expr._mul_alt_Lmosek_4fusion_4Expression_2D(*args)
#   29965     else:
# > 29966       raise ValueError('Invalid argument list mul('+','.join(map(repr,args))+'). Candidates are\n\tmosek.fusion.Expr.mul(mosek.fusion.Expression,array(double,ndim=1))\n\tmosek.fusion.Expr.mul(mosek.fusion.Matrix,mosek.fusion.Variable)\n\tmosek.fusion.Expr.mul(array(double,ndim=1),mosek.fusion.Expression)\n\tmosek.fusion.Expr.mul(double,mosek.fusion.Expression)\n\tmosek.fusion.Expr.mul(mosek.fusion.Matrix,mosek.fusion.Expression)\n\tmosek.fusion.Expr.mul(mosek.fusion.Expression,mosek.fusion.Parameter)\n\tmosek.fusion.Expr.mul(mosek.fusion.Variable,mosek.fusion.Matrix)\n\tmosek.fusion.Expr.mul(mosek.fusion.Parameter,mosek.fusion.Expression)\n\tmosek.fusion.Expr.mul(array(double,ndim=2),mosek.fusion.Expression)\n\tmosek.fusion.Expr.mul(mosek.fusion.Expression,mosek.fusion.Matrix)\n\tmosek.fusion.Expr.mul(mosek.fusion.Expression,array(double,ndim=2))\n\tmosek.fusion.Expr.mul(mosek.fusion.Expression,double)')
#   29967   @staticmethod
#   29968   def repeat(*args):
#
# ValueError: Invalid argument list mul(<245424x60054 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1120265 stored elements in COOrdinate format>,mosek.fusion.LinearVariable). Candidates are
# 	mosek.fusion.Expr.mul(mosek.fusion.Expression,array(double,ndim=1))
# 	mosek.fusion.Expr.mul(mosek.fusion.Matrix,mosek.fusion.Variable)
# 	mosek.fusion.Expr.mul(array(double,ndim=1),mosek.fusion.Expression)
# 	mosek.fusion.Expr.mul(double,mosek.fusion.Expression)
# 	mosek.fusion.Expr.mul(mosek.fusion.Matrix,mosek.fusion.Expression)
# 	mosek.fusion.Expr.mul(mosek.fusion.Expression,mosek.fusion.Parameter)
# 	mosek.fusion.Expr.mul(mosek.fusion.Variable,mosek.fusion.Matrix)
# 	mosek.fusion.Expr.mul(mosek.fusion.Parameter,mosek.fusion.Expression)
# 	mosek.fusion.Expr.mul(array(double,ndim=2),mosek.fusion.Expression)
# 	mosek.fusion.Expr.mul(mosek.fusion.Expression,mosek.fusion.Matrix)
# 	mosek.fusion.Expr.mul(mosek.fusion.Expression,array(double,ndim=2))
# 	mosek.fusion.Expr.mul(mosek.fusion.Expression,double)

# %%
sol

# %%
j=0
con=9
for i in bool_idx:
    if j == con:
        j=0
        print('----')
        if con==9:
            con=14
        else:
            con=9
    j+=1
    print(sol[i], x.value[i])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-83-a3858cce7161> in <module>
#      10             con=9
#      11     j+=1
# ---> 12     print(sol[i], x.value[i])
#
# AttributeError: 'LinearVariable' object has no attribute 'value'

# %%
x_star = x.value
g = A_coup@x_star-b_coup
np.linalg.norm(g,2)
# Out:
# 8540536.510722203

# %%
lam = np.zeros(len(b_coup))
errors = []
xvals = []
for i in range(100):

    bool_vars_idx = [(x,) for x in bool_idx]

    x = cp.Variable(A.shape[1], boolean = bool_vars_idx)

    p = cp.Problem(cp.Minimize(c.T@x - lam.T@(A_coup@x - b_coup) ),
                     [A@x<=b])
    p = p.solve(solver = 'MOSEK', verbose = False)

    
    x = x.value
    xvals.append(x)
    
    g = A_coup@x-b_coup
    errors.append(np.linalg.norm(g,2))

    bool_vars_idx = [(x,) for x in bool_idx]

    lam = cp.Variable(len(b_coup))

    p = cp.Problem(cp.Maximize(lam.T@(A_coup@x - b_coup) ),
                     [lam >=0, c.T + lam.T@A_coup >=0])
    p = p.solve(solver = 'MOSEK', verbose = False)
    
    lam = lam.value

# %%
vecerrors = np.array([np.linalg.norm(v-x_star,2) for v in xvals])
vecerrors/=max(vecerrors)
errors = np.array(errors)
errors /= max(errors)

# %%
err
# Out:
# 1.0

# %%
import matplotlib.pyplot as plt
plt.plot(errors)
plt.plot(vecerrors)

# %%
x = cp.Variable(A_coup.shape[1], boolean = bool_vars_idx)
p = cp.Problem(cp.Minimize(c.T@x) ,
                 [A_coup@x<=b_coup])
p = p.solve(solver = 'MOSEK', verbose = True)
# Out:
# ===============================================================================
#                                      CVXPY
#                                     v1.1.14
# ===============================================================================
# (CVXPY) Aug 22 05:57:40 PM: Your problem has 318 variables, 1 constraints, and 0 parameters.
# (CVXPY) Aug 22 05:57:40 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Aug 22 05:57:40 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Aug 22 05:57:40 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Aug 22 05:57:40 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Aug 22 05:57:40 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Aug 22 05:57:40 PM: Applying reduction Dcp2Cone
# (CVXPY) Aug 22 05:57:40 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Aug 22 05:57:40 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Aug 22 05:57:40 PM: Applying reduction MOSEK
# (CVXPY) Aug 22 05:57:40 PM: Finished problem compilation (took 1.912e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Aug 22 05:57:40 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : LO (linear optimization problem)
#   Constraints            : 1296
#   Cones                  : 0
#   Scalar variables       : 318
#   Matrix variables       : 0
#   Integer variables      : 60
#
# Optimizer started.
# Mixed integer optimizer started.
# Threads used: 4
# Presolve started.
# Presolve terminated. Time = 0.00
# Presolved problem: 295 variables, 1296 constraints, 5184 non-zeros
# Presolved problem: 60 general integer, 0 binary, 235 continuous
# Clique table size: 0
# BRANCHES RELAXS   ACT_NDS  DEPTH    BEST_INT_OBJ         BEST_RELAX_OBJ       REL_GAP(%)  TIME
#
# Objective of best integer solution : Not available.
# Best objective bound               : Not available.
# Construct solution objective       : Not employed
# User objective cut value           : Not employed
# Number of cuts generated           : 0
# Number of branches                 : 0
# Number of relaxations solved       : 0
# Number of interior point iterations: 0
# Number of simplex iterations       : 0
# Time spend presolving the root     : 0.00
# Time spend optimizing the root     : 0.00
# Mixed integer optimizer terminated. Time: 0.01
#
# Optimizer terminated. Time: 0.02
#
#
# Integer solution solution summary
#   Problem status  : PRIMAL_INFEASIBLE_OR_UNBOUNDED
#   Solution status : UNKNOWN
#   Primal.  obj: 0.0000000000e+00    nrm: 0e+00    Viol.  con: 0e+00    var: 0e+00    itg: 0e+00
# ---------------------------------------------------------------------------
# SolverError                               Traceback (most recent call last)
# <ipython-input-101-be24e43d5c6a> in <module>
#       2 p = cp.Problem(cp.Minimize(c.T@x) ,
#       3                  [A_coup@x<=b_coup])
# ----> 4 p = p.solve(solver = 'MOSEK', verbose = True)
#
# ~/.local/lib/python3.6/site-packages/cvxpy/problems/problem.py in solve(self, *args, **kwargs)
#     460         else:
#     461             solve_func = Problem._solve
# --> 462         return solve_func(self, *args, **kwargs)
#     463
#     464     @classmethod
#
# ~/.local/lib/python3.6/site-packages/cvxpy/problems/problem.py in _solve(self, solver, warm_start, verbose, gp, qcp, requires_grad, enforce_dpp, **kwargs)
#     960         end = time.time()
#     961         self._solve_time = end - start
# --> 962         self.unpack_results(solution, solving_chain, inverse_data)
#     963         if verbose:
#     964             print(_FOOTER)
#
# ~/.local/lib/python3.6/site-packages/cvxpy/problems/problem.py in unpack_results(self, solution, chain, inverse_data)
#    1284             raise error.SolverError(
#    1285                     "Solver '%s' failed. " % chain.solver.name() +
# -> 1286                     "Try another solver, or solve with verbose=True for more "
#    1287                     "information.")
#    1288
#
# SolverError: Solver 'MOSEK' failed. Try another solver, or solve with verbose=True for more information.

# %%
lam = np.zeros(len(b_coup))
A=np.vstack((A,A_coup))
b = np.hstack((b, b_coup))
bool_vars_idx = [(x,) for x in bool_idx]

x = cp.Variable(A.shape[1], boolean = bool_vars_idx)

p = cp.Problem(cp.Minimize(c.T@x),
                 [A@x<=b])
p.solve(solver = 'MOSEK', verbose = True)

lam = cp.Variable(len(b))

d = cp.Problem(cp.Maximize(-b.T@lam),
                 [A.T@lam + c ==0, lam >=0 ])
d.solve(solver = 'MOSEK', verbose = True)
# Out:
# ===============================================================================
#                                      CVXPY
#                                     v1.1.14
# ===============================================================================
# (CVXPY) Aug 22 05:51:37 PM: Your problem has 318 variables, 1 constraints, and 0 parameters.
# (CVXPY) Aug 22 05:51:37 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Aug 22 05:51:37 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Aug 22 05:51:37 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Aug 22 05:51:37 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Aug 22 05:51:37 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Aug 22 05:51:37 PM: Applying reduction Dcp2Cone
# (CVXPY) Aug 22 05:51:37 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Aug 22 05:51:37 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Aug 22 05:51:37 PM: Applying reduction MOSEK
# (CVXPY) Aug 22 05:51:37 PM: Finished problem compilation (took 1.942e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Aug 22 05:51:37 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : LO (linear optimization problem)
#   Constraints            : 2167
#   Cones                  : 0
#   Scalar variables       : 318
#   Matrix variables       : 0
#   Integer variables      : 60
#
# Optimizer started.
# Mixed integer optimizer started.
# Threads used: 4
# Presolve started.
# Presolve terminated. Time = 0.01
# Presolved problem: 188 variables, 1583 constraints, 7188 non-zeros
# Presolved problem: 0 general integer, 32 binary, 156 continuous
# Clique table size: 2
# BRANCHES RELAXS   ACT_NDS  DEPTH    BEST_INT_OBJ         BEST_RELAX_OBJ       REL_GAP(%)  TIME
# 0        1        1        0        NA                   0.0000000000e+00     NA          0.1
# 0        1        1        0        0.0000000000e+00     0.0000000000e+00     0.00e+00    0.1
# An optimal solution satisfying the relative gap tolerance of 1.00e-02(%) has been located.
# The relative gap is 0.00e+00(%).
# An optimal solution satisfying the absolute gap tolerance of 0.00e+00 has been located.
# The absolute gap is 0.00e+00.
#
# Objective of best integer solution : 0.000000000000e+00
# Best objective bound               : 0.000000000000e+00
# Construct solution objective       : Not employed
# User objective cut value           : Not employed
# Number of cuts generated           : 0
# Number of branches                 : 0
# Number of relaxations solved       : 1
# Number of interior point iterations: 20
# Number of simplex iterations       : 0
# Time spend presolving the root     : 0.01
# Time spend optimizing the root     : 0.03
# Mixed integer optimizer terminated. Time: 0.07
#
# Optimizer terminated. Time: 0.10
#
#
# Integer solution solution summary
#   Problem status  : PRIMAL_FEASIBLE
#   Solution status : INTEGER_OPTIMAL
#   Primal.  obj: 0.0000000000e+00    nrm: 2e+05    Viol.  con: 0e+00    var: 0e+00    itg: 0e+00
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Aug 22 05:51:37 PM: Problem status: optimal
# (CVXPY) Aug 22 05:51:37 PM: Optimal value: 0.000e+00
# (CVXPY) Aug 22 05:51:37 PM: Compilation took 1.942e-02 seconds
# (CVXPY) Aug 22 05:51:37 PM: Solver (including time spent in interface) took 1.143e-01 seconds
# ===============================================================================
#                                      CVXPY
#                                     v1.1.14
# ===============================================================================
# (CVXPY) Aug 22 05:51:37 PM: Your problem has 2167 variables, 2 constraints, and 0 parameters.
# (CVXPY) Aug 22 05:51:37 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Aug 22 05:51:37 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Aug 22 05:51:37 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Aug 22 05:51:37 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Aug 22 05:51:37 PM: Reduction chain: FlipObjective -> Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Aug 22 05:51:37 PM: Applying reduction FlipObjective
# (CVXPY) Aug 22 05:51:37 PM: Applying reduction Dcp2Cone
# (CVXPY) Aug 22 05:51:37 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Aug 22 05:51:37 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Aug 22 05:51:37 PM: Applying reduction MOSEK
# (CVXPY) Aug 22 05:51:37 PM: Finished problem compilation (took 6.905e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Aug 22 05:51:37 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : LO (linear optimization problem)
#   Constraints            : 2167
#   Cones                  : 0
#   Scalar variables       : 2485
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : LO (linear optimization problem)
#   Constraints            : 2167
#   Cones                  : 0
#   Scalar variables       : 2485
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the dual
# Optimizer  - Constraints            : 188
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 1656              conic                  : 0
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Factor     - setup time             : 0.00              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 4157              after factor           : 6398
# Factor     - dense dim.             : 0                 flops                  : 3.60e+05
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   2.3e+08  1.2e+05  2.5e+11  0.00e+00   0.000000000e+00   3.223736820e+08   6.0e+05  0.01
# 1   2.3e+07  1.2e+04  2.5e+10  -1.00e+00  -7.146426950e+02  3.223651025e+08   5.9e+04  0.03
# 2   1.9e+06  9.9e+02  2.0e+09  -1.00e+00  -9.937526481e+03  3.222126408e+08   4.9e+03  0.04
# 3   2.6e+04  1.3e+01  2.8e+07  -9.99e-01  -7.036613498e+05  3.062171109e+08   6.6e+01  0.04
# 4   2.7e+02  1.4e-01  2.9e+05  -9.04e-01  -1.187130396e+07  4.360742281e+07   6.9e-01  0.05
# 5   3.0e+01  1.5e-02  3.2e+04  6.91e-01   -3.720513116e+06  3.323155675e+06   7.6e-02  0.05
# 6   4.5e+00  2.4e-03  4.9e+03  9.50e-01   -1.560262945e+05  9.479865290e+05   1.2e-02  0.05
# 7   3.1e+00  1.6e-03  3.3e+03  9.62e-01   -6.644324296e+04  6.888489522e+05   7.9e-03  0.05
# 8   1.3e+00  6.7e-04  1.4e+03  1.01e+00   -1.030638939e+05  2.138819354e+05   3.3e-03  0.06
# 9   1.7e-01  9.0e-05  1.9e+02  9.92e-01   -1.384968459e+04  2.860609979e+04   4.5e-04  0.06
# 10  1.0e-03  5.2e-07  1.1e+00  9.99e-01   -7.877029750e+01  1.663728601e+02   2.6e-06  0.06
# 11  5.2e-06  2.7e-09  5.6e-03  1.00e+00   -4.125941954e-01  8.715614228e-01   1.3e-08  0.06
# 12  2.8e-08  1.6e-09  2.6e-04  1.00e+00   -2.169849300e-03  5.759014757e-02   7.1e-11  0.07
# 13  1.4e-10  8.6e-12  1.4e-06  1.00e+00   -1.128102493e-05  3.051679560e-04   3.7e-13  0.07
# 14  1.4e-12  3.6e-14  4.2e-09  1.00e+00   -5.864993643e-08  -1.012804992e-06  1.9e-15  0.07
# 15  1.4e-12  3.6e-14  4.2e-09  1.99e+02   -5.864993643e-08  -1.012804992e-06  1.9e-15  0.07
# 16  6.6e-13  1.9e-16  2.2e-11  1.00e+00   -3.049204359e-10  -5.265563077e-09  1.0e-17  0.08
# Optimizer terminated. Time: 0.10
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: -3.0492043593e-10   nrm: 3e+05    Viol.  con: 2e-10    var: 0e+00
#   Dual.    obj: -5.2655630768e-09   nrm: 1e+00    Viol.  con: 0e+00    var: 3e-17
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Aug 22 05:51:37 PM: Problem status: optimal
# (CVXPY) Aug 22 05:51:37 PM: Optimal value: 5.266e-09
# (CVXPY) Aug 22 05:51:37 PM: Compilation took 6.905e-02 seconds
# (CVXPY) Aug 22 05:51:37 PM: Solver (including time spent in interface) took 1.244e-01 seconds
# 5.265563076765421e-09

# %%
bool_vars_idx = [(x,) for x in bool_idx]

lam = np.ones(len(b_coup))
max_iter = 10000
tolerance = 0.5
x = cp.Variable(A.shape[1], boolean = bool_vars_idx)

lb = -np.inf
ub = np.inf
currbest = ub
error = []
j= 0 
divider=2
z=100
for i in range(max_iter):
    print('iteration',i)
    #print('solving decoupled', i)
    #x = cp.Variable(A.shape[1], boolean = bool_vars_idx)
    #p_sub = cp.Problem(cp.Minimize(c.T@x),
    #             [A@x<=b])
    #print(lam)
    #z = p_sub.solve(solver = 'MOSEK', verbose = True)    
    #x = x.value

    #print('solving dual', i)
    #d = cp.Problem(cp.Maximize( -np.hstack((b,b_coup)).T@lam ),
    #         [np.vstack((A,A_coup)).T@lam +c == 0, lam>=0])
    
    #d_star = d.solve(solver = 'MOSEK', verbose = True) 
    #print('solving relaxed', i)
    #lam = cp.Variable(len(b_coup))
    x = cp.Variable(A.shape[1], boolean = bool_vars_idx)
    r = cp.Problem(cp.Minimize(c.T@x +  lam.T@(A_coup@x -b_coup) ),
                 [A@x<=b])
    try:
        z = r.solve(solver = 'MOSEK', verbose = False)
        print(z)
        x = x.value
        xprev = x.copy()
    except:
        lam = lamprev.copy()
        divider = divider/2
        x=xprev.copy()
        print('failed')

    g = A_coup@x-b_coup
    error.append(np.linalg.norm(g,2))
    
    if z<currbest:
        currbest = z
    else:
        if j==10:
            divider = divider/2
            j=0
        
    
    step = divider*z/np.linalg.norm(g,2)
    if np.linalg.norm(g,2)<=tolerance:
        break
    else:
        lamprev = lam.copy()
        lam = np.maximum(0,lam+g*step)
        #lam = np.round(lam)
    j+=1
# Out:
# iteration 0
# -299996334.0
# iteration 1
# failed
# iteration 2
# failed
# iteration 3
# failed
# iteration 4
# failed
# iteration 5
# failed
# iteration 6
# failed
# iteration 7
# failed
# iteration 8
# failed
# iteration 9
# failed
# iteration 10
# failed
# iteration 11
# failed
# iteration 12
# failed
# iteration 13
# failed
# iteration 14
# failed
# iteration 15
# failed
# iteration 16
# failed
# iteration 17
# failed
# iteration 18
# failed
# iteration 19
# failed
# iteration 20
# failed
# iteration 21
# failed
# iteration 22
# failed
# iteration 23
# failed
# iteration 24
# failed
# iteration 25
# failed
# iteration 26
# failed
# iteration 27
# failed
# iteration 28
# failed
# iteration 29
# -304975723.58170915
# iteration 30
# failed
# iteration 31
# -306243164.7564106
# iteration 32
# failed
# iteration 33
# failed
# iteration 34
# failed
# iteration 35
# -306402253.31923306
# iteration 36
# failed
# iteration 37
# -306481838.922662
# iteration 38
# failed
# iteration 39
# failed
# iteration 40
# failed
# iteration 41
# failed
# iteration 42
# -306484326.6187611
# iteration 43
# failed
# iteration 44
# -306485570.4769068
# iteration 45
# failed
# iteration 46
# failed
# iteration 47
# -306485881.4427054
# iteration 48
# failed
# iteration 49
# failed
# iteration 50
# failed
# iteration 51
# -306485900.8780875
# iteration 52
# failed
# iteration 53
# failed
# iteration 54
# -306485905.73693323
# iteration 55
# failed
# iteration 56
# -306485908.16635597
# iteration 57
# failed
# iteration 58
# -306485909.38106745
# iteration 59
# failed
# iteration 60
# failed
# iteration 61
# -306485909.5329066
# iteration 62
# -306485909.6847454
# iteration 63
# failed
# iteration 64
# failed
# iteration 65
# -306485909.7227055
# iteration 66
# failed
# iteration 67
# -306485909.7416854
# iteration 68
# failed
# iteration 69
# -306485909.7511753
# iteration 70
# failed
# iteration 71
# failed
# iteration 72
# failed
# iteration 73
# -306485909.75176835
# iteration 74
# failed
# iteration 75
# -306485909.752065
# iteration 76
# failed
# iteration 77
# -306485909.75221324
# iteration 78
# failed
# iteration 79
# -306485909.752287
# iteration 80
# failed
# iteration 81
# -306485909.75230587
# iteration 82
# -306485909.75232446
# iteration 83
# failed
# iteration 84
# failed
# iteration 85
# -306485909.75232875
# iteration 86
# failed
# iteration 87
# -306485909.752331
# iteration 88
# failed
# iteration 89
# -306485909.75233245
# iteration 90
# failed
# iteration 91
# -306485909.7523328
# iteration 92
# -306485909.75233305
# iteration 93
# -306485909.7523332
# iteration 94
# failed
# iteration 95
# failed
# iteration 96
# -306485909.7523333
# iteration 97
# -306485909.75233334
# iteration 98
# -306485909.75233334
# iteration 99
# -306485909.7523334
# iteration 100
# -306485909.7523334
# iteration 101
# failed
# iteration 102
# -306485909.7523334
# iteration 103
# -306485909.7523334
# iteration 104
# -306485909.7523334
# iteration 105
# -306485909.7523334
# iteration 106
# -306485909.7523334
# iteration 107
# -306485909.7523334
# iteration 108
# -306485909.7523334
# iteration 109
# -306485909.7523334
# iteration 110
# -306485909.7523334
# iteration 111
# -306485909.7523334
# iteration 112
# -306485909.7523334
# iteration 113
# -306485909.7523334
# iteration 114
# -306485909.7523334
# iteration 115
# -306485909.7523334
# iteration 116
# -306485909.7523334
# iteration 117
# -306485909.7523334
# iteration 118
# -306485909.7523334
# iteration 119
# -306485909.7523334
# iteration 120
# -306485909.7523334
# iteration 121
# -306485909.7523334
# iteration 122
# -306485909.7523334
# iteration 123
# -306485909.7523334
# iteration 124
# -306485909.7523334
# iteration 125
# -306485909.7523334
# iteration 126
# -306485909.7523334
# iteration 127
# -306485909.7523334
# iteration 128
# -306485909.7523334
# iteration 129
# -306485909.7523334
# iteration 130
# -306485909.7523334
# iteration 131
# -306485909.7523334
# iteration 132
# -306485909.7523334
# iteration 133
# -306485909.7523334
# iteration 134
# -306485909.7523334
# iteration 135
# -306485909.7523334
# iteration 136
# -306485909.7523334
# iteration 137
# -306485909.7523334
# iteration 138
# -306485909.7523334
# iteration 139
# -306485909.7523334
# iteration 140
# -306485909.7523334
# iteration 141
# -306485909.7523334
# iteration 142
# -306485909.7523334
# iteration 143
# -306485909.7523334
# iteration 144
# -306485909.7523334
# iteration 145
# -306485909.7523334
# iteration 146
# -306485909.7523334
# iteration 147
# -306485909.7523334
# iteration 148
# -306485909.7523334
# iteration 149
# -306485909.7523334
# iteration 150
# -306485909.7523334
# iteration 151
# -306485909.7523334
# iteration 152
# -306485909.7523334
# iteration 153
# -306485909.7523334
# iteration 154
# -306485909.7523334
# iteration 155
# -306485909.7523334
# iteration 156
# -306485909.7523334
# iteration 157
# -306485909.7523334
# iteration 158
# -306485909.7523334
# iteration 159
# -306485909.7523334
# iteration 160
# -306485909.7523334
# iteration 161
# -306485909.7523334
# iteration 162
# -306485909.7523334
# iteration 163
# -306485909.7523334
# iteration 164
# -306485909.7523334
# iteration 165
# -306485909.7523334
# iteration 166
# -306485909.7523334
# iteration 167
# -306485909.7523334
# iteration 168
# -306485909.7523334
# iteration 169
# -306485909.7523334
# iteration 170
# -306485909.7523334
# iteration 171
# -306485909.7523334
# iteration 172
# -306485909.7523334
# iteration 173
# -306485909.7523334
# iteration 174
# -306485909.7523334
# iteration 175
# -306485909.7523334
# iteration 176
# -306485909.7523334
# iteration 177
# -306485909.7523334
# iteration 178
# -306485909.7523334
# iteration 179
# -306485909.7523334
# iteration 180
# -306485909.7523334
# iteration 181
# -306485909.7523334
# iteration 182
# -306485909.7523334
# iteration 183
# -306485909.7523334
# iteration 184
# -306485909.7523334
# iteration 185
# -306485909.7523334
# iteration 186
# -306485909.7523334
# iteration 187
# -306485909.7523334
# iteration 188
# -306485909.7523334
# iteration 189
# -306485909.7523334
# iteration 190
# -306485909.7523334
# iteration 191
# -306485909.7523334
# iteration 192
# -306485909.7523334
# iteration 193
# -306485909.7523334
# iteration 194
# -306485909.7523334
# iteration 195
# -306485909.7523334
# iteration 196
# -306485909.7523334
# iteration 197
# -306485909.7523334
# iteration 198
# -306485909.7523334
# iteration 199
# -306485909.7523334
# iteration 200
# -306485909.7523334
# iteration 201
# -306485909.7523334
# iteration 202
# -306485909.7523334
# iteration 203
# -306485909.7523334
# iteration 204
# -306485909.7523334
# iteration 205
# -306485909.7523334
# iteration 206
# -306485909.7523334
# iteration 207
# -306485909.7523334
# iteration 208
# -306485909.7523334
# iteration 209
# -306485909.7523334
# iteration 210
# -306485909.7523334
# iteration 211
# -306485909.7523334
# iteration 212
# -306485909.7523334
# iteration 213
# -306485909.7523334
# iteration 214
# -306485909.7523334
# iteration 215
# -306485909.7523334
# iteration 216
# -306485909.7523334
# iteration 217
# -306485909.7523334
# iteration 218
# -306485909.7523334
# iteration 219
# -306485909.7523334
# iteration 220
# -306485909.7523334
# iteration 221
# -306485909.7523334
# iteration 222
# -306485909.7523334
# iteration 223
# -306485909.7523334
# iteration 224
# -306485909.7523334
# iteration 225
# -306485909.7523334
# iteration 226
# -306485909.7523334
# iteration 227
# -306485909.7523334
# iteration 228
# -306485909.7523334
# iteration 229
# -306485909.7523334
# iteration 230
# -306485909.7523334
# iteration 231
# -306485909.7523334
# iteration 232
# -306485909.7523334
# iteration 233
# -306485909.7523334
# iteration 234
# -306485909.7523334
# iteration 235
# -306485909.7523334
# iteration 236
# -306485909.7523334
# iteration 237
# -306485909.7523334
# iteration 238
# -306485909.7523334
# iteration 239
# -306485909.7523334
# iteration 240
# -306485909.7523334
# iteration 241
# -306485909.7523334
# iteration 242
# -306485909.7523334
# iteration 243
# -306485909.7523334
# iteration 244
# -306485909.7523334
# iteration 245
# -306485909.7523334
# iteration 246
# -306485909.7523334
# iteration 247
# -306485909.7523334
# iteration 248
# -306485909.7523334
# iteration 249
# -306485909.7523334
# iteration 250
# -306485909.7523334
# iteration 251
# -306485909.7523334
# iteration 252
# -306485909.7523334
# iteration 253
# -306485909.7523334
# iteration 254
# -306485909.7523334
# iteration 255
# -306485909.7523334
# iteration 256
# -306485909.7523334
# iteration 257
# -306485909.7523334
# iteration 258
# -306485909.7523334
# iteration 259
# -306485909.7523334
# iteration 260
# -306485909.7523334
# iteration 261
# -306485909.7523334
# iteration 262
# -306485909.7523334
# iteration 263
# -306485909.7523334
# iteration 264
# -306485909.7523334
# iteration 265
# -306485909.7523334
# iteration 266
# -306485909.7523334
# iteration 267
# -306485909.7523334
# iteration 268
# -306485909.7523334
# iteration 269
# -306485909.7523334
# iteration 270
# -306485909.7523334
# iteration 271
# -306485909.7523334
# iteration 272
# -306485909.7523334
# iteration 273
# -306485909.7523334
# iteration 274
# -306485909.7523334
# iteration 275
# -306485909.7523334
# iteration 276
# -306485909.7523334
# iteration 277
# -306485909.7523334
# iteration 278
# -306485909.7523334
# iteration 279
# -306485909.7523334
# iteration 280
# -306485909.7523334
# iteration 281
# -306485909.7523334
# iteration 282
# -306485909.7523334
# iteration 283
# -306485909.7523334
# iteration 284
# -306485909.7523334
# iteration 285
# -306485909.7523334
# iteration 286
# -306485909.7523334
# iteration 287
# -306485909.7523334
# iteration 288
# -306485909.7523334
# iteration 289
# -306485909.7523334
# iteration 290
# failed
# iteration 291
# -306485909.7523334
# iteration 292
# -306485909.7523334
# iteration 293
# -306485909.7523334
# iteration 294
# -306485909.7523334
# iteration 295
# -306485909.7523334
# iteration 296
# -306485909.7523334
# iteration 297
# -306485909.7523334
# iteration 298
# -306485909.7523334
# iteration 299
# -306485909.7523334
# iteration 300
# -306485909.7523334
# iteration 301
# -306485909.7523334
# iteration 302
# -306485909.7523334
# iteration 303
# -306485909.7523334
# iteration 304
# -306485909.7523334
# iteration 305
# -306485909.7523334
# iteration 306
# -306485909.7523334
# iteration 307
# -306485909.7523334
# iteration 308
# -306485909.7523334
# iteration 309
# -306485909.7523334
# iteration 310
# -306485909.7523334
# iteration 311
# -306485909.7523334
# iteration 312
# -306485909.7523334
# iteration 313
# -306485909.7523334
# iteration 314
# -306485909.7523334
# iteration 315
# -306485909.7523334
# iteration 316
# -306485909.7523334
# iteration 317
# -306485909.7523334
# iteration 318
# -306485909.7523334
# iteration 319
# -306485909.7523334
# iteration 320
# -306485909.7523334
# iteration 321
# -306485909.7523334
# iteration 322
# -306485909.7523334
# iteration 323
# -306485909.7523334
# iteration 324
# -306485909.7523334
# iteration 325
# -306485909.7523334
# iteration 326
# -306485909.7523334
# iteration 327
# -306485909.7523334
# iteration 328
# -306485909.7523334
# iteration 329
# -306485909.7523334
# iteration 330
# -306485909.7523334
# iteration 331
# -306485909.7523334
# iteration 332
# -306485909.7523334
# iteration 333
# -306485909.7523334
# iteration 334
# -306485909.7523334
# iteration 335
# -306485909.7523334
# iteration 336
# -306485909.7523334
# iteration 337
# -306485909.7523334
# iteration 338
# -306485909.7523334
# iteration 339
# -306485909.7523334
# iteration 340
# -306485909.7523334
# iteration 341
# -306485909.7523334
# iteration 342
# -306485909.7523334
# iteration 343
# -306485909.7523334
# iteration 344
# -306485909.7523334
# iteration 345
# -306485909.7523334
# iteration 346
# -306485909.7523334
# iteration 347
# -306485909.7523334
# iteration 348
# -306485909.7523334
# iteration 349
# -306485909.7523334
# iteration 350
# -306485909.7523334
# iteration 351
# -306485909.7523334
# iteration 352
# -306485909.7523334
# iteration 353
# -306485909.7523334
# iteration 354
# -306485909.7523334
# iteration 355
# -306485909.7523334
# iteration 356
# -306485909.7523334
# iteration 357
# -306485909.7523334
# iteration 358
# -306485909.7523334
# iteration 359
# -306485909.7523334
# iteration 360
# -306485909.7523334
# iteration 361
# -306485909.7523334
# iteration 362
# -306485909.7523334
# iteration 363
# -306485909.7523334
# iteration 364
# -306485909.7523334
# iteration 365
# -306485909.7523334
# iteration 366
# -306485909.7523334
# iteration 367
# -306485909.7523334
# iteration 368
# -306485909.7523334
# iteration 369
# -306485909.7523334
# iteration 370
# -306485909.7523334
# iteration 371
# -306485909.7523334
# iteration 372
# -306485909.7523334
# iteration 373
# -306485909.7523334
# iteration 374
# -306485909.7523334
# iteration 375
# -306485909.7523334
# iteration 376
# -306485909.7523334
# iteration 377
# -306485909.7523334
# iteration 378
# -306485909.7523334
# iteration 379
# -306485909.7523334
# iteration 380
# -306485909.7523334
# iteration 381
# -306485909.7523334
# iteration 382
# -306485909.7523334
# iteration 383
# -306485909.7523334
# iteration 384
# -306485909.7523334
# iteration 385
# -306485909.7523334
# iteration 386
# -306485909.7523334
# iteration 387
# -306485909.7523334
# iteration 388
# -306485909.7523334
# iteration 389
# -306485909.7523334
# iteration 390
# -306485909.7523334
# iteration 391
# -306485909.7523334
# iteration 392
# -306485909.7523334
# iteration 393
# -306485909.7523334
# iteration 394
# -306485909.7523334
# iteration 395
# -306485909.7523334
# iteration 396
# -306485909.7523334
# iteration 397
# -306485909.7523334
# iteration 398
# -306485909.7523334
# iteration 399
# -306485909.7523334
# iteration 400
# -306485909.7523334
# iteration 401
# -306485909.7523334
# iteration 402
# -306485909.7523334
# iteration 403
# -306485909.7523334
# iteration 404
# -306485909.7523334
# iteration 405
# -306485909.7523334
# iteration 406
# -306485909.7523334
# iteration 407
# -306485909.7523334
# iteration 408
# -306485909.7523334
# iteration 409
# -306485909.7523334
# iteration 410
# -306485909.7523334
# iteration 411
# -306485909.7523334
# iteration 412
# -306485909.7523334
# iteration 413
# -306485909.7523334
# iteration 414
# -306485909.7523334
# iteration 415
# -306485909.7523334
# iteration 416
# -306485909.7523334
# iteration 417
# -306485909.7523334
# iteration 418
# -306485909.7523334
# iteration 419
# -306485909.7523334
# iteration 420
# -306485909.7523334
# iteration 421
# -306485909.7523334
# iteration 422
# -306485909.7523334
# iteration 423
# -306485909.7523334
# iteration 424
# -306485909.7523334
# iteration 425
# -306485909.7523334
# iteration 426
# -306485909.7523334
# iteration 427
# -306485909.7523334
# iteration 428
# -306485909.7523334
# iteration 429
# -306485909.7523334
# iteration 430
# -306485909.7523334
# iteration 431
# -306485909.7523334
# iteration 432
# -306485909.7523334
# iteration 433
# -306485909.7523334
# iteration 434
# -306485909.7523334
# iteration 435
# -306485909.7523334
# iteration 436
# -306485909.7523334
# iteration 437
# -306485909.7523334
# iteration 438
# -306485909.7523334
# iteration 439
# -306485909.7523334
# iteration 440
# -306485909.7523334
# iteration 441
# -306485909.7523334
# iteration 442
# -306485909.7523334
# iteration 443
# -306485909.7523334
# iteration 444
# -306485909.7523334
# iteration 445
# -306485909.7523334
# iteration 446
# -306485909.7523334
# iteration 447
# -306485909.7523334
# iteration 448
# -306485909.7523334
# iteration 449
# -306485909.7523334
# iteration 450
# -306485909.7523334
# iteration 451
# -306485909.7523334
# iteration 452
# -306485909.7523334
# iteration 453
# -306485909.7523334
# iteration 454
# -306485909.7523334
# iteration 455
# -306485909.7523334
# iteration 456
# -306485909.7523334
# iteration 457
# -306485909.7523334
# iteration 458
# -306485909.7523334
# iteration 459
# -306485909.7523334
# iteration 460
# -306485909.7523334
# iteration 461
# -306485909.7523334
# iteration 462
# -306485909.7523334
# iteration 463
# -306485909.7523334
# iteration 464
# -306485909.7523334
# iteration 465
# -306485909.7523334
# iteration 466
# -306485909.7523334
# iteration 467
# -306485909.7523334
# iteration 468
# -306485909.7523334
# iteration 469
# -306485909.7523334
# iteration 470
# -306485909.7523334
# iteration 471
# -306485909.7523334
# iteration 472
# -306485909.7523334
# iteration 473
# -306485909.7523334
# iteration 474
# -306485909.7523334
# iteration 475
# -306485909.7523334
# iteration 476
# -306485909.7523334
# iteration 477
# -306485909.7523334
# iteration 478
# -306485909.7523334
# iteration 479
# -306485909.7523334
# iteration 480
# -306485909.7523334
# iteration 481
# -306485909.7523334
# iteration 482
# -306485909.7523334
# iteration 483
# -306485909.7523334
# iteration 484
# -306485909.7523334
# iteration 485
# -306485909.7523334
# iteration 486
# -306485909.7523334
# iteration 487
# -306485909.7523334
# iteration 488
# -306485909.7523334
# iteration 489
# -306485909.7523334
# iteration 490
# -306485909.7523334
# iteration 491
# -306485909.7523334
# iteration 492
# -306485909.7523334
# iteration 493
# -306485909.7523334
# iteration 494
# -306485909.7523334
# iteration 495
# -306485909.7523334
# iteration 496
# -306485909.7523334
# iteration 497
# -306485909.7523334
# iteration 498
# -306485909.7523334
# iteration 499
# -306485909.7523334
# iteration 500
# -306485909.7523334
# iteration 501
# -306485909.7523334
# iteration 502
# -306485909.7523334
# iteration 503
# -306485909.7523334
# iteration 504
# -306485909.7523334
# iteration 505
# -306485909.7523334
# iteration 506
# -306485909.7523334
# iteration 507
# -306485909.7523334
# iteration 508
# -306485909.7523334
# iteration 509
# -306485909.7523334
# iteration 510
# -306485909.7523334
# iteration 511
# -306485909.7523334
# iteration 512
# -306485909.7523334
# iteration 513
# -306485909.7523334
# iteration 514
# -306485909.7523334
# iteration 515
# -306485909.7523334
# iteration 516
# -306485909.7523334
# iteration 517
# -306485909.7523334
# iteration 518
# -306485909.7523334
# iteration 519
# -306485909.7523334
# iteration 520
# -306485909.7523334
# iteration 521
# -306485909.7523334
# iteration 522
# -306485909.7523334
# iteration 523
# -306485909.7523334
# iteration 524
# -306485909.7523334
# iteration 525
# -306485909.7523334
# iteration 526
# -306485909.7523334
# iteration 527
# -306485909.7523334
# iteration 528
# -306485909.7523334
# iteration 529
# -306485909.7523334
# iteration 530
# -306485909.7523334
# iteration 531
# -306485909.7523334
# iteration 532
# -306485909.7523334
# iteration 533
# -306485909.7523334
# iteration 534
# -306485909.7523334
# iteration 535
# -306485909.7523334
# iteration 536
# -306485909.7523334
# iteration 537
# -306485909.7523334
# iteration 538
# -306485909.7523334
# iteration 539
# -306485909.7523334
# iteration 540
# -306485909.7523334
# iteration 541
# -306485909.7523334
# iteration 542
# -306485909.7523334
# iteration 543
# -306485909.7523334
# iteration 544
# -306485909.7523334
# iteration 545
# -306485909.7523334
# iteration 546
# -306485909.7523334
# iteration 547
# -306485909.7523334
# iteration 548
# -306485909.7523334
# iteration 549
# -306485909.7523334
# iteration 550
# -306485909.7523334
# iteration 551
# -306485909.7523334
# iteration 552
# -306485909.7523334
# iteration 553
# -306485909.7523334
# iteration 554
# -306485909.7523334
# iteration 555
# -306485909.7523334
# iteration 556
# -306485909.7523334
# iteration 557
# -306485909.7523334
# iteration 558
# -306485909.7523334
# iteration 559
# -306485909.7523334
# iteration 560
# -306485909.7523334
# iteration 561
# -306485909.7523334
# iteration 562
# -306485909.7523334
# iteration 563
# -306485909.7523334
# iteration 564
# -306485909.7523334
# iteration 565
# -306485909.7523334
# iteration 566
# -306485909.7523334
# iteration 567
# -306485909.7523334
# iteration 568
# -306485909.7523334
# iteration 569
# -306485909.7523334
# iteration 570
# -306485909.7523334
# iteration 571
# -306485909.7523334
# iteration 572
# -306485909.7523334
# iteration 573
# -306485909.7523334
# iteration 574
# -306485909.7523334
# iteration 575
# -306485909.7523334
# iteration 576
# -306485909.7523334
# iteration 577
# -306485909.7523334
# iteration 578
# -306485909.7523334
# iteration 579
# -306485909.7523334
# iteration 580
# -306485909.7523334
# iteration 581
# -306485909.7523334
# iteration 582
# -306485909.7523334
# iteration 583
# -306485909.7523334
# iteration 584
# -306485909.7523334
# iteration 585
# -306485909.7523334
# iteration 586
# -306485909.7523334
# iteration 587
# -306485909.7523334
# iteration 588
# -306485909.7523334
# iteration 589
# -306485909.7523334
# iteration 590
# -306485909.7523334
# iteration 591
# -306485909.7523334
# iteration 592
# -306485909.7523334
# iteration 593
# -306485909.7523334
# iteration 594
# -306485909.7523334
# iteration 595
# -306485909.7523334
# iteration 596
# -306485909.7523334
# iteration 597
# -306485909.7523334
# iteration 598
# -306485909.7523334
# iteration 599
# -306485909.7523334
# iteration 600
# -306485909.7523334
# iteration 601
# -306485909.7523334
# iteration 602
# -306485909.7523334
# iteration 603
# -306485909.7523334
# iteration 604
# -306485909.7523334
# iteration 605
# -306485909.7523334
# iteration 606
# -306485909.7523334
# iteration 607
# -306485909.7523334
# iteration 608
# -306485909.7523334
# iteration 609
# -306485909.7523334
# iteration 610
# -306485909.7523334
# iteration 611
# -306485909.7523334
# iteration 612
# -306485909.7523334
# iteration 613
# -306485909.7523334
# iteration 614
# -306485909.7523334
# iteration 615
# -306485909.7523334
# iteration 616
# -306485909.7523334
# iteration 617
# -306485909.7523334
# iteration 618
# -306485909.7523334
# iteration 619
# -306485909.7523334
# iteration 620
# -306485909.7523334
# iteration 621
# -306485909.7523334
# iteration 622
# -306485909.7523334
# iteration 623
# -306485909.7523334
# iteration 624
# -306485909.7523334
# iteration 625
# -306485909.7523334
# iteration 626
# -306485909.7523334
# iteration 627
# -306485909.7523334
# iteration 628
# -306485909.7523334
# iteration 629
# -306485909.7523334
# iteration 630
# -306485909.7523334
# iteration 631
# -306485909.7523334
# iteration 632
# -306485909.7523334
# iteration 633
# -306485909.7523334
# iteration 634
# -306485909.7523334
# iteration 635
# -306485909.7523334
# iteration 636
# -306485909.7523334
# iteration 637
# -306485909.7523334
# iteration 638
# -306485909.7523334
# iteration 639
# -306485909.7523334
# iteration 640
# -306485909.7523334
# iteration 641
# -306485909.7523334
# iteration 642
# -306485909.7523334
# iteration 643
# -306485909.7523334
# iteration 644
# -306485909.7523334
# iteration 645
# -306485909.7523334
# iteration 646
# -306485909.7523334
# iteration 647
# -306485909.7523334
# iteration 648
# -306485909.7523334
# iteration 649
# -306485909.7523334
# iteration 650
# -306485909.7523334
# iteration 651
# -306485909.7523334
# iteration 652
# -306485909.7523334
# iteration 653
# -306485909.7523334
# iteration 654
# -306485909.7523334
# iteration 655
# -306485909.7523334
# iteration 656
# -306485909.7523334
# iteration 657
# -306485909.7523334
# iteration 658
# -306485909.7523334
# iteration 659
# -306485909.7523334
# iteration 660
# -306485909.7523334
# iteration 661
# -306485909.7523334
# iteration 662
# -306485909.7523334
# iteration 663
# -306485909.7523334
# iteration 664
# -306485909.7523334
# iteration 665
# -306485909.7523334
# iteration 666
# -306485909.7523334
# iteration 667
# -306485909.7523334
# iteration 668
# -306485909.7523334
# iteration 669
# -306485909.7523334
# iteration 670
# -306485909.7523334
# iteration 671
# -306485909.7523334
# iteration 672
# -306485909.7523334
# iteration 673
# -306485909.7523334
# iteration 674
# -306485909.7523334
# iteration 675
# -306485909.7523334
# iteration 676
# -306485909.7523334
# iteration 677
# -306485909.7523334
# iteration 678
# -306485909.7523334
# iteration 679
# -306485909.7523334
# iteration 680
# -306485909.7523334
# iteration 681
# -306485909.7523334
# iteration 682
# -306485909.7523334
# iteration 683
# -306485909.7523334
# iteration 684
# -306485909.7523334
# iteration 685
# -306485909.7523334
# iteration 686
# -306485909.7523334
# iteration 687
# -306485909.7523334
# iteration 688
# -306485909.7523334
# iteration 689
# -306485909.7523334
# iteration 690
# -306485909.7523334
# iteration 691
# -306485909.7523334
# iteration 692
# -306485909.7523334
# iteration 693
# -306485909.7523334
# iteration 694
# -306485909.7523334
# iteration 695
# -306485909.7523334
# iteration 696
# -306485909.7523334
# iteration 697
# -306485909.7523334
# iteration 698
# -306485909.7523334
# iteration 699
# -306485909.7523334
# iteration 700
# -306485909.7523334
# iteration 701
# -306485909.7523334
# iteration 702
# -306485909.7523334
# iteration 703
# -306485909.7523334
# iteration 704
# -306485909.7523334
# iteration 705
# -306485909.7523334
# iteration 706
# -306485909.7523334
# iteration 707
# -306485909.7523334
# iteration 708
# -306485909.7523334
# iteration 709
# -306485909.7523334
# iteration 710
# -306485909.7523334
# iteration 711
# -306485909.7523334
# iteration 712
# -306485909.7523334
# iteration 713
# -306485909.7523334
# iteration 714
# -306485909.7523334
# iteration 715
# -306485909.7523334
# iteration 716
# -306485909.7523334
# iteration 717
# -306485909.7523334
# iteration 718
# -306485909.7523334
# iteration 719
# -306485909.7523334
# iteration 720
# -306485909.7523334
# iteration 721
# -306485909.7523334
# iteration 722
# -306485909.7523334
# iteration 723
# -306485909.7523334
# iteration 724
# -306485909.7523334
# iteration 725
# -306485909.7523334
# iteration 726
# -306485909.7523334
# iteration 727
# -306485909.7523334
# iteration 728
# -306485909.7523334
# iteration 729
# -306485909.7523334
# iteration 730
# -306485909.7523334
# iteration 731
# -306485909.7523334
# iteration 732
# -306485909.7523334
# iteration 733
# -306485909.7523334
# iteration 734
# -306485909.7523334
# iteration 735
# -306485909.7523334
# iteration 736
# -306485909.7523334
# iteration 737
# -306485909.7523334
# iteration 738
# -306485909.7523334
# iteration 739
# -306485909.7523334
# iteration 740
# -306485909.7523334
# iteration 741
# -306485909.7523334
# iteration 742
# -306485909.7523334
# iteration 743
# -306485909.7523334
# iteration 744
# -306485909.7523334
# iteration 745
# -306485909.7523334
# iteration 746
# -306485909.7523334
# iteration 747
# -306485909.7523334
# iteration 748
# -306485909.7523334
# iteration 749
# -306485909.7523334
# iteration 750
# -306485909.7523334
# iteration 751
# -306485909.7523334
# iteration 752
# -306485909.7523334
# iteration 753
# -306485909.7523334
# iteration 754
# -306485909.7523334
# iteration 755
# -306485909.7523334
# iteration 756
# -306485909.7523334
# iteration 757
# -306485909.7523334
# iteration 758
# -306485909.7523334
# iteration 759
# -306485909.7523334
# iteration 760
# -306485909.7523334
# iteration 761
# -306485909.7523334
# iteration 762
# -306485909.7523334
# iteration 763
# -306485909.7523334
# iteration 764
# -306485909.7523334
# iteration 765
# -306485909.7523334
# iteration 766
# -306485909.7523334
# iteration 767
# -306485909.7523334
# iteration 768
# -306485909.7523334
# iteration 769
# -306485909.7523334
# iteration 770
# -306485909.7523334
# iteration 771
# -306485909.7523334
# iteration 772
# -306485909.7523334
# iteration 773
# -306485909.7523334
# iteration 774
# -306485909.7523334
# iteration 775
# -306485909.7523334
# iteration 776
# -306485909.7523334
# iteration 777
# -306485909.7523334
# iteration 778
# -306485909.7523334
# iteration 779
# -306485909.7523334
# iteration 780
# -306485909.7523334
# iteration 781
# -306485909.7523334
# iteration 782
# -306485909.7523334
# iteration 783
# -306485909.7523334
# iteration 784
# -306485909.7523334
# iteration 785
# -306485909.7523334
# iteration 786
# -306485909.7523334
# iteration 787
# -306485909.7523334
# iteration 788
# -306485909.7523334
# iteration 789
# -306485909.7523334
# iteration 790
# -306485909.7523334
# iteration 791
# -306485909.7523334
# iteration 792
# -306485909.7523334
# iteration 793
# -306485909.7523334
# iteration 794
# -306485909.7523334
# iteration 795
# -306485909.7523334
# iteration 796
# -306485909.7523334
# iteration 797
# -306485909.7523334
# iteration 798
# -306485909.7523334
# iteration 799
# -306485909.7523334
# iteration 800
# -306485909.7523334
# iteration 801
# -306485909.7523334
# iteration 802
# -306485909.7523334
# iteration 803
# -306485909.7523334
# iteration 804
# -306485909.7523334
# iteration 805
# -306485909.7523334
# iteration 806
# -306485909.7523334
# iteration 807
# -306485909.7523334
# iteration 808
# -306485909.7523334
# iteration 809
# -306485909.7523334
# iteration 810
# -306485909.7523334
# iteration 811
# -306485909.7523334
# iteration 812
# -306485909.7523334
# iteration 813
# -306485909.7523334
# iteration 814
# -306485909.7523334
# iteration 815
# -306485909.7523334
# iteration 816
# -306485909.7523334
# iteration 817
# -306485909.7523334
# iteration 818
# -306485909.7523334
# iteration 819
# -306485909.7523334
# iteration 820
# -306485909.7523334
# iteration 821
# -306485909.7523334
# iteration 822
# -306485909.7523334
# iteration 823
# -306485909.7523334
# iteration 824
# -306485909.7523334
# iteration 825
# -306485909.7523334
# iteration 826
# -306485909.7523334
# iteration 827
# -306485909.7523334
# iteration 828
# -306485909.7523334
# iteration 829
# -306485909.7523334
# iteration 830
# -306485909.7523334
# iteration 831
# -306485909.7523334
# iteration 832
# -306485909.7523334
# iteration 833
# -306485909.7523334
# iteration 834
# -306485909.7523334
# iteration 835
# -306485909.7523334
# iteration 836
# -306485909.7523334
# iteration 837
# -306485909.7523334
# iteration 838
# -306485909.7523334
# iteration 839
# -306485909.7523334
# iteration 840
# -306485909.7523334
# iteration 841
# -306485909.7523334
# iteration 842
# -306485909.7523334
# iteration 843
# -306485909.7523334
# iteration 844
# -306485909.7523334
# iteration 845
# -306485909.7523334
# iteration 846
# -306485909.7523334
# iteration 847
# -306485909.7523334
# iteration 848
# -306485909.7523334
# iteration 849
# -306485909.7523334
# iteration 850
# -306485909.7523334
# iteration 851
# -306485909.7523334
# iteration 852
# -306485909.7523334
# iteration 853
# -306485909.7523334
# iteration 854
# -306485909.7523334
# iteration 855
# -306485909.7523334
# iteration 856
# -306485909.7523334
# iteration 857
# -306485909.7523334
# iteration 858
# -306485909.7523334
# iteration 859
# -306485909.7523334
# iteration 860
# -306485909.7523334
# iteration 861
# -306485909.7523334
# iteration 862
# -306485909.7523334
# iteration 863
# -306485909.7523334
# iteration 864
# -306485909.7523334
# iteration 865
# -306485909.7523334
# iteration 866
# -306485909.7523334
# iteration 867
# -306485909.7523334
# iteration 868
# -306485909.7523334
# iteration 869
# -306485909.7523334
# iteration 870
# -306485909.7523334
# iteration 871
# -306485909.7523334
# iteration 872
# -306485909.7523334
# iteration 873
# -306485909.7523334
# iteration 874
# -306485909.7523334
# iteration 875
# -306485909.7523334
# iteration 876
# -306485909.7523334
# iteration 877
# -306485909.7523334
# iteration 878
# -306485909.7523334
# iteration 879
# -306485909.7523334
# iteration 880
# -306485909.7523334
# iteration 881
# -306485909.7523334
# iteration 882
# -306485909.7523334
# iteration 883
# -306485909.7523334
# iteration 884
# -306485909.7523334
# iteration 885
# -306485909.7523334
# iteration 886
# -306485909.7523334
# iteration 887
# -306485909.7523334
# iteration 888
# -306485909.7523334
# iteration 889
# -306485909.7523334
# iteration 890
# -306485909.7523334
# iteration 891
# -306485909.7523334
# iteration 892
# -306485909.7523334
# iteration 893
# -306485909.7523334
# iteration 894
# -306485909.7523334
# iteration 895
# -306485909.7523334
# iteration 896
# -306485909.7523334
# iteration 897
# -306485909.7523334
# iteration 898
# -306485909.7523334
# iteration 899
# -306485909.7523334
# iteration 900
# -306485909.7523334
# iteration 901
# -306485909.7523334
# iteration 902
# -306485909.7523334
# iteration 903
# -306485909.7523334
# iteration 904
# -306485909.7523334
# iteration 905
# -306485909.7523334
# iteration 906
# -306485909.7523334
# iteration 907
# -306485909.7523334
# iteration 908
# -306485909.7523334
# iteration 909
# -306485909.7523334
# iteration 910
# -306485909.7523334
# iteration 911
# -306485909.7523334
# iteration 912
# -306485909.7523334
# iteration 913
# -306485909.7523334
# iteration 914
# -306485909.7523334
# iteration 915
# -306485909.7523334
# iteration 916
# -306485909.7523334
# iteration 917
# -306485909.7523334
# iteration 918
# -306485909.7523334
# iteration 919
# -306485909.7523334
# iteration 920
# -306485909.7523334
# iteration 921
# -306485909.7523334
# iteration 922
# -306485909.7523334
# iteration 923
# -306485909.7523334
# iteration 924
# -306485909.7523334
# iteration 925
# -306485909.7523334
# iteration 926
# -306485909.7523334
# iteration 927
# -306485909.7523334
# iteration 928
# -306485909.7523334
# iteration 929
# -306485909.7523334
# iteration 930
# -306485909.7523334
# iteration 931
# -306485909.7523334
# iteration 932
# -306485909.7523334
# iteration 933
# -306485909.7523334
# iteration 934
# -306485909.7523334
# iteration 935
# -306485909.7523334
# iteration 936
# -306485909.7523334
# iteration 937
# -306485909.7523334
# iteration 938
# -306485909.7523334
# iteration 939
# -306485909.7523334
# iteration 940
# -306485909.7523334
# iteration 941
# -306485909.7523334
# iteration 942
# -306485909.7523334
# iteration 943
# -306485909.7523334
# iteration 944
# -306485909.7523334
# iteration 945
# -306485909.7523334
# iteration 946
# -306485909.7523334
# iteration 947
# -306485909.7523334
# iteration 948
# -306485909.7523334
# iteration 949
# -306485909.7523334
# iteration 950
# -306485909.7523334
# iteration 951
# -306485909.7523334
# iteration 952
# -306485909.7523334
# iteration 953
# -306485909.7523334
# iteration 954
# -306485909.7523334
# iteration 955
# -306485909.7523334
# iteration 956
# -306485909.7523334
# iteration 957
# -306485909.7523334
# iteration 958
# -306485909.7523334
# iteration 959
# -306485909.7523334
# iteration 960
# -306485909.7523334
# iteration 961
# -306485909.7523334
# iteration 962
# -306485909.7523334
# iteration 963
# -306485909.7523334
# iteration 964
# -306485909.7523334
# iteration 965
# -306485909.7523334
# iteration 966
# -306485909.7523334
# iteration 967
# -306485909.7523334
# iteration 968
# -306485909.7523334
# iteration 969
# -306485909.7523334
# iteration 970
# -306485909.7523334
# iteration 971
# -306485909.7523334
# iteration 972
# -306485909.7523334
# iteration 973
# -306485909.7523334
# iteration 974
# -306485909.7523334
# iteration 975
# -306485909.7523334
# iteration 976
# -306485909.7523334
# iteration 977
# -306485909.7523334
# iteration 978
# -306485909.7523334
# iteration 979
# -306485909.7523334
# iteration 980
# -306485909.7523334
# iteration 981
# -306485909.7523334
# iteration 982
# -306485909.7523334
# iteration 983
# -306485909.7523334
# iteration 984
# -306485909.7523334
# iteration 985
# -306485909.7523334
# iteration 986
# -306485909.7523334
# iteration 987
# -306485909.7523334
# iteration 988
# -306485909.7523334
# iteration 989
# -306485909.7523334
# iteration 990
# -306485909.7523334
# iteration 991
# -306485909.7523334
# iteration 992
# -306485909.7523334
# iteration 993
# -306485909.7523334
# iteration 994
# -306485909.7523334
# iteration 995
# -306485909.7523334
# iteration 996
# -306485909.7523334
# iteration 997
# -306485909.7523334
# iteration 998
# -306485909.7523334
# iteration 999
# -306485909.7523334
# iteration 1000
# -306485909.7523334
# iteration 1001
# -306485909.7523334
# iteration 1002
# -306485909.7523334
# iteration 1003
# -306485909.7523334
# iteration 1004
# -306485909.7523334
# iteration 1005
# -306485909.7523334
# iteration 1006
# -306485909.7523334
# iteration 1007
# -306485909.7523334
# iteration 1008
# -306485909.7523334
# iteration 1009
# -306485909.7523334
# iteration 1010
# -306485909.7523334
# iteration 1011
# -306485909.7523334
# iteration 1012
# -306485909.7523334
# iteration 1013
# -306485909.7523334
# iteration 1014
# -306485909.7523334
# iteration 1015
# -306485909.7523334
# iteration 1016
# -306485909.7523334
# iteration 1017
# -306485909.7523334
# iteration 1018
# -306485909.7523334
# iteration 1019
# -306485909.7523334
# iteration 1020
# -306485909.7523334
# iteration 1021
# -306485909.7523334
# iteration 1022
# -306485909.7523334
# iteration 1023
# -306485909.7523334
# iteration 1024
# -306485909.7523334
# iteration 1025
# -306485909.7523334
# iteration 1026
# -306485909.7523334
# iteration 1027
# -306485909.7523334
# iteration 1028
# -306485909.7523334
# iteration 1029
# -306485909.7523334
# iteration 1030
# -306485909.7523334
# iteration 1031
# -306485909.7523334
# iteration 1032
# -306485909.7523334
# iteration 1033
# -306485909.7523334
# iteration 1034
# -306485909.7523334
# iteration 1035
# -306485909.7523334
# iteration 1036
# -306485909.7523334
# iteration 1037
# -306485909.7523334
# iteration 1038
# -306485909.7523334
# iteration 1039
# -306485909.7523334
# iteration 1040
# -306485909.7523334
# iteration 1041
# -306485909.7523334
# iteration 1042
# -306485909.7523334
# iteration 1043
# -306485909.7523334
# iteration 1044
# -306485909.7523334
# iteration 1045
# -306485909.7523334
# iteration 1046
# -306485909.7523334
# iteration 1047
# -306485909.7523334
# iteration 1048
# -306485909.7523334
# iteration 1049
# -306485909.7523334
# iteration 1050
# -306485909.7523334
# iteration 1051
# -306485909.7523334
# iteration 1052
# -306485909.7523334
# iteration 1053
# -306485909.7523334
# iteration 1054
# -306485909.7523334
# iteration 1055
# -306485909.7523334
# iteration 1056
# -306485909.7523334
# iteration 1057
# -306485909.7523334
# iteration 1058
# -306485909.7523334
# iteration 1059
# -306485909.7523334
# iteration 1060
# -306485909.7523334
# iteration 1061
# -306485909.7523334
# iteration 1062
# -306485909.7523334
# iteration 1063
# -306485909.7523334
# iteration 1064
# -306485909.7523334
# iteration 1065
# -306485909.7523334
# iteration 1066
# -306485909.7523334
# iteration 1067
# -306485909.7523334
# iteration 1068
# -306485909.7523334
# iteration 1069
# -306485909.7523334
# iteration 1070
# -306485909.7523334
# iteration 1071
# -306485909.7523334
# iteration 1072
# -306485909.7523334
# iteration 1073
# -306485909.7523334
# iteration 1074
# -306485909.7523334
# iteration 1075
# -306485909.7523334
# iteration 1076
# -306485909.7523334
# iteration 1077
# -306485909.7523334
# iteration 1078
# -306485909.7523334
# iteration 1079
# -306485909.7523334
# iteration 1080
# -306485909.7523334
# iteration 1081
# -306485909.7523334
# iteration 1082
# -306485909.7523334
# iteration 1083
# -306485909.7523334
# iteration 1084
# -306485909.7523334
# iteration 1085
# -306485909.7523334
# iteration 1086
# -306485909.7523334
# iteration 1087
# -306485909.7523334
# iteration 1088
# -306485909.7523334
# iteration 1089
# -306485909.7523334
# iteration 1090
# -306485909.7523334
# iteration 1091
# -306485909.7523334
# iteration 1092
# -306485909.7523334
# iteration 1093
# -306485909.7523334
# iteration 1094
# -306485909.7523334
# iteration 1095
# -306485909.7523334
# iteration 1096
# -306485909.7523334
# iteration 1097
# -306485909.7523334
# iteration 1098
# -306485909.7523334
# iteration 1099
# -306485909.7523334
# iteration 1100
# -306485909.7523334
# iteration 1101
# -306485909.7523334
# iteration 1102
# -306485909.7523334
# iteration 1103
# -306485909.7523334
# iteration 1104
# -306485909.7523334
# iteration 1105
# -306485909.7523334
# iteration 1106
# -306485909.7523334
# iteration 1107
# -306485909.7523334
# iteration 1108
# -306485909.7523334
# iteration 1109
# -306485909.7523334
# iteration 1110
# -306485909.7523334
# iteration 1111
# -306485909.7523334
# iteration 1112
# -306485909.7523334
# iteration 1113
# -306485909.7523334
# iteration 1114
# -306485909.7523334
# iteration 1115
# -306485909.7523334
# iteration 1116
# -306485909.7523334
# iteration 1117
# -306485909.7523334
# iteration 1118
# -306485909.7523334
# iteration 1119
# -306485909.7523334
# iteration 1120
# -306485909.7523334
# iteration 1121
# -306485909.7523334
# iteration 1122
# -306485909.7523334
# iteration 1123
# -306485909.7523334
# iteration 1124
# -306485909.7523334
# iteration 1125
# -306485909.7523334
# iteration 1126
# -306485909.7523334
# iteration 1127
# -306485909.7523334
# iteration 1128
# -306485909.7523334
# iteration 1129
# -306485909.7523334
# iteration 1130
# -306485909.7523334
# iteration 1131
# -306485909.7523334
# iteration 1132
# -306485909.7523334
# iteration 1133
# -306485909.7523334
# iteration 1134
# -306485909.7523334
# iteration 1135
# -306485909.7523334
# iteration 1136
# -306485909.7523334
# iteration 1137
# -306485909.7523334
# iteration 1138
# -306485909.7523334
# iteration 1139
# -306485909.7523334
# iteration 1140
# -306485909.7523334
# iteration 1141
# -306485909.7523334
# iteration 1142
# -306485909.7523334
# iteration 1143
# -306485909.7523334
# iteration 1144
# -306485909.7523334
# iteration 1145
# -306485909.7523334
# iteration 1146
# -306485909.7523334
# iteration 1147
# -306485909.7523334
# iteration 1148
# -306485909.7523334
# iteration 1149
# -306485909.7523334
# iteration 1150
# -306485909.7523334
# iteration 1151
# -306485909.7523334
# iteration 1152
# -306485909.7523334
# iteration 1153
# -306485909.7523334
# iteration 1154
# -306485909.7523334
# iteration 1155
# -306485909.7523334
# iteration 1156
# -306485909.7523334
# iteration 1157
# -306485909.7523334
# iteration 1158
# -306485909.7523334
# iteration 1159
# -306485909.7523334
# iteration 1160
# -306485909.7523334
# iteration 1161
# -306485909.7523334
# iteration 1162
# -306485909.7523334
# iteration 1163
# -306485909.7523334
# iteration 1164
# -306485909.7523334
# iteration 1165
# -306485909.7523334
# iteration 1166
# -306485909.7523334
# iteration 1167
# -306485909.7523334
# iteration 1168
# -306485909.7523334
# iteration 1169
# -306485909.7523334
# iteration 1170
# -306485909.7523334
# iteration 1171
# -306485909.7523334
# iteration 1172
# -306485909.7523334
# iteration 1173
# -306485909.7523334
# iteration 1174
# -306485909.7523334
# iteration 1175
# -306485909.7523334
# iteration 1176
# -306485909.7523334
# iteration 1177
# -306485909.7523334
# iteration 1178
# -306485909.7523334
# iteration 1179
# -306485909.7523334
# iteration 1180
# -306485909.7523334
# iteration 1181
# -306485909.7523334
# iteration 1182
# -306485909.7523334
# iteration 1183
# -306485909.7523334
# iteration 1184
# -306485909.7523334
# iteration 1185
# -306485909.7523334
# iteration 1186
# -306485909.7523334
# iteration 1187
# -306485909.7523334
# iteration 1188
# -306485909.7523334
# iteration 1189
# -306485909.7523334
# iteration 1190
# -306485909.7523334
# iteration 1191
# -306485909.7523334
# iteration 1192
# -306485909.7523334
# iteration 1193
# -306485909.7523334
# iteration 1194
# -306485909.7523334
# iteration 1195
# -306485909.7523334
# iteration 1196
# -306485909.7523334
# iteration 1197
# -306485909.7523334
# iteration 1198
# -306485909.7523334
# iteration 1199
# -306485909.7523334
# iteration 1200
# -306485909.7523334
# iteration 1201
# -306485909.7523334
# iteration 1202
# -306485909.7523334
# iteration 1203
# -306485909.7523334
# iteration 1204
# -306485909.7523334
# iteration 1205
# -306485909.7523334
# iteration 1206
# -306485909.7523334
# iteration 1207
# -306485909.7523334
# iteration 1208
# -306485909.7523334
# iteration 1209
# -306485909.7523334
# iteration 1210
# -306485909.7523334
# iteration 1211
# -306485909.7523334
# iteration 1212
# -306485909.7523334
# iteration 1213
# -306485909.7523334
# iteration 1214
# -306485909.7523334
# iteration 1215
# -306485909.7523334
# iteration 1216
# -306485909.7523334
# iteration 1217
# -306485909.7523334
# iteration 1218
# -306485909.7523334
# iteration 1219
# -306485909.7523334
# iteration 1220
# -306485909.7523334
# iteration 1221
# -306485909.7523334
# iteration 1222
# -306485909.7523334
# iteration 1223
# -306485909.7523334
# iteration 1224
# -306485909.7523334
# iteration 1225
# -306485909.7523334
# iteration 1226
# -306485909.7523334
# iteration 1227
# -306485909.7523334
# iteration 1228
# -306485909.7523334
# iteration 1229
# -306485909.7523334
# iteration 1230
# -306485909.7523334
# iteration 1231
# -306485909.7523334
# iteration 1232
# -306485909.7523334
# iteration 1233
# -306485909.7523334
# iteration 1234
# -306485909.7523334
# iteration 1235
# -306485909.7523334
# iteration 1236
# -306485909.7523334
# iteration 1237
# -306485909.7523334
# iteration 1238
# -306485909.7523334
# iteration 1239
# -306485909.7523334
# iteration 1240
# -306485909.7523334
# iteration 1241
# -306485909.7523334
# iteration 1242
# -306485909.7523334
# iteration 1243
# -306485909.7523334
# iteration 1244
# -306485909.7523334
# iteration 1245
# -306485909.7523334
# iteration 1246
# -306485909.7523334
# iteration 1247
# -306485909.7523334
# iteration 1248
# -306485909.7523334
# iteration 1249
# -306485909.7523334
# iteration 1250
# -306485909.7523334
# iteration 1251
# -306485909.7523334
# iteration 1252
# -306485909.7523334
# iteration 1253
# -306485909.7523334
# iteration 1254
# -306485909.7523334
# iteration 1255
# -306485909.7523334
# iteration 1256
# -306485909.7523334
# iteration 1257
# -306485909.7523334
# iteration 1258
# -306485909.7523334
# iteration 1259
# -306485909.7523334
# iteration 1260
# -306485909.7523334
# iteration 1261
# -306485909.7523334
# iteration 1262
# -306485909.7523334
# iteration 1263
# -306485909.7523334
# iteration 1264
# -306485909.7523334
# iteration 1265
# -306485909.7523334
# iteration 1266
# -306485909.7523334
# iteration 1267
# -306485909.7523334
# iteration 1268
# -306485909.7523334
# iteration 1269
# -306485909.7523334
# iteration 1270
# -306485909.7523334
# iteration 1271
# -306485909.7523334
# iteration 1272
# -306485909.7523334
# iteration 1273
# -306485909.7523334
# iteration 1274
# -306485909.7523334
# iteration 1275
# -306485909.7523334
# iteration 1276
# -306485909.7523334
# iteration 1277
# -306485909.7523334
# iteration 1278
# -306485909.7523334
# iteration 1279
# -306485909.7523334
# iteration 1280
# -306485909.7523334
# iteration 1281
# -306485909.7523334
# iteration 1282
# -306485909.7523334
# iteration 1283
# -306485909.7523334
# iteration 1284
# -306485909.7523334
# iteration 1285
# -306485909.7523334
# iteration 1286
# -306485909.7523334
# iteration 1287
# -306485909.7523334
# iteration 1288
# -306485909.7523334
# iteration 1289
# -306485909.7523334
# iteration 1290
# -306485909.7523334
# iteration 1291
# -306485909.7523334
# iteration 1292
# -306485909.7523334
# iteration 1293
# -306485909.7523334
# iteration 1294
# -306485909.7523334
# iteration 1295
# -306485909.7523334
# iteration 1296
# -306485909.7523334
# iteration 1297
# -306485909.7523334
# iteration 1298
# -306485909.7523334
# iteration 1299
# -306485909.7523334
# iteration 1300
# -306485909.7523334
# iteration 1301
# -306485909.7523334
# iteration 1302
# -306485909.7523334
# iteration 1303
# -306485909.7523334
# iteration 1304
# -306485909.7523334
# iteration 1305
# -306485909.7523334
# iteration 1306
# -306485909.7523334
# iteration 1307
# -306485909.7523334
# iteration 1308
# -306485909.7523334
# iteration 1309
# -306485909.7523334
# iteration 1310
# -306485909.7523334
# iteration 1311
# -306485909.7523334
# iteration 1312
# -306485909.7523334
# iteration 1313
# -306485909.7523334
# iteration 1314
# -306485909.7523334
# iteration 1315
# -306485909.7523334
# iteration 1316
# -306485909.7523334
# iteration 1317
# -306485909.7523334
# iteration 1318
# -306485909.7523334
# iteration 1319
# -306485909.7523334
# iteration 1320
# -306485909.7523334
# iteration 1321
# -306485909.7523334
# iteration 1322
# -306485909.7523334
# iteration 1323
# -306485909.7523334
# iteration 1324
# -306485909.7523334
# iteration 1325
# -306485909.7523334
# iteration 1326
# -306485909.7523334
# iteration 1327
# -306485909.7523334
# iteration 1328
# -306485909.7523334
# iteration 1329
# -306485909.7523334
# iteration 1330
# -306485909.7523334
# iteration 1331
# -306485909.7523334
# iteration 1332
# -306485909.7523334
# iteration 1333
# -306485909.7523334
# iteration 1334
# -306485909.7523334
# iteration 1335
# -306485909.7523334
# iteration 1336
# -306485909.7523334
# iteration 1337
# -306485909.7523334
# iteration 1338
# -306485909.7523334
# iteration 1339
# -306485909.7523334
# iteration 1340
# -306485909.7523334
# iteration 1341
# -306485909.7523334
# iteration 1342
# -306485909.7523334
# iteration 1343
# -306485909.7523334
# iteration 1344
# -306485909.7523334
# iteration 1345
# -306485909.7523334
# iteration 1346
# -306485909.7523334
# iteration 1347
# -306485909.7523334
# iteration 1348
# -306485909.7523334
# iteration 1349
# -306485909.7523334
# iteration 1350
# -306485909.7523334
# iteration 1351
# -306485909.7523334
# iteration 1352
# -306485909.7523334
# iteration 1353
# -306485909.7523334
# iteration 1354
# -306485909.7523334
# iteration 1355
# -306485909.7523334
# iteration 1356
# -306485909.7523334
# iteration 1357
# -306485909.7523334
# iteration 1358
# -306485909.7523334
# iteration 1359
# -306485909.7523334
# iteration 1360
# -306485909.7523334
# iteration 1361
# -306485909.7523334
# iteration 1362
# -306485909.7523334
# iteration 1363
# -306485909.7523334
# iteration 1364
# -306485909.7523334
# iteration 1365
# -306485909.7523334
# iteration 1366
# -306485909.7523334
# iteration 1367
# -306485909.7523334
# iteration 1368
# -306485909.7523334
# iteration 1369
# -306485909.7523334
# iteration 1370
# -306485909.7523334
# iteration 1371
# -306485909.7523334
# iteration 1372
# -306485909.7523334
# iteration 1373
# -306485909.7523334
# iteration 1374
# -306485909.7523334
# iteration 1375
# -306485909.7523334
# iteration 1376
# -306485909.7523334
# iteration 1377
# -306485909.7523334
# iteration 1378
# -306485909.7523334
# iteration 1379
# -306485909.7523334
# iteration 1380
# -306485909.7523334
# iteration 1381
# -306485909.7523334
# iteration 1382
# -306485909.7523334
# iteration 1383
# -306485909.7523334
# iteration 1384
# -306485909.7523334
# iteration 1385
# -306485909.7523334
# iteration 1386
# -306485909.7523334
# iteration 1387
# -306485909.7523334
# iteration 1388
# -306485909.7523334
# iteration 1389
# -306485909.7523334
# iteration 1390
# -306485909.7523334
# iteration 1391
# -306485909.7523334
# iteration 1392
# -306485909.7523334
# iteration 1393
# -306485909.7523334
# iteration 1394
# -306485909.7523334
# iteration 1395
# -306485909.7523334
# iteration 1396
# -306485909.7523334
# iteration 1397
# -306485909.7523334
# iteration 1398
# -306485909.7523334
# iteration 1399
# -306485909.7523334
# iteration 1400
# -306485909.7523334
# iteration 1401
# -306485909.7523334
# iteration 1402
# -306485909.7523334
# iteration 1403
# -306485909.7523334
# iteration 1404
# -306485909.7523334
# iteration 1405
# -306485909.7523334
# iteration 1406
# -306485909.7523334
# iteration 1407
# -306485909.7523334
# iteration 1408
# -306485909.7523334
# iteration 1409
# -306485909.7523334
# iteration 1410
# -306485909.7523334
# iteration 1411
# -306485909.7523334
# iteration 1412
# -306485909.7523334
# iteration 1413
# -306485909.7523334
# iteration 1414
# -306485909.7523334
# iteration 1415
# -306485909.7523334
# iteration 1416
# -306485909.7523334
# iteration 1417
# -306485909.7523334
# iteration 1418
# -306485909.7523334
# iteration 1419
# -306485909.7523334
# iteration 1420
# -306485909.7523334
# iteration 1421
# -306485909.7523334
# iteration 1422
# -306485909.7523334
# iteration 1423
# -306485909.7523334
# iteration 1424
# -306485909.7523334
# iteration 1425
# -306485909.7523334
# iteration 1426
# -306485909.7523334
# iteration 1427
# -306485909.7523334
# iteration 1428
# -306485909.7523334
# iteration 1429
# -306485909.7523334
# iteration 1430
# -306485909.7523334
# iteration 1431
# -306485909.7523334
# iteration 1432
# -306485909.7523334
# iteration 1433
# -306485909.7523334
# iteration 1434
# -306485909.7523334
# iteration 1435
# -306485909.7523334
# iteration 1436
# -306485909.7523334
# iteration 1437
# -306485909.7523334
# iteration 1438
# -306485909.7523334
# iteration 1439
# -306485909.7523334
# iteration 1440
# -306485909.7523334
# iteration 1441
# -306485909.7523334
# iteration 1442
# -306485909.7523334
# iteration 1443
# -306485909.7523334
# iteration 1444
# -306485909.7523334
# iteration 1445
# -306485909.7523334
# iteration 1446
# -306485909.7523334
# iteration 1447
# -306485909.7523334
# iteration 1448
# -306485909.7523334
# iteration 1449
# -306485909.7523334
# iteration 1450
# -306485909.7523334
# iteration 1451
# -306485909.7523334
# iteration 1452
# -306485909.7523334
# iteration 1453
# -306485909.7523334
# iteration 1454
# -306485909.7523334
# iteration 1455
# -306485909.7523334
# iteration 1456
# -306485909.7523334
# iteration 1457
# -306485909.7523334
# iteration 1458
# -306485909.7523334
# iteration 1459
# -306485909.7523334
# iteration 1460
# -306485909.7523334
# iteration 1461
# -306485909.7523334
# iteration 1462
# -306485909.7523334
# iteration 1463
# -306485909.7523334
# iteration 1464
# -306485909.7523334
# iteration 1465
# -306485909.7523334
# iteration 1466
# -306485909.7523334
# iteration 1467
# -306485909.7523334
# iteration 1468
# ...
# -306485909.7523334
# iteration 9530
# -306485909.7523334
# iteration 9531
# -306485909.7523334
# iteration 9532
# -306485909.7523334
# iteration 9533
# -306485909.7523334
# iteration 9534
# -306485909.7523334
# iteration 9535
# -306485909.7523334
# iteration 9536
# -306485909.7523334
# iteration 9537
# -306485909.7523334
# iteration 9538
# -306485909.7523334
# iteration 9539
# -306485909.7523334
# iteration 9540
# -306485909.7523334
# iteration 9541
# -306485909.7523334
# iteration 9542
# -306485909.7523334
# iteration 9543
# -306485909.7523334
# iteration 9544
# -306485909.7523334
# iteration 9545
# -306485909.7523334
# iteration 9546
# -306485909.7523334
# iteration 9547
# -306485909.7523334
# iteration 9548
# -306485909.7523334
# iteration 9549
# -306485909.7523334
# iteration 9550
# -306485909.7523334
# iteration 9551
# -306485909.7523334
# iteration 9552
# -306485909.7523334
# iteration 9553
# -306485909.7523334
# iteration 9554
# -306485909.7523334
# iteration 9555
# -306485909.7523334
# iteration 9556
# -306485909.7523334
# iteration 9557
# -306485909.7523334
# iteration 9558
# -306485909.7523334
# iteration 9559
# -306485909.7523334
# iteration 9560
# -306485909.7523334
# iteration 9561
# -306485909.7523334
# iteration 9562
# -306485909.7523334
# iteration 9563
# -306485909.7523334
# iteration 9564
# -306485909.7523334
# iteration 9565
# -306485909.7523334
# iteration 9566
# -306485909.7523334
# iteration 9567
# -306485909.7523334
# iteration 9568
# -306485909.7523334
# iteration 9569
# -306485909.7523334
# iteration 9570
# -306485909.7523334
# iteration 9571
# -306485909.7523334
# iteration 9572
# -306485909.7523334
# iteration 9573
# -306485909.7523334
# iteration 9574
# -306485909.7523334
# iteration 9575
# -306485909.7523334
# iteration 9576
# -306485909.7523334
# iteration 9577
# -306485909.7523334
# iteration 9578
# -306485909.7523334
# iteration 9579
# -306485909.7523334
# iteration 9580
# -306485909.7523334
# iteration 9581
# -306485909.7523334
# iteration 9582
# -306485909.7523334
# iteration 9583
# -306485909.7523334
# iteration 9584
# -306485909.7523334
# iteration 9585
# -306485909.7523334
# iteration 9586
# -306485909.7523334
# iteration 9587
# -306485909.7523334
# iteration 9588
# -306485909.7523334
# iteration 9589
# -306485909.7523334
# iteration 9590
# -306485909.7523334
# iteration 9591
# -306485909.7523334
# iteration 9592
# -306485909.7523334
# iteration 9593
# -306485909.7523334
# iteration 9594
# -306485909.7523334
# iteration 9595
# -306485909.7523334
# iteration 9596
# -306485909.7523334
# iteration 9597
# -306485909.7523334
# iteration 9598
# -306485909.7523334
# iteration 9599
# -306485909.7523334
# iteration 9600
# -306485909.7523334
# iteration 9601
# -306485909.7523334
# iteration 9602
# -306485909.7523334
# iteration 9603
# -306485909.7523334
# iteration 9604
# -306485909.7523334
# iteration 9605
# -306485909.7523334
# iteration 9606
# -306485909.7523334
# iteration 9607
# -306485909.7523334
# iteration 9608
# -306485909.7523334
# iteration 9609
# -306485909.7523334
# iteration 9610
# -306485909.7523334
# iteration 9611
# -306485909.7523334
# iteration 9612
# -306485909.7523334
# iteration 9613
# -306485909.7523334
# iteration 9614
# -306485909.7523334
# iteration 9615
# -306485909.7523334
# iteration 9616
# -306485909.7523334
# iteration 9617
# -306485909.7523334
# iteration 9618
# -306485909.7523334
# iteration 9619
# -306485909.7523334
# iteration 9620
# -306485909.7523334
# iteration 9621
# -306485909.7523334
# iteration 9622
# -306485909.7523334
# iteration 9623
# -306485909.7523334
# iteration 9624
# -306485909.7523334
# iteration 9625
# -306485909.7523334
# iteration 9626
# -306485909.7523334
# iteration 9627
# -306485909.7523334
# iteration 9628
# -306485909.7523334
# iteration 9629
# -306485909.7523334
# iteration 9630
# -306485909.7523334
# iteration 9631
# -306485909.7523334
# iteration 9632
# -306485909.7523334
# iteration 9633
# -306485909.7523334
# iteration 9634
# -306485909.7523334
# iteration 9635
# -306485909.7523334
# iteration 9636
# -306485909.7523334
# iteration 9637
# -306485909.7523334
# iteration 9638
# -306485909.7523334
# iteration 9639
# -306485909.7523334
# iteration 9640
# -306485909.7523334
# iteration 9641
# -306485909.7523334
# iteration 9642
# -306485909.7523334
# iteration 9643
# -306485909.7523334
# iteration 9644
# -306485909.7523334
# iteration 9645
# -306485909.7523334
# iteration 9646
# -306485909.7523334
# iteration 9647
# -306485909.7523334
# iteration 9648
# -306485909.7523334
# iteration 9649
# -306485909.7523334
# iteration 9650
# -306485909.7523334
# iteration 9651
# -306485909.7523334
# iteration 9652
# -306485909.7523334
# iteration 9653
# -306485909.7523334
# iteration 9654
# -306485909.7523334
# iteration 9655
# -306485909.7523334
# iteration 9656
# -306485909.7523334
# iteration 9657
# -306485909.7523334
# iteration 9658
# -306485909.7523334
# iteration 9659
# -306485909.7523334
# iteration 9660
# -306485909.7523334
# iteration 9661
# -306485909.7523334
# iteration 9662
# -306485909.7523334
# iteration 9663
# -306485909.7523334
# iteration 9664
# -306485909.7523334
# iteration 9665
# -306485909.7523334
# iteration 9666
# -306485909.7523334
# iteration 9667
# -306485909.7523334
# iteration 9668
# -306485909.7523334
# iteration 9669
# -306485909.7523334
# iteration 9670
# -306485909.7523334
# iteration 9671
# -306485909.7523334
# iteration 9672
# -306485909.7523334
# iteration 9673
# -306485909.7523334
# iteration 9674
# -306485909.7523334
# iteration 9675
# -306485909.7523334
# iteration 9676
# -306485909.7523334
# iteration 9677
# -306485909.7523334
# iteration 9678
# -306485909.7523334
# iteration 9679
# -306485909.7523334
# iteration 9680
# -306485909.7523334
# iteration 9681
# -306485909.7523334
# iteration 9682
# -306485909.7523334
# iteration 9683
# -306485909.7523334
# iteration 9684
# -306485909.7523334
# iteration 9685
# -306485909.7523334
# iteration 9686
# -306485909.7523334
# iteration 9687
# -306485909.7523334
# iteration 9688
# -306485909.7523334
# iteration 9689
# -306485909.7523334
# iteration 9690
# -306485909.7523334
# iteration 9691
# -306485909.7523334
# iteration 9692
# -306485909.7523334
# iteration 9693
# -306485909.7523334
# iteration 9694
# -306485909.7523334
# iteration 9695
# -306485909.7523334
# iteration 9696
# -306485909.7523334
# iteration 9697
# -306485909.7523334
# iteration 9698
# -306485909.7523334
# iteration 9699
# -306485909.7523334
# iteration 9700
# -306485909.7523334
# iteration 9701
# -306485909.7523334
# iteration 9702
# -306485909.7523334
# iteration 9703
# -306485909.7523334
# iteration 9704
# -306485909.7523334
# iteration 9705
# -306485909.7523334
# iteration 9706
# -306485909.7523334
# iteration 9707
# -306485909.7523334
# iteration 9708
# -306485909.7523334
# iteration 9709
# -306485909.7523334
# iteration 9710
# -306485909.7523334
# iteration 9711
# -306485909.7523334
# iteration 9712
# -306485909.7523334
# iteration 9713
# -306485909.7523334
# iteration 9714
# -306485909.7523334
# iteration 9715
# -306485909.7523334
# iteration 9716
# -306485909.7523334
# iteration 9717
# -306485909.7523334
# iteration 9718
# -306485909.7523334
# iteration 9719
# -306485909.7523334
# iteration 9720
# -306485909.7523334
# iteration 9721
# -306485909.7523334
# iteration 9722
# -306485909.7523334
# iteration 9723
# -306485909.7523334
# iteration 9724
# -306485909.7523334
# iteration 9725
# -306485909.7523334
# iteration 9726
# -306485909.7523334
# iteration 9727
# -306485909.7523334
# iteration 9728
# -306485909.7523334
# iteration 9729
# -306485909.7523334
# iteration 9730
# -306485909.7523334
# iteration 9731
# -306485909.7523334
# iteration 9732
# -306485909.7523334
# iteration 9733
# -306485909.7523334
# iteration 9734
# -306485909.7523334
# iteration 9735
# -306485909.7523334
# iteration 9736
# -306485909.7523334
# iteration 9737
# -306485909.7523334
# iteration 9738
# -306485909.7523334
# iteration 9739
# -306485909.7523334
# iteration 9740
# -306485909.7523334
# iteration 9741
# -306485909.7523334
# iteration 9742
# -306485909.7523334
# iteration 9743
# -306485909.7523334
# iteration 9744
# -306485909.7523334
# iteration 9745
# -306485909.7523334
# iteration 9746
# -306485909.7523334
# iteration 9747
# -306485909.7523334
# iteration 9748
# -306485909.7523334
# iteration 9749
# -306485909.7523334
# iteration 9750
# -306485909.7523334
# iteration 9751
# -306485909.7523334
# iteration 9752
# -306485909.7523334
# iteration 9753
# -306485909.7523334
# iteration 9754
# -306485909.7523334
# iteration 9755
# -306485909.7523334
# iteration 9756
# -306485909.7523334
# iteration 9757
# -306485909.7523334
# iteration 9758
# -306485909.7523334
# iteration 9759
# -306485909.7523334
# iteration 9760
# -306485909.7523334
# iteration 9761
# -306485909.7523334
# iteration 9762
# -306485909.7523334
# iteration 9763
# -306485909.7523334
# iteration 9764
# -306485909.7523334
# iteration 9765
# -306485909.7523334
# iteration 9766
# -306485909.7523334
# iteration 9767
# -306485909.7523334
# iteration 9768
# -306485909.7523334
# iteration 9769
# -306485909.7523334
# iteration 9770
# -306485909.7523334
# iteration 9771
# -306485909.7523334
# iteration 9772
# -306485909.7523334
# iteration 9773
# -306485909.7523334
# iteration 9774
# -306485909.7523334
# iteration 9775
# -306485909.7523334
# iteration 9776
# -306485909.7523334
# iteration 9777
# -306485909.7523334
# iteration 9778
# -306485909.7523334
# iteration 9779
# -306485909.7523334
# iteration 9780
# -306485909.7523334
# iteration 9781
# -306485909.7523334
# iteration 9782
# -306485909.7523334
# iteration 9783
# -306485909.7523334
# iteration 9784
# -306485909.7523334
# iteration 9785
# -306485909.7523334
# iteration 9786
# -306485909.7523334
# iteration 9787
# -306485909.7523334
# iteration 9788
# -306485909.7523334
# iteration 9789
# -306485909.7523334
# iteration 9790
# -306485909.7523334
# iteration 9791
# -306485909.7523334
# iteration 9792
# -306485909.7523334
# iteration 9793
# -306485909.7523334
# iteration 9794
# -306485909.7523334
# iteration 9795
# -306485909.7523334
# iteration 9796
# -306485909.7523334
# iteration 9797
# -306485909.7523334
# iteration 9798
# -306485909.7523334
# iteration 9799
# -306485909.7523334
# iteration 9800
# -306485909.7523334
# iteration 9801
# -306485909.7523334
# iteration 9802
# -306485909.7523334
# iteration 9803
# -306485909.7523334
# iteration 9804
# -306485909.7523334
# iteration 9805
# -306485909.7523334
# iteration 9806
# -306485909.7523334
# iteration 9807
# -306485909.7523334
# iteration 9808
# -306485909.7523334
# iteration 9809
# -306485909.7523334
# iteration 9810
# -306485909.7523334
# iteration 9811
# -306485909.7523334
# iteration 9812
# -306485909.7523334
# iteration 9813
# -306485909.7523334
# iteration 9814
# -306485909.7523334
# iteration 9815
# -306485909.7523334
# iteration 9816
# -306485909.7523334
# iteration 9817
# -306485909.7523334
# iteration 9818
# -306485909.7523334
# iteration 9819
# -306485909.7523334
# iteration 9820
# -306485909.7523334
# iteration 9821
# -306485909.7523334
# iteration 9822
# -306485909.7523334
# iteration 9823
# -306485909.7523334
# iteration 9824
# -306485909.7523334
# iteration 9825
# -306485909.7523334
# iteration 9826
# -306485909.7523334
# iteration 9827
# -306485909.7523334
# iteration 9828
# -306485909.7523334
# iteration 9829
# -306485909.7523334
# iteration 9830
# -306485909.7523334
# iteration 9831
# -306485909.7523334
# iteration 9832
# -306485909.7523334
# iteration 9833
# -306485909.7523334
# iteration 9834
# -306485909.7523334
# iteration 9835
# -306485909.7523334
# iteration 9836
# -306485909.7523334
# iteration 9837
# -306485909.7523334
# iteration 9838
# -306485909.7523334
# iteration 9839
# -306485909.7523334
# iteration 9840
# -306485909.7523334
# iteration 9841
# -306485909.7523334
# iteration 9842
# -306485909.7523334
# iteration 9843
# -306485909.7523334
# iteration 9844
# -306485909.7523334
# iteration 9845
# -306485909.7523334
# iteration 9846
# -306485909.7523334
# iteration 9847
# -306485909.7523334
# iteration 9848
# -306485909.7523334
# iteration 9849
# -306485909.7523334
# iteration 9850
# -306485909.7523334
# iteration 9851
# -306485909.7523334
# iteration 9852
# -306485909.7523334
# iteration 9853
# -306485909.7523334
# iteration 9854
# -306485909.7523334
# iteration 9855
# -306485909.7523334
# iteration 9856
# -306485909.7523334
# iteration 9857
# -306485909.7523334
# iteration 9858
# -306485909.7523334
# iteration 9859
# -306485909.7523334
# iteration 9860
# -306485909.7523334
# iteration 9861
# -306485909.7523334
# iteration 9862
# -306485909.7523334
# iteration 9863
# -306485909.7523334
# iteration 9864
# -306485909.7523334
# iteration 9865
# -306485909.7523334
# iteration 9866
# -306485909.7523334
# iteration 9867
# -306485909.7523334
# iteration 9868
# -306485909.7523334
# iteration 9869
# -306485909.7523334
# iteration 9870
# -306485909.7523334
# iteration 9871
# -306485909.7523334
# iteration 9872
# -306485909.7523334
# iteration 9873
# -306485909.7523334
# iteration 9874
# -306485909.7523334
# iteration 9875
# -306485909.7523334
# iteration 9876
# -306485909.7523334
# iteration 9877
# -306485909.7523334
# iteration 9878
# -306485909.7523334
# iteration 9879
# -306485909.7523334
# iteration 9880
# -306485909.7523334
# iteration 9881
# -306485909.7523334
# iteration 9882
# -306485909.7523334
# iteration 9883
# -306485909.7523334
# iteration 9884
# -306485909.7523334
# iteration 9885
# -306485909.7523334
# iteration 9886
# -306485909.7523334
# iteration 9887
# -306485909.7523334
# iteration 9888
# -306485909.7523334
# iteration 9889
# -306485909.7523334
# iteration 9890
# -306485909.7523334
# iteration 9891
# -306485909.7523334
# iteration 9892
# -306485909.7523334
# iteration 9893
# -306485909.7523334
# iteration 9894
# -306485909.7523334
# iteration 9895
# -306485909.7523334
# iteration 9896
# -306485909.7523334
# iteration 9897
# -306485909.7523334
# iteration 9898
# -306485909.7523334
# iteration 9899
# -306485909.7523334
# iteration 9900
# -306485909.7523334
# iteration 9901
# -306485909.7523334
# iteration 9902
# -306485909.7523334
# iteration 9903
# -306485909.7523334
# iteration 9904
# -306485909.7523334
# iteration 9905
# -306485909.7523334
# iteration 9906
# -306485909.7523334
# iteration 9907
# -306485909.7523334
# iteration 9908
# -306485909.7523334
# iteration 9909
# -306485909.7523334
# iteration 9910
# -306485909.7523334
# iteration 9911
# -306485909.7523334
# iteration 9912
# -306485909.7523334
# iteration 9913
# -306485909.7523334
# iteration 9914
# -306485909.7523334
# iteration 9915
# -306485909.7523334
# iteration 9916
# -306485909.7523334
# iteration 9917
# -306485909.7523334
# iteration 9918
# -306485909.7523334
# iteration 9919
# -306485909.7523334
# iteration 9920
# -306485909.7523334
# iteration 9921
# -306485909.7523334
# iteration 9922
# -306485909.7523334
# iteration 9923
# -306485909.7523334
# iteration 9924
# -306485909.7523334
# iteration 9925
# -306485909.7523334
# iteration 9926
# -306485909.7523334
# iteration 9927
# -306485909.7523334
# iteration 9928
# -306485909.7523334
# iteration 9929
# -306485909.7523334
# iteration 9930
# -306485909.7523334
# iteration 9931
# -306485909.7523334
# iteration 9932
# -306485909.7523334
# iteration 9933
# -306485909.7523334
# iteration 9934
# -306485909.7523334
# iteration 9935
# -306485909.7523334
# iteration 9936
# -306485909.7523334
# iteration 9937
# -306485909.7523334
# iteration 9938
# -306485909.7523334
# iteration 9939
# -306485909.7523334
# iteration 9940
# -306485909.7523334
# iteration 9941
# -306485909.7523334
# iteration 9942
# -306485909.7523334
# iteration 9943
# -306485909.7523334
# iteration 9944
# -306485909.7523334
# iteration 9945
# -306485909.7523334
# iteration 9946
# -306485909.7523334
# iteration 9947
# -306485909.7523334
# iteration 9948
# -306485909.7523334
# iteration 9949
# -306485909.7523334
# iteration 9950
# -306485909.7523334
# iteration 9951
# -306485909.7523334
# iteration 9952
# -306485909.7523334
# iteration 9953
# -306485909.7523334
# iteration 9954
# -306485909.7523334
# iteration 9955
# -306485909.7523334
# iteration 9956
# -306485909.7523334
# iteration 9957
# -306485909.7523334
# iteration 9958
# -306485909.7523334
# iteration 9959
# -306485909.7523334
# iteration 9960
# -306485909.7523334
# iteration 9961
# -306485909.7523334
# iteration 9962
# -306485909.7523334
# iteration 9963
# -306485909.7523334
# iteration 9964
# -306485909.7523334
# iteration 9965
# -306485909.7523334
# iteration 9966
# -306485909.7523334
# iteration 9967
# -306485909.7523334
# iteration 9968
# -306485909.7523334
# iteration 9969
# -306485909.7523334
# iteration 9970
# -306485909.7523334
# iteration 9971
# -306485909.7523334
# iteration 9972
# -306485909.7523334
# iteration 9973
# -306485909.7523334
# iteration 9974
# -306485909.7523334
# iteration 9975
# -306485909.7523334
# iteration 9976
# -306485909.7523334
# iteration 9977
# -306485909.7523334
# iteration 9978
# -306485909.7523334
# iteration 9979
# -306485909.7523334
# iteration 9980
# -306485909.7523334
# iteration 9981
# -306485909.7523334
# iteration 9982
# -306485909.7523334
# iteration 9983
# -306485909.7523334
# iteration 9984
# -306485909.7523334
# iteration 9985
# -306485909.7523334
# iteration 9986
# -306485909.7523334
# iteration 9987
# -306485909.7523334
# iteration 9988
# -306485909.7523334
# iteration 9989
# -306485909.7523334
# iteration 9990
# -306485909.7523334
# iteration 9991
# -306485909.7523334
# iteration 9992
# -306485909.7523334
# iteration 9993
# -306485909.7523334
# iteration 9994
# -306485909.7523334
# iteration 9995
# -306485909.7523334
# iteration 9996
# -306485909.7523334
# iteration 9997
# -306485909.7523334
# iteration 9998
# -306485909.7523334
# iteration 9999
# -306485909.7523334

# %%
r.objective.value

# %%
plt.plot(error)

# %% [markdown]
# ### Solver

# %% [markdown]
# ### Lagrangian relaxation

# %%
A = A.astype(float)
A[A.nonzero()]=1
from matplotlib import pyplot as plt
(x,y) = A.shape
S=5
plt.figure(figsize = (S,int(S*x/y)))
plt.imshow(A, cmap='Greys',  interpolation='nearest')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-d1184546ac89> in <module>
#       1 A = A.astype(float)
# ----> 2 A[A.nonzero()]=1
#       3 from matplotlib import pyplot as plt
#       4 (x,y) = A.shape
#       5 S=5
#
# TypeError: 'coo_matrix' object does not support item assignment

# %% [markdown]
# ### Constraint check
